# %% [markdown]
# ## Introduction ..
#
# This notebook presents my trail to solve WUZZUF competition hereunder ..
#
# https://www.kaggle.com/WUZZUF/wuzzuf-job-posts/data
#
# This competition dataset is a sample of jobs posted on WUZZUF and the corresponding applications, mainly during 2014 and 2015

# %%
## data manipulation
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from scipy import stats

## reading the data 
import json
import zipfile
import csv

from collections import Counter

# ## plotting .. 
import seaborn as sns
import matplotlib.pyplot as plt
% matplotlib inline

from datetime import datetime


## warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 1. Applications Dataset:

# %%
df_app = pd.read_csv('Wuzzuf_Applications_Sample.csv')

# %%
df_app.head()
# Out:
#          id   user_id   job_id             app_date
# 0  ba7b8f17  846d013c  516e4ed  2014-01-01 07:27:52
# 1  30e1ae86  9d5e32c5  516e4ed  2014-01-01 08:20:42
# 2  d829a6b7  eb26a291  516e4ed  2014-01-01 10:30:37
# 3  3f985f37  7b5e68a8  516e4ed  2014-01-01 10:55:07
# 4   27e1695  76fa79b1  516e4ed  2014-01-01 11:00:26

# %%
np.shape(df_app)
# Out:
# (1854190, 4)

# %% [markdown]
# There are 1854190 applications in this dataset .. each of which contains 4 columns (i.e. id, user_id, job_id, and application_date)

# %% [markdown]
# What is the type of each variable ..

# %%
df_app.columns.to_series().groupby(df_app.dtypes).groups
# Out:
# {dtype('O'): Index([u'id', u'user_id', u'job_id', u'app_date'], dtype='object')}

# %% [markdown]
# ### Comment ..
# ALL variables are considered (Categorical) ..
#
# And this makes sence except for app_date variable .. that has to be a date_time ! ..

# %% [markdown]
# Are there any null values in this dataset ?!

# %%
df_app.isnull().any().any()
# Out:
# False

# %% [markdown]
# NO ! :)
#
# Let's double check ..

# %%
df_app.isnull().sum()
# Out:
# id          0
# user_id     0
# job_id      0
# app_date    0
# dtype: int64

# %% [markdown]
# Confirmed ! :) ..
#
# None of the columns contains null values ..

# %% [markdown]
# ## 2. Job Posts Dataset:

# %%
df_job = pd.read_csv('Wuzzuf_Job_Posts_Sample.csv')

# %%
df_job.head()
# Out:
#          id        city                        job_title  \
# 0   516e4ed        Ciro          Sales & Marketing Agent
# 1  a361ef59       Cairo     German Training Coordinator
# 2  7226ce78       Cairo       Junior Software Developer
# 3  f4b2bcd6       Cairo     Application Support Engineer
# 4  3fee6f73  Alexandria  Electrical Maintenance Engineer
#
#                        job_category1   job_category2    job_category3  \
# 0  Sales/Retail/Business Development       Marketing           Select
# 1           Customer Service/Support  Administration  Human Resources
# 2            IT/Software Development          Select           Select
# 3            IT/Software Development          Select           Select
# 4                        Engineering          Select           Select
#
#                      job_industry1              job_industry2 job_industry3  \
# 0      Telecommunications Services                     Select        Select
# 1  Translation and Localization     Business Services - Other     Education
# 2                Computer Software                     Select        Select
# 3      Telecommunications Services                     Select        Select
# 4     Food and Beverage Production                     Select        Select
#
#    salary_minimum  salary_maximum  num_vacancies               career_level  \
# 0            2000            3500              8                Entry Level
# 1            1000            5000              8                Entry Level
# 2            2000            2500              1                Entry Level
# 3            2000            3500              1                Entry Level
# 4            5000            8000              1  Experienced (Non-Manager)
#
#   experience_years            post_date  views  \
# 0              0-1  2014-01-01 06:01:41   2602
# 1              0-2  2014-01-01 20:01:18   2213
# 2                2  2014-01-02 11:01:03   2940
# 3              1-2  2014-01-02 12:01:23   2042
# 4              1-3  2014-01-21 13:45:56   5684
#
#                                      job_description job_requirements  \
# 0  <p><strong>Qualifications</strong>:<br /><br /...              NaN
# 1  <p>&bull;Placing jobs' ads on various websites...              NaN
# 2  <span style="text-decoration: underline;"><str...              NaN
# 3  <strong><span style="text-decoration: underlin...              NaN
# 4  Job Title: Electrical Maintenance Engineer<br ...              NaN
#
#   payment_period        currency
# 0      Per Month  Egyptian Pound
# 1      Per Month  Egyptian Pound
# 2      Per Month  Egyptian Pound
# 3      Per Month  Egyptian Pound
# 4      Per Month  Egyptian Pound

# %%
np.shape(df_job)
# Out:
# (21850, 20)

# %% [markdown]
# ### Comment ..
# There are about 21850 applications for different jobs .. and about 20 columns ..
#
# Let's check the names of these columns ..

# %%
df_job.columns
# Out:
# Index([u'id', u'city', u'job_title', u'job_category1', u'job_category2',
#        u'job_category3', u'job_industry1', u'job_industry2', u'job_industry3',
#        u'salary_minimum', u'salary_maximum', u'num_vacancies', u'career_level',
#        u'experience_years', u'post_date', u'views', u'job_description',
#        u'job_requirements', u'payment_period', u'currency'],
#       dtype='object')

# %% [markdown]
# What is the data type of each variable ?!

# %%
df_job.columns.to_series().groupby(df_job.dtypes).groups
# Out:
# {dtype('int64'): Index([u'salary_minimum', u'salary_maximum', u'num_vacancies', u'views'], dtype='object'),
#  dtype('O'): Index([u'id', u'city', u'job_title', u'job_category1', u'job_category2',
#         u'job_category3', u'job_industry1', u'job_industry2', u'job_industry3',
#         u'career_level', u'experience_years', u'post_date', u'job_description',
#         u'job_requirements', u'payment_period', u'currency'],
#        dtype='object')}

# %% [markdown]
# ### Comment ..
# There are 4 integer variables .. and 16 categorical variables ..

# %% [markdown]
# Let's check if any of them is null !

# %%
df_job.isnull().any()
# Out:
# id                  False
# city                False
# job_title           False
# job_category1       False
# job_category2       False
# job_category3       False
# job_industry1       False
# job_industry2       False
# job_industry3       False
# salary_minimum      False
# salary_maximum      False
# num_vacancies       False
# career_level        False
# experience_years    False
# post_date           False
# views               False
# job_description      True
# job_requirements     True
# payment_period       True
# currency             True
# dtype: bool

# %% [markdown]
# ### Comment ..
# 4 variables contain null values ! .. let's count these values to check if they matter !

# %%
df_job.isnull().sum()
# Out:
# id                     0
# city                   0
# job_title              0
# job_category1          0
# job_category2          0
# job_category3          0
# job_industry1          0
# job_industry2          0
# job_industry3          0
# salary_minimum         0
# salary_maximum         0
# num_vacancies          0
# career_level           0
# experience_years       0
# post_date              0
# views                  0
# job_description      274
# job_requirements    2633
# payment_period         5
# currency               5
# dtype: int64

# %% [markdown]
# ### Comment ..
# both (payment_period) and (currency) have only 5 missing cells in each ..
#
# Followed by job_description that contains 274 missing cells ..
#
# However, (job_requirements) contains 2633 missing value of of 21850 .. which is a little bit huge number !

# %%
## heatmap
corr = df_job.corr()
sns.heatmap(corr, xticklabels=corr.columns.values, yticklabels=corr.columns.values)

# %%
np.corrcoef([df_job.salary_minimum, df_job.salary_maximum, df_job.num_vacancies, df_job.views])
# Out:
# array([[  1.00000000e+00,   6.36124766e-01,  -5.02982450e-02,
#          -7.29620187e-04],
#        [  6.36124766e-01,   1.00000000e+00,  -4.81621058e-02,
#          -1.22877948e-03],
#        [ -5.02982450e-02,  -4.81621058e-02,   1.00000000e+00,
#           7.68507898e-02],
#        [ -7.29620187e-04,  -1.22877948e-03,   7.68507898e-02,
#           1.00000000e+00]])

# %% [markdown]
# ## Comment ..
# From the heatmap and correlation results above .. the following can be concluded ..
#
# 1. There is some how strong linear relationship between minimum salary and maximum salary for the applicants ..
# 2. The correlation between minimum salary and both number of vacancies and jobs views is very weak !
# 3. The correlation is a bit higher in case of maximum salary .. yet it is a weak correlation ..

# %%
df_job.describe()
# Out:
#        salary_minimum  salary_maximum  num_vacancies         views
# count    21850.000000    21850.000000   21850.000000  21850.000000
# mean      3333.283982     5476.040412       5.856934   1376.874737
# std       5293.894787    10783.029504      16.633904   1065.109847
# min          0.000000        0.000000       1.000000      0.000000
# 25%       1500.000000     2500.000000       1.000000    797.000000
# 50%       2500.000000     4000.000000       1.000000   1230.000000
# 75%       3500.000000     6000.000000       3.000000   1791.000000
# max     250000.000000  1000000.000000     100.000000  37568.000000

# %% [markdown]
# ### Univariate Analysis:
#
# Let's analyze each variable graphically ..

# %%
# Job Category1

plt.figure(figsize=(16,16))
plt.subplot(311)
sns.countplot(x = "job_category1", data = df_job, order = df_job.job_category1.value_counts().iloc[:].index)
plt.xticks(rotation=90)
plt.ylabel('Count', fontsize=12)
plt.xlabel('job_category1', fontsize=12)
plt.title("Frequency of Job Categories Count in Members Data Set", fontsize=12)
# Out:
# Text(0.5,1,u'Frequency of Job Categories Count in Members Data Set')

# %%
job_cat = Counter(df_job['job_category1']).most_common()
job_cat
# Out:
# [('IT/Software Development', 5762),
#  ('Engineering', 3405),
#  ('Customer Service/Support', 2917),
#  ('Marketing', 2590),
#  ('Sales/Retail/Business Development', 1998),
#  ('Creative/Design', 1712),
#  ('Quality Assurance/Quality Control', 474),
#  ('Administration', 459),
#  ('Editorial/Writing', 458),
#  ('Installation/Maintenance/Repair', 287),
#  ('Project/Program Management', 268),
#  ('Education/Training', 224),
#  ('Manufacturing/Production/Operations', 184),
#  ('Medical', 131),
#  ('Media/Journalism/Publishing', 112),
#  ('Pharmaceutical', 107),
#  ('Biotech/R&D/Science', 106),
#  ('Tourism/Travel', 89),
#  ('Research', 85),
#  ('Logistics/Transportation', 74),
#  ('Building Construction/Skilled Trades', 71),
#  ('Management', 70),
#  ('Business ', 62),
#  ('Accounting/Finance/Insurance', 56),
#  ('Food Services/Hospitality', 53),
#  ('Banking', 42),
#  ('Human Resources', 28),
#  ('Fashion', 11),
#  ('Sports and Leisure', 11),
#  ('Legal', 4)]

# %% [markdown]
# the most frequent job category within the 1st set of categories is "IT/Software Development" that appears 5762 times ..
#
# the least term is "Legal" that appears only 4 times ..

# %%
# job_category2

plt.figure(figsize=(16,16))
plt.subplot(311)
sns.countplot(x = "job_category2", data = df_job, order = df_job.job_category2.value_counts().iloc[:].index)
plt.xticks(rotation=90)
plt.ylabel('Count', fontsize=12)
plt.xlabel('job_category2', fontsize=12)
plt.title("Frequency of job Titles Count in Members Data Set", fontsize=12)
# Out:
# Text(0.5,1,u'Frequency of job Titles Count in Members Data Set')

# %%
job_cat = Counter(df_job['job_category2']).most_common()
job_cat
# Out:
# [('Select', 10259),
#  ('Engineering', 1716),
#  ('Sales/Retail/Business Development', 1351),
#  ('Customer Service/Support', 1330),
#  ('IT/Software Development', 1077),
#  ('Marketing', 926),
#  ('Installation/Maintenance/Repair', 904),
#  ('Creative/Design', 702),
#  ('Quality Assurance/Quality Control', 481),
#  ('Project/Program Management', 399),
#  ('Media/Journalism/Publishing', 385),
#  ('Administration', 283),
#  ('Building Construction/Skilled Trades', 216),
#  ('Manufacturing/Production/Operations', 211),
#  ('Medical', 211),
#  ('Biotech/R&D/Science', 211),
#  ('Editorial/Writing', 179),
#  ('Business ', 138),
#  ('Management', 129),
#  ('Research', 127),
#  ('Pharmaceutical', 110),
#  ('Logistics/Transportation', 107),
#  ('Education/Training', 100),
#  ('Accounting/Finance/Insurance', 76),
#  ('Tourism/Travel', 63),
#  ('Banking', 53),
#  ('Food Services/Hospitality', 52),
#  ('Sports and Leisure', 17),
#  ('Human Resources', 16),
#  ('Fashion', 14),
#  ('Legal', 7)]

# %% [markdown]
# The job category of "Select" appears the most in the dataset of 10259.. followed by "Engineering" that appears 1716 times
# and the least number of jobs categories goes to "Legal"

# %%
# job category3

plt.figure(figsize=(16,16))
plt.subplot(311)
sns.countplot(x = "job_category3", data = df_job, order = df_job.job_category3.value_counts().iloc[:].index)
plt.xticks(rotation=90)
plt.ylabel('Count', fontsize=12)
plt.xlabel('job_category3', fontsize=12)
plt.title("Frequency of Job Categories Count in Members Data Set", fontsize=12)
# Out:
# Text(0.5,1,u'Frequency of Job Categories Count in Members Data Set')

# %%
job_cat = Counter(df_job['job_category3']).most_common()
job_cat
# Out:
# [('Select', 18788),
#  ('Engineering', 356),
#  ('Customer Service/Support', 313),
#  ('Marketing', 255),
#  ('Sales/Retail/Business Development', 244),
#  ('IT/Software Development', 203),
#  ('Biotech/R&D/Science', 197),
#  ('Installation/Maintenance/Repair', 191),
#  ('Quality Assurance/Quality Control', 139),
#  ('Medical', 137),
#  ('Project/Program Management', 133),
#  ('Creative/Design', 126),
#  ('Management', 90),
#  ('Media/Journalism/Publishing', 82),
#  ('Building Construction/Skilled Trades', 75),
#  ('Manufacturing/Production/Operations', 66),
#  ('Pharmaceutical', 64),
#  ('Research', 58),
#  ('Administration', 56),
#  ('Business ', 50),
#  ('Editorial/Writing', 48),
#  ('Logistics/Transportation', 30),
#  ('Accounting/Finance/Insurance', 28),
#  ('Education/Training', 27),
#  ('Food Services/Hospitality', 26),
#  ('Tourism/Travel', 22),
#  ('Human Resources', 16),
#  ('Fashion', 13),
#  ('Sports and Leisure', 10),
#  ('Legal', 4),
#  ('Banking', 3)]

# %% [markdown]
# Wow ! ..
#
# The job category of "Select" appears in the 3rd category column more than within the 2nd category .. of 18788 times ..
#
# the least word is "Banking" that appears only 3 times .. compared to 53 times within the 2nd category and 42 within the 1st set of categories

# %%
# job_title

job_tit = Counter(df_job['job_title']).most_common()
job_tit
# Out:
# [('Graphic Designer', 363),
#  ('Call Center Agent', 204),
#  ('Social Media Specialist', 178),
#  ('Sales Engineer', 171),
#  ('Web Developer', 146),
#  ('Marketing Specialist', 130),
#  ('Customer Service Representative', 129),
#  ('Web Designer', 127),
#  ('PHP Developer', 127),
#  ('Customer Service Agent', 116),
#  ('Telesales Agent', 110),
#  ('Senior PHP Developer', 94),
#  ('Software Developer', 93),
#  ('Marketing Manager', 92),
#  ('Marketing Executive', 91),
#  ('Java Developer', 86),
#  ('iOS Developer', 79),
#  ('Digital Marketing Specialist', 77),
#  ('Graphic Designer ', 77),
#  ('Senior .Net Developer', 75),
#  ('Android Developer', 73),
#  ('Project Manager', 69),
#  ('Senior Java Developer', 69),
#  ('IT Specialist', 66),
#  ('Senior Software Developer', 63),
#  ('Sales Account Manager', 61),
#  ('.Net Developer', 60),
#  ('Interior Designer', 60),
#  ('Mechanical Engineer', 58),
#  ('Site Engineer', 56),
#  ('Architect', 55),
#  ('Project Coordinator', 53),
#  ('Senior Android Developer', 53),
#  ('E-Marketing Specialist', 51),
#  ('Account Manager', 51),
#  ('Customer Service Representative ', 49),
#  ('Senior iOS Developer', 48),
#  ('Technical Office Engineer', 46),
#  ('Telesales Representative', 46),
#  ('Electrical Engineer', 46),
#  ('Telesales Agent ', 46),
#  ('Senior Graphic Designer', 46),
#  ('Call Center Agent ', 45),
#  ('Senior Web Developer', 45),
#  ('Social Media Specialist ', 44),
#  ('Civil Engineer', 43),
#  ('Sales Engineer ', 39),
#  ('Account Executive', 39),
#  ('Receptionist', 38),
#  ('Maintenance Engineer', 37),
#  ('Technical Sales Engineer', 34),
#  ('Social Media Executive', 34),
#  ('Marketing Coordinator', 34),
#  ('UI Developer', 34),
#  ('Software Engineer', 33),
#  ('Software Tester', 32),
#  ('Marketing Specialist ', 32),
#  ('Customer Service Agent ', 31),
#  ('Senior Software Engineer', 31),
#  ('Production Engineer', 31),
#  ('Senior .NET Developer', 30),
#  ('Sales Representative', 29),
#  ('Translator', 28),
#  ('Web Designer ', 28),
#  ('Digital Marketing Specialist ', 28),
#  ('Business Analyst', 28),
#  ('Senior Web Designer', 28),
#  ('SEO Specialist', 28),
#  ('Customer Care Agent', 27),
#  ('Art Director', 27),
#  ('Telemarketing Agent', 27),
#  ('UI/UX Designer', 26),
#  ('Technical Writer', 26),
#  ('Junior Graphic Designer', 25),
#  ('Technical Support Specialist', 25),
#  ('Marketing Manager ', 24),
#  ('Maintenance Manager', 24),
#  ('PHP Developer ', 24),
#  ('Front End Developer', 24),
#  ('Sales Executive', 24),
#  ('Presales Engineer', 24),
#  ('Technical Support Engineer', 24),
#  ('Tour Operator', 24),
#  ('SW Quality Assurance Engineer/Tester', 24),
#  ('Planning Engineer', 24),
#  ('Marketing Executive ', 24),
#  ('Electrical Maintenance Engineer', 23),
#  ('Oracle Developer', 23),
#  ('Senior Software Tester', 23),
#  ('Technical Support Agent', 23),
#  ('IT Manager', 23),
#  ('Digital Marketing Executive', 23),
#  ('Enterprise Technical Support Engineer', 23),
#  ('Mobile Application Developer', 22),
#  ('Product Manager', 22),
#  ('Quality Assurance Specialist', 22),
#  ('System Administrator', 22),
#  ('Secretary', 22),
#  ('PHP Web Developer', 22),
#  ('System Engineer', 21),
#  ('Medical Representative', 20),
#  ('Junior Software Developer', 20),
#  ('.NET Developer', 20),
#  ('Senior Software Developer ', 20),
#  ('Architect ', 19),
#  ('Customer Support Agent', 19),
#  ('Web Developer ', 19),
#  ('Application Support Engineer', 19),
#  ('Customer Service Manager', 19),
#  ('E-marketing Specialist', 18),
#  ('Quality Control Engineer', 18),
#  ('WordPress Developer', 18),
#  ('Customer Service Agents ( UK Account ) ', 17),
#  ('Production Manager', 17),
#  ('Online Marketing Specialist', 17),
#  ('Junior PHP Developer', 17),
#  ('Senior Social Media Specialist', 17),
#  ('IOS Developer', 17),
#  ('Project Engineer', 17),
#  ('Mechanical Engineer ', 17),
#  ('Quality Control Specialist', 17),
#  ('Customer Care Agent ', 17),
#  ('Sales & Marketing Specialist', 16),
#  ('Digital Marketing Manager', 16),
#  ('Sales Manager', 16),
#  ('Brand Manager', 16),
#  ('Creative Graphic Designer', 16),
#  ('Software Developer ', 16),
#  ('Senior Java Developer ', 16),
#  ('Business Development Specialist', 16),
#  ('Production Engineer ', 16),
#  ('SharePoint Developer', 15),
#  ('Biomedical Engineer', 15),
#  ('Tele-Marketing Representative ', 15),
#  ('Marketing Coordinator ', 15),
#  ('Senior Translator', 15),
#  ('Branch Manager - Ladies Fitness Center', 15),
#  ('Call Center Representative', 15),
#  ('Mobile Developer', 15),
#  ('Executive Secretary', 14),
#  ('Software Quality Control Engineer', 14),
#  ('Front-End Developer', 14),
#  ('Sales Representative ', 14),
#  ('Sales Agent', 14),
#  ('Ticketing Agent', 14),
#  ('Telesales Executive', 14),
#  ('Network Administrator', 14),
#  ('Business Development Manager', 14),
#  ('Junior Java Developer', 14),
#  ('Technical Office Engineer ', 14),
#  ('Junior Architect', 14),
#  ('E-Marketing Specialist ', 14),
#  ('Junior .NET Developer', 13),
#  ('Senior Marketing Executive', 13),
#  ('Video Editor', 13),
#  ('Chemist', 13),
#  ('Customer Care Representative', 13),
#  ('Business Intelligence Engineer', 13),
#  ('Senior .Net Developer ', 13),
#  ('Senior Architect', 12),
#  ('Mechanical Sales Engineer', 12),
#  ('Telemarketing Agent ', 12),
#  ('Senior PHP Developer ', 12),
#  ('Quality Control Manager', 12),
#  ('Art Teacher', 12),
#  ('Project Manager ', 12),
#  ('Junior .Net Developer', 12),
#  ('System Administrator ', 12),
#  ('Senior Front-End Developer', 12),
#  ('Telesales', 12),
#  ('Social Media Manager', 12),
#  ('Graphic Designer - Alexandria', 12),
#  ('Senior SharePoint Developer', 12),
#  ('Operations Manager', 12),
#  ('Quality Assurance Engineer', 12),
#  ('Java Developer ', 12),
#  ('iOS Developer ', 11),
#  ('Maintenance Engineer ', 11),
#  ('Sales Executive ', 11),
#  ('Senior Marketing Specialist ', 11),
#  ('Call Center Advisor ( VF- UK )', 11),
#  ('Call Center Agent - Offshore', 11),
#  ('Call Center Advisor', 11),
#  ('Customer Service Agent - Banking', 11),
#  ('Sales & Customer Service Agent', 11),
#  ('Senior Sales Engineer', 11),
#  ('Customer Service Executive', 11),
#  ('International Call Center Agent', 11),
#  ('English Translator', 11),
#  ('Graphic & Web Designer', 11),
#  ('Junior Translator', 11),
#  ('2D Graphic Designer', 11),
#  ('Social Media Executive ', 11),
#  ('Call Center Advisor ( VF-UK )', 11),
#  ('Senior Marketing Specialist', 11),
#  ('Technical Sales Engineer ', 11),
#  ('Junior Software Engineer', 11),
#  ('Site Engineer ', 11),
#  ('Field Service Engineer', 10),
#  ('customer service', 10),
#  ('Android Developer ', 10),
#  ('Contact Center Representative', 10),
#  ('Translator ', 10),
#  ('Software Development Team Leader', 10),
#  ('Interior Designer ', 10),
#  ('Software Quality Assurance Engineer', 10),
#  ('Offshore Call Center Agent', 10),
#  ('Software Engineer ', 10),
#  ('Technical Support Agent ', 10),
#  ('sales', 10),
#  ('Editorial Assistant', 10),
#  ('Senior Digital Marketing Specialist', 10),
#  ('IT Project Manager', 10),
#  ('Quality Engineer', 10),
#  ('IT Specialist ', 10),
#  ('German Account Advisor', 10),
#  ('International Account Advisor ', 10),
#  ('Technical Support Agent - Etisalat Emirates', 10),
#  ('Online Marketing Specialist ', 10),
#  ('Service Engineer', 10),
#  ('Architecture Engineer', 10),
#  ('IT Technical Support', 9),
#  ('Motion Graphic Designer', 9),
#  ('Customer Service Advisor (VIS)', 9),
#  ('Copywriter', 9),
#  ('Marketing Representative', 9),
#  ('Customer Service Agent - UK Account', 9),
#  ('Marketing Representative ', 9),
#  ('Senior Planning Engineer', 9),
#  ('Secretary ', 9),
#  ('Technical Support Engineer ', 9),
#  ('UI/UX Developer', 9),
#  ('Web Project Manager', 9),
#  ('Senior Interior Designer', 9),
#  ('Account Manager ', 9),
#  ('Technical Support', 9),
#  ('Python Developer', 9),
#  ('Full Stack Developer', 9),
#  ('SEO Specialist ', 9),
#  ('Sales & Marketing Executive', 9),
#  ('UI/UX Web Designer', 9),
#  ('Biomedical Sales Engineer', 9),
#  ('Senior UI Developer', 9),
#  ('Admin Assistant', 9),
#  ('Electrical Design Engineer', 9),
#  ('Mechanical Maintenance Engineer', 9),
#  ('Senior Technical Office Engineer', 9),
#  ('IT Sales Account Manager', 9),
#  ('Customer Care Officer', 9),
#  ('Senior Oracle Developer', 9),
#  ('3D Designer', 9),
#  ('Procurement Engineer', 9),
#  ('Public Relations Specialist', 9),
#  ('Receptionist ', 9),
#  ('Copy Editor', 9),
#  ('Business Analyst ', 8),
#  ('Senior PHP Web Developer', 8),
#  ('Customer Service Specialist ', 8),
#  ('Sales Coordinator', 8),
#  ('Sales Representative - Advertising', 8),
#  ('Service Advisor', 8),
#  ('Network Engineer ', 8),
#  ('Quality Manager', 8),
#  ('Graphics Designer', 8),
#  ('ASP.NET Developer', 8),
#  ('Project Coordinator ', 8),
#  ('Senior Android Developer ', 8),
#  ('Indoor Sales Executive', 8),
#  ('Java Software Developer', 8),
#  ('Market Researcher', 8),
#  ('Sales & Marketing Specialist ', 8),
#  ('Reviewers "Cairo or Alexandria "', 8),
#  ('Senior Mobile Application Developer', 8),
#  ('Engineer', 8),
#  ('IT Coordinator', 8),
#  ('Technical Office Manager', 8),
#  ('Junior Software Developer ', 8),
#  ('System Analyst', 8),
#  ('IT Engineer', 8),
#  ('Media Sales Consultant (Outdoor)', 8),
#  ('Business Development Executive', 8),
#  ('Customer Service Advisor', 8),
#  ('Software Quality Engineer ', 8),
#  ('Linux System Administrator', 8),
#  ('Telesales Representative ', 8),
#  ('Customer Service Agent - Alexandria', 7),
#  ('Senior Mechanical Engineer', 7),
#  ('Sales Account Manager ', 7),
#  ('Call Center Agent (International Bank)', 7),
#  ('SharePoint Developer ', 7),
#  ('Cost Control Engineer', 7),
#  ('Web Developer  (C#/ASP.NET) ', 7),
#  ('Document Controller', 7),
#  ('Web & Graphic Designer', 7),
#  ('Sales & Marketing Representative', 7),
#  ('Receptionist / Customer Care Agent', 7),
#  ('Senior Graphic Designer ', 7),
#  ('graphic designer', 7),
#  ('Senior Software QC Engineer', 7),
#  ('Quality Control Engineer ', 7),
#  ("Technical Software Engineer ''.Net''", 7),
#  ('Instructional Designer', 7),
#  ('.Net Software Developer', 7),
#  ('Customer Care Representative ', 7),
#  ('Lab Chemist', 7),
#  ('SharePoint Administrator', 7),
#  ('Senior Business Analyst', 7),
#  ('Design Engineer', 7),
#  ('Research & Development Specialist', 7),
#  ('Architect Engineer ', 7),
#  ('Office Manager', 7),
#  ('.Net Developer ', 7),
#  ('Content Manager', 7),
#  ('Account Manager - Advertising', 7),
#  ('Customer Care Executive', 7),
#  ('Chemical Engineer', 7),
#  ('Communication Engineer', 7),
#  ('Call Center Agent (Local Account)', 7),
#  ('Software Project Manager', 7),
#  ('Java Engineer', 7),
#  ('Senior Java Engineer', 7),
#  ('Microbiology Specialist', 7),
#  ('Software Test Engineer', 7),
#  ('Marketing Agent', 7),
#  ('Front End Web Developer', 7),
#  ('SW Quality Control Engineer', 7),
#  ('Junior Android Developer', 7),
#  ('JavaScript Software Developer', 7),
#  ('Customer Service Agent - Multinational Bank', 7),
#  ('Construction Manager', 7),
#  ('Architectural Engineer', 7),
#  ('Technical Sales Representative', 7),
#  ('Senior Electrical Engineer', 7),
#  ('Customer Service', 7),
#  ('IT Sales Engineer', 7),
#  ('Customer Service Executive - Multinational Bank', 7),
#  ('Customer Support Professional - English', 7),
#  ('Marketing Assistant', 7),
#  ('Electrical Sales Engineer', 7),
#  ('C++ Software Engineer - Medical Imaging', 7),
#  ('Data Analyst', 7),
#  ('Sales', 7),
#  ('Agricultural Engineer', 7),
#  ('Quality Control Analyst', 7),
#  ('Quantity Surveyor', 7),
#  ('Internet Call Center Representative ', 6),
#  ('Telecom Engineer', 6),
#  ('R&D Specialist ', 6),
#  ('Electrical Site Engineer', 6),
#  ('Mechanical Technical Office Engineer', 6),
#  ('Technical Office Architect', 6),
#  ('Database Administrator ', 6),
#  ('Event Manager', 6),
#  ('Facility Manager', 6),
#  ('Digital Graphic Designer', 6),
#  ('Digital & Social Media Specialist ', 6),
#  ('Senior Urban & Landscape Engineer', 6),
#  ('UI/UX Designer ', 6),
#  ('Spare Parts Specialist (Engineer)', 6),
#  ('Technical Office Civil Engineer', 6),
#  ('Content Writer', 6),
#  ('Quality Assurance Manager', 6),
#  ('Senior / Lead Java Web Developer', 6),
#  ('Marketing Specialist - Alexandria', 6),
#  ('Sales Account Executive ', 6),
#  ('Front Office Admin', 6),
#  ('Technical Support Representative', 6),
#  ('IT Sales Representative', 6),
#  ('IT Help Desk Specialist ', 6),
#  ('Quality Assurance Pharmacist', 6),
#  ('Electro-Mechanical Engineer', 6),
#  ('Developer Team Lead  (Mobile & Web )', 6),
#  ('Outbound Telemarketing Agent (Etisalat Emirates)', 6),
#  ('Mechanical Production Engineer', 6),
#  ('3D Graphic Designer ', 6),
#  ('Web Developer - PHP', 6),
#  ('Social Media Marketing Specialist', 6),
#  ('Senior SharePoint Developer ', 6),
#  ('Engineering Instructor ', 6),
#  ('Banking Applications Support Engineer ', 6),
#  ('Senior .NET Web Developer ', 6),
#  ('CRM Officer ', 6),
#  ('Branch Manager - Males Fitness Center', 6),
#  ('Social Media Specialist - Alexandria', 6),
#  ('Events Manager', 6),
#  ('Web UI Developer', 6),
#  ('Production & Quality Pharmacist', 6),
#  ('Junior Web Developer', 6),
#  ('Front-End Web Developer', 6),
#  ('Fleet Manager', 6),
#  ('Game Master', 6),
#  ('Java Technical Lead', 6),
#  ('Outgoing Tour Operator', 6),
#  ('Senior UI/UX Designer', 6),
#  ('Senior Software Engineer ', 6),
#  ('social media specialist', 6),
#  ('Junior Architect ', 6),
#  ('Architect & Interior Designer', 6),
#  ('Membership Coordinator', 6),
#  ('Public Relations Specialist ', 6),
#  ('Graphic Desiqner', 6),
#  ('Call Center Operator', 6),
#  ('Senior Linux Admin', 6),
#  ('IT Help Desk Clerk ', 6),
#  ('Writer Editor', 6),
#  ('Electrical Engineer ', 6),
#  ('HSE Engineer', 6),
#  ('Administrative Assistant', 6),
#  ('Junior Web Designer', 6),
#  ('Mathematics French Content Writer', 6),
#  ('Sales Specialist', 6),
#  ('Senior Enterprise Java Developer', 6),
#  ('Senior Software Quality Control Engineer', 6),
#  ('Online Marketing Executive', 6),
#  ('C++ Software Engineer (Medical Imaging)', 6),
#  ('Technical Office Engineer - Civil Engineering', 6),
#  ('IT Help Desk', 6),
#  ('Network Engineer', 6),
#  ('Mathematics English Content Writer', 6),
#  ('call center', 6),
#  ('Senior System Administrator', 6),
#  ('.Net Team Leader', 6),
#  ('Event Coordinator', 6),
#  ('Oracle ADF Developer', 6),
#  ('Senior Sales Account Manager', 6),
#  ('Gaming Referee', 6),
#  ('Software Process Improvement Analyst / Project Manager', 6),
#  ('Technical Office Electrical Engineer', 6),
#  ('UI Designer', 6),
#  ('Maintenance Engineer -Medical Devices ', 6),
#  ('Offshore Telesales Agent - Australian Account', 5),
#  ('R&D Specialist', 5),
#  ('Production Manager ', 5),
#  ('UI / UX Designer', 5),
#  ('Furniture Designer', 5),
#  ('Executive Engineer', 5),
#  ('Key Account Manager', 5),
#  ('Help Desk Engineer', 5),
#  ('Senior Web Developer ', 5),
#  ('Social Media Specialist - Females Only', 5),
#  ('Sales & Marketing Executive ', 5),
#  ('Media Sales Consultant ', 5),
#  ('Senior Translator (English<>Arabic)', 5),
#  ('Backend Developer', 5),
#  ('General Manager', 5),
#  ('Joomla and UI Web Designer', 5),
#  ('Customer Service Specialist', 5),
#  ('Senior UX Designer', 5),
#  ('Senior Project Manager', 5),
#  ('Creative Designer', 5),
#  ('SEO Manager', 5),
#  ('Business Analyst - IT', 5),
#  ('Marketing Officer', 5),
#  ('Marketing & Sales Executive ', 5),
#  ('Software Engineer (PHP)', 5),
#  ('PowerBuilder Developer', 5),
#  ('Technical Support Biomedical Engineer', 5),
#  ('Call Center Representative ', 5),
#  ('ADSL Technical Support Agents', 5),
#  ('Content Creator', 5),
#  ('Embedded Software Engineer', 5),
#  ('Research & Development Pharmacist ', 5),
#  ('Senior Mobile Developer', 5),
#  ('Planning Manager', 5),
#  ('Senior ASP.Net Developer - ERP', 5),
#  ('E-Marketing Supervisor', 5),
#  ('Electrical Power Engineer', 5),
#  ('Web / Graphic Designer ', 5),
#  ('Trade Marketing Manager', 5),
#  ('Architecture Engineer ', 5),
#  ('Digital Marketing Manager ', 5),
#  ('IT Supervisor', 5),
#  ('telesales', 5),
#  (' E-Marketing Specialist', 5),
#  ('Outdoor Sales Representative', 5),
#  ('Software Applications Support Engineer ', 5),
#  ('Marketing Supervisor', 5),
#  ('Civil Design Engineer', 5),
#  ('Technical Lead', 5),
#  ('Industrial Engineer', 5),
#  ('customer service agent', 5),
#  ('Outdoor Sales Agent', 5),
#  ('Senior Sharepoint Developer', 5),
#  ('Quality Assurance Specialist ', 5),
#  ("Technical Support Agent - Etisalat Int'l Account", 5),
#  ('Software Project Manager ', 5),
#  ('Technical Support Specialist ', 5),
#  ('SAP Project Manager', 5),
#  ('Sales Account Executive', 5),
#  ('Java EE Developer', 5),
#  ('JavaScript Developer', 5),
#  ('Sales Engineer - Alexandria', 5),
#  ('iOS Mobile Developer', 5),
#  ('Italian Call Center Agent', 5),
#  ('Fashion Designer', 5),
#  ('Planning Engineer ', 5),
#  ('Visual Merchandiser', 5),
#  ('Social Media Strategist', 5),
#  ('IT Help Desk Specialist', 5),
#  ('Customer Service Representative - German Offshore', 5),
#  ('Call Center Agent - Local Account', 5),
#  ('Contact Center Representative ', 5),
#  ('Civil Engineer ', 5),
#  ('Electrical Power Engineer ', 5),
#  ('Installation & Maintenance Security Systems Manager', 5),
#  ('HSE Engineer ', 5),
#  ('Back Office Implementer (Hotel Software Solution)', 5),
#  ('Medical Advisor', 5),
#  ('Motion Graphics Designer', 5),
#  ('PHPFox Developer', 5),
#  ('Oracle Database Administrator', 5),
#  ('SEO Expert', 5),
#  ('Social Media Moderator ', 5),
#  ('Sales & Marketing Manager', 5),
#  ('SEO Specialist (Search Engine Optimization)', 5),
#  ('Market Research Analyst ', 5),
#  ('Ruby on Rails Developer', 5),
#  ('Purchasing Manager', 5),
#  ('Junior Graphic Designer ', 5),
#  ('3D Graphic Designer', 5),
#  ('Senior Sales Engineer ', 5),
#  ('Software Product Manager', 5),
#  ('Software Testing Engineer', 5),
#  ('Mobile Application Developer ', 5),
#  ('Advertising Account Executive', 5),
#  ('Telesales Agent - Advertising', 5),
#  ('IT Administrator', 5),
#  ('Writer/ Editor', 5),
#  ('IT Technical Support Specialist', 5),
#  ('Data Entry Agent', 5),
#  ('Telesales Agent- Telecommunication Service', 5),
#  ('Executive Assistant', 5),
#  ('Photocopier Maintenance Engineer', 5),
#  ('Call Center Manager', 5),
#  ('Senior .Net Web Developer', 5),
#  ('Indoor Sales Representative', 5),
#  ('Civil Site Engineer', 5),
#  ('PHP Web Developer ', 4),
#  ('Tendering Manager', 4),
#  ('HVAC Engineer', 4),
#  ('Quality Controller', 4),
#  ('ios Developer', 4),
#  ('Call Center Agent - Local Account ', 4),
#  ('Product Specialist', 4),
#  ('Indoor Sales Executive - Retail', 4),
#  ('Marketing & Sales Engineer ', 4),
#  ('Network and System Administrator', 4),
#  ('Senior Software Quality Engineer', 4),
#  ('CSR - International Bank "Internship" ', 4),
#  ('Junior Sales Representative', 4),
#  ('Engagement Manager', 4),
#  ('Junior Java Developer ', 4),
#  ('Back-End Developer', 4),
#  ('Offshore Telesales Agent', 4),
#  ('Sales Account Manager - IT', 4),
#  ('Android Software Developer', 4),
#  ('Senior Front End Developer - Angular JS', 4),
#  ('Site Manager', 4),
#  ('Java Web Developer', 4),
#  ('ASP.Net Developer', 4),
#  ('Assistant Brand Manager', 4),
#  ('Senior Sales Engineer at EMFCO', 4),
#  ('Call Center/ Data Entry Agent', 4),
#  ('Marketing Consultant', 4),
#  ('Marketing And Sales Executive', 4),
#  ('IT Technical Support ', 4),
#  ('Outdoor Data Collector - Alexandria ', 4),
#  ('Operations Coordinator ', 4),
#  ('Magazine Sales Executive', 4),
#  ('Support Engineer', 4),
#  ('Operations Coordinator', 4),
#  ('Presales Engineer ', 4),
#  ('Senior Application Developer', 4),
#  ('IT Technical Support Agent', 4),
#  ('.NET Software Developer', 4),
#  ('Quality Assurance Section Head', 4),
#  ('Advertising Sales Executive', 4),
#  ('Marketing Manager - Alexandria', 4),
#  ('Junior .Net Developer ', 4),
#  ('Tendering Engineer', 4),
#  ('Customer Inquiry Advisor', 4),
#  ('Automation Control Engineer', 4),
#  ('Regulatory Affairs Specialist', 4),
#  ('Academic Professor- Faculty of Art and Design ', 4),
#  ('Telemarketing Representative', 4),
#  ('UI Developer ', 4),
#  ('Senior Software Quality Assurance Engineer', 4),
#  ('Data Entry Clerk', 4),
#  ('Senior Site Engineer', 4),
#  ('Customer Service Coordinator', 4),
#  ('Call Center Agent.', 4),
#  ('2D Graphic Designer ', 4),
#  ('sales engineer', 4),
#  ('Site Engineer - Civil Engineering', 4),
#  ('Software Quality Assurance Engineer ', 4),
#  ('AutoCAD Drafter', 4),
#  ('Pre-Sales Engineer ', 4),
#  ('Senior SoftwareTester', 4),
#  ('Customer Care Specialist', 4),
#  ('Mathematics Content Developer', 4),
#  ('Senior .NET Software Developer', 4),
#  ('Technical Writer ', 4),
#  ('Product Specialist (Assuit)', 4),
#  ('Technical Sales Engineer - IT', 4),
#  ('French Contact Center & Technical Support Representative', 4),
#  ('Graphic designer', 4),
#  ('Junior Electrical Engineer', 4),
#  ('Mechanical Engineer - Alexandria', 4),
#  ('Marketing & Business Development Executive', 4),
#  ('\xd9\x85\xd9\x88\xd8\xb8\xd9\x81\xd9\x8a\xd9\x86 \xd8\xae\xd8\xaf\xd9\x85\xd8\xa9 \xd8\xb9\xd9\x85\xd9\x84\xd8\xa7\xd8\xa1 - Call Center Agents (Mobily)',
#   4),
#  ('Software Development Engineer', 4),
#  ('Mechanical Design Engineer', 4),
#  ('French Speaker - Customer Service Agent', 4),
#  ('Advertising Account Manager', 4),
#  ('Senior Mathematics English Content Writer', 4),
#  ('Junior Web Developer ', 4),
#  ('Medical Services Coordinator - Preauthorization Team', 4),
#  ('.NET Team Lead', 4),
#  ('Store Manager', 4),
#  ('Advertising Manager', 4),
#  ('Senior IT Sales Account Manager', 4),
#  ('Marketing & Sales Manager', 4),
#  ('Pharmacist  ', 4),
#  ('EESH Engineer', 4),
#  ('Network Sales Engineer ', 4),
#  ('Projects Manager', 4),
#  ('Technician', 4),
#  ('Senior Software Engineer - Java', 4),
#  ('Photo Copier Maintenance Engineer', 4),
#  ('Technical Office Engineer - Alexandria', 4),
#  ('Mobile Test Engineer', 4),
#  ('Indoor Sales Engineer', 4),
#  ('HVAC Sales Engineering Support Manager', 4),
#  ('Fashion Brand Manager', 4),
#  ('Pre Sales Engineer', 4),
#  ('Senior Presales Engineer', 4),
#  ('Senior Software QC Specialist - Accounting Systems', 4),
#  ('Senior Marketing Executive ', 4),
#  ('Telesales Executive ', 4),
#  ('Software Engineering Manager', 4),
#  ('ERP Implementer', 4),
#  ('Indoor Sales Representative - Retail', 4),
#  ('3D Max Designer', 4),
#  ('Endoscopy Key Account Specialist', 4),
#  ('JS & CSS UI Developer', 4),
#  ('Medical Representative - Alexandria', 4),
#  ('Architect / Property Consultant', 4),
#  ('Customer Service Agent- Etisalat Emirates', 4),
#  ('call center agent', 4),
#  ('E-Marketing Executive', 4),
#  ('Customer Service Agent ( UK Account ) ', 4),
#  ('Senior Mobile & Web Developer ', 4),
#  ('Project Planning Engineer', 4),
#  ('IT Help Desk ', 4),
#  ('Mobile Application Designer', 4),
#  ('Quality Control Specialist  ', 4),
#  ('Senior Software Quality Specialist', 4),
#  ('Sales/Marketing Trainee', 4),
#  ('Senior iOS Mobile Application Developer', 4),
#  ('Medical Sales Representative', 4),
#  ('Senior Account Executive - Advertising', 4),
#  ('Senior .Net Software Engineer', 4),
#  ('Tour Operator ', 4),
#  ('Light Current Engineer', 4),
#  ('Market Research Analyst', 4),
#  ('Senior C++ Developer ', 4),
#  ('Oracle DBA Administrator', 4),
#  ('Software Technical Support Engineer ', 4),
#  ('GIS Developer', 4),
#  ('Technical Office Manager ', 4),
#  ('Project Sales Engineer', 4),
#  ('Graphic Designer  ', 4),
#  ('Customer Service Supervisor', 4),
#  ('Technical Coordinator', 4),
#  ('Safety Engineer', 4),
#  ('Academic Professor- Faculty of Engineering', 4),
#  ('Web Graphic Designer ', 4),
#  ('Accessibility Specialist', 4),
#  ('Marketing Director', 4),
#  ('Call Center Agent - USA Account', 4),
#  ('Android Mobile Developer', 4),
#  ('Graphics Designer ', 4),
#  ('Offshore Customer Care Representative', 4),
#  ('Technical Curriculum Developer', 4),
#  ('Senior Account Manager', 4),
#  ('Senior 3D Designer', 4),
#  ('Lifestyle Manager', 4),
#  ('Account Executive - Advertising', 4),
#  ('Senior IOS Developer', 4),
#  ('Marketing and Sales Manager', 4),
#  ('Senior Civil Design Engineer', 4),
#  ('Software Support Engineer', 4),
#  ('Customer Support Representative', 4),
#  ('Admin Assistant ', 4),
#  ('Customer Relation Coordinator', 4),
#  ('Electrician', 4),
#  ('Call Center Executive', 4),
#  ('ERP Sales Executive', 4),
#  ('Business Development Engineer', 4),
#  ('ERP Business Consultant', 4),
#  ('Electrical Technical Office Engineer', 4),
#  ('Sales Executive -  Software Solutions', 4),
#  ('Back-End Web Developer', 4),
#  ('Corporate Account Manager', 4),
#  ('Teaching Assistant - Art & Design', 4),
#  ('Call Center Supervisor', 4),
#  ('Marketing & Sales Executive', 4),
#  ('Senior / Lead Java Engineer', 4),
#  ('Service Engineer ', 4),
#  ('Service Desk Agent ', 4),
#  ('Senior PHP Developer - Alexandria', 4),
#  ('Relationship Officer', 4),
#  ('Senior Software Tester ', 4),
#  ('Telemarketing Executive', 4),
#  ('CRM Specialist', 4),
#  ('Flash Designer', 4),
#  ('IT Trainee', 4),
#  ('Call Center Advisor ( VF- Ireland )', 4),
#  ('Installation & Maintenance Security Systems Engineer', 4),
#  ('Sales Account Executive - Advertising', 4),
#  ('Supply Chain Manager', 4),
#  ('Sales Engineer - Software', 4),
#  ('Web Graphic Designer', 4),
#  ('Architecture', 4),
#  ('Marketing Internship - Chandigarh, India', 4),
#  ('IT Specialist - Alexandria', 4),
#  ('Illustrator', 4),
#  ('Mobile Applications Developer', 4),
#  ('Call Center Agent (Etisalat)', 4),
#  ('Technical Engineer', 4),
#  ('Senior Mathematics French Content Writer', 4),
#  ('Web / Graphic Designer', 4),
#  ('Senior .NET Web Developer', 4),
#  ('SQL Database Administrator ', 4),
#  ('Safety Officer', 4),
#  ('Production Supervisor', 4),
#  ('Marketing Associate', 4),
#  ('Content Management Specialist', 4),
#  ('Site Engineer (Architectural)', 4),
#  ('Mechanical Technician', 4),
#  ('QC Engineer', 4),
#  ('Call Center', 4),
#  ('Junior Python Developer - Alexandria', 4),
#  ('Electrical Sales Engineer ', 4),
#  ('Localization Project  Manager ', 4),
#  ('UX Designer', 4),
#  ('Ruby on Rails Software Developer', 4),
#  ('Document Control & Regulatory Compliance Specialist', 3),
#  ('Telesales Agent- IT Industry ', 3),
#  ('Mechanical Studies Engineer ', 3),
#  ('Technical Support  Agent', 3),
#  ('Game Characters Modeller', 3),
#  ('Sales Engineer- Lighting ', 3),
#  ('Product Specialist  (Alex Office)', 3),
#  ('Sales Engineer - Industrial Projects ', 3),
#  ('Customer Service Agent - Ireland Account', 3),
#  ('E-Marketing / SEO Specialist', 3),
#  ('Sales Executive - IT', 3),
#  ('Java Backend Developer', 3),
#  ('Technical Manager', 3),
#  ('Installation Engineer', 3),
#  ('R&D Stability Chemist ', 3),
#  ('Java Enterprise Developer', 3),
#  ('Local Search Team Specialist ', 3),
#  ('Laboratory Chemist  ', 3),
#  ('Senior Pre Sales Consultant  ', 3),
#  ('Architectural Design Engineer ', 3),
#  ('ERP Consultant', 3),
#  ('HR Recruitment Specialist ', 3),
#  ('Central Air Conditioner Sales Engineer', 3),
#  ('Export Coordinator', 3),
#  ('Artificial Intelligence (AI & NLP) Specialist ', 3),
#  ('Technical Support Agent (Sinai Based)', 3),
#  ('Operation Coordinator', 3),
#  ('Sales and Marketing Executive', 3),
#  ('Software Quality Engineer', 3),
#  ('Corporate Sales Specialist', 3),
#  ('Customer Service / Technical Support Representative', 3),
#  ('Web developer', 3),
#  ('Marketing Account Executive', 3),
#  ('Project Engineer ', 3),
#  ('IT Support Specialist', 3),
#  ('Customer Service Agent.', 3),
#  ('Customer Service Agents', 3),
#  ('Call Center & Operations Agent ', 3),
#  ('Drupal Back-End Developer', 3),
#  ('Sales Agriculture Engineer', 3),
#  ('Operations Agent', 3),
#  ('Sales /Technical Support Engineer', 3),
#  ('Marketing Officer ', 3),
#  ('Category Brand Manager - Candies ', 3),
#  ('Mechanical Power Engineer', 3),
#  ('Senior ASP.NET Developer', 3),
#  ('Customer Service Agent  (French Speakers)', 3),
#  ('Merchandiser ', 3),
#  ('Operations Engineer', 3),
#  ('Senior Mechanical Engineer ', 3),
#  ('Technical Office Architecture Engineer', 3),
#  ('ios Developer ', 3),
#  ('Front Desk Customer Service Representative ', 3),
#  ('Site Engineer / Architect', 3),
#  ('Business Development & Sales Specialist', 3),
#  ('After Sales Manager', 3),
#  ('Telesales Agent- Credit Services ', 3),
#  ('Senior SharePoint Software Developer ', 3),
#  ('HSE Officer', 3),
#  ('Senior WordPress Developer', 3),
#  ('Senior ERP Application Consultant', 3),
#  ('Medical Representative ', 3),
#  ('Senior BI Developer', 3),
#  ('Customer Service Representative - Russian ', 3),
#  ('Computer Teacher', 3),
#  ('Quality Assurance & Quality Control Engineer', 3),
#  ('IT Sales Engineer ', 3),
#  ('Software Quality Assurance (SQA) Engineer', 3),
#  ('Customer Services Officer', 3),
#  ('Offshore Call Center Advisor', 3),
#  ('Telemarketing Executive ', 3),
#  ('Web Customer Service Agent', 3),
#  ('Senior PHP Developer (Ruby on Rails)', 3),
#  ('Concept Artist', 3),
#  ('Senior German Translator', 3),
#  ('Sr. Graphic Designer', 3),
#  ('Telesales Agent - Alexandria', 3),
#  ('Operation Manager - Education ', 3),
#  ('Video Editor ', 3),
#  ('Teaching Assistant - Faculty of Engineering ', 3),
#  ('Sales Engineer - Biomedical', 3),
#  ('Service Evaluator', 3),
#  ('C# Engineer', 3),
#  ('Software Engineer (Ruby on Rails)', 3),
#  ('Sharepoint Senior Developer/Architect ', 3),
#  ('Outdoor Marketing Specialist- Alexandria & Beheira', 3),
#  ('Business Coordinator', 3),
#  ('E-Marketing Officer ', 3),
#  ('Sales Engineer - Oil & Gas', 3),
#  ('SQL Database Administrator', 3),
#  ('Database & Report Developer / Analyst', 3),
#  ('Software Quality Assurance Manager', 3),
#  ('IT Assistant', 3),
#  ('PR Executive', 3),
#  ('Visual Merchandiser - VM', 3),
#  ('Social Media Strategist ', 3),
#  ('Mobile App Developer', 3),
#  ('Customer Service Representatives ', 3),
#  ('Engineers', 3),
#  ('Fitness Trainer', 3),
#  ('Electro Design Engineer', 3),
#  ('Junior Process Engineer', 3),
#  ('Localization Vendor Manager ', 3),
#  ('Senior Telesales Agent', 3),
#  ('IT Support Engineer', 3),
#  ('Sales Real Estate ', 3),
#  ('Junior Front End Developer ', 3),
#  ('Content Specialist', 3),
#  ('Senior Software Developer (.NET)', 3),
#  ('Indoor Sales Engineer ', 3),
#  ('Senior Account Executive / Marketing', 3),
#  ('Senior Angular JS Developer ', 3),
#  ('Senior Web/UI Designer', 3),
#  ('Marketing Supervisor - Alexandria', 3),
#  ('IT Technical Support Engineer ', 3),
#  ('\xd9\x81\xd9\x86\xd9\x8a \xd9\x85\xd9\x8a\xd9\x83\xd8\xa7\xd9\x86\xd9\x8a\xd9\x83\xd8\xa7 \xd8\xa8\xd8\xad\xd8\xb1\xd9\x8a\xd8\xa9',
#   3),
#  ('Customer Support Professional - Spanish', 3),
#  ('Mobile Maintenance Engineer', 3),
#  ('Solution Engineer', 3),
#  ('Outdoor News Editor', 3),
#  ('Security Systems Engineer', 3),
#  ('International Call Center Advisor', 3),
#  ('Usher', 3),
#  ('Insurance Sales Agent', 3),
#  ('SoftWare Developer', 3),
#  ('Product Specialist - Mansoura', 3),
#  ('Outdoor Marketing Specialist - Dakahlia', 3),
#  ('Chief Engineer', 3),
#  ('IT Help Desk Officer', 3),
#  ('Call Center Agent - Alexandria', 3),
#  ('Structural Engineer', 3),
#  ('Product Manager - Pharmaceutical', 3),
#  ('Big Data Analyst ', 3),
#  ('Indoor Sales Representative ', 3),
#  ('Senior Python / Django Developer', 3),
#  ('German Account Advisor ', 3),
#  ('Electric Engineer ', 3),
#  ('ERP Systems Implementer', 3),
#  ('Chemical Engineer ', 3),
#  ('Junior Quality Assurance Engineer', 3),
#  ('IT Presales Engineer ', 3),
#  ('Procurement Engineer ', 3),
#  ('Medical Call Center Representative', 3),
#  ('Program Manager', 3),
#  ('Quality Engineer ', 3),
#  ('Application Support Supervisor (IT Supervisor)', 3),
#  ('Sales Executive - Advertising', 3),
#  ('Web Designer / Developer', 3),
#  ('Mechanical Maintenance Engineer ', 3),
#  ('Construction Engineer', 3),
#  ('Mechanical Engineer - Construction', 3),
#  ('Data Entry Specialist ', 3),
#  ('Executive Secretary ', 3),
#  ('Creative Director', 3),
#  ('IT Technical Support Officer', 3),
#  ('\xd9\x85\xd8\xaf\xd9\x8a\xd8\xb1 \xd8\xaa\xd8\xb3\xd9\x88\xd9\x8a\xd9\x82',
#   3),
#  ('.Net Developer at Estabena', 3),
#  ('System Analyst ', 3),
#  ('HSE Supervisor', 3),
#  ('Call center agent', 3),
#  ('Survey Engineer', 3),
#  ('Telemarketing Specialist', 3),
#  ('Senior Structure Engineer ', 3),
#  ('Play Animator', 3),
#  ('Software Technical Support Engineer', 3),
#  ('Software Project Coordinator', 3),
#  ('Sales & Marketing Executive - Freight Forwarding', 3),
#  ('Software Tester ', 3),
#  ('Dynamics AX Application Consultant', 3),
#  ('3D Max Designer ', 3),
#  ('Senior Quality Assurance Engineer', 3),
#  ('Social Media ', 3),
#  ('Java Web Developer ', 3),
#  ('3D Designer ', 3),
#  ('International Customer Service Representative - German', 3),
#  ('Telemarketing Specialist ', 3),
#  ('Senior PHP Developer / Team Leader', 3),
#  ('Technical Support Representative - English', 3),
#  ('Technical Maintenance Engineer', 3),
#  ('Photographer', 3),
#  ('Telecom Site Engineer', 3),
#  ('International Customer Service Representative ', 3),
#  ('Graphic / Web Designer ', 3),
#  ('Site Manager - Electromechanical Maintenance', 3),
#  ('Lubricant Sales Engineer', 3),
#  ('Creative Web Designer', 3),
#  ('Web Content Editor', 3),
#  ('Furniture Showroom Manager', 3),
#  ('Sales and Marketing Representative', 3),
#  ('Marketing Engineer', 3),
#  ('Freelance Web Designer', 3),
#  ('IT Help Desk Clerk', 3),
#  ('Customer Service Agents (UK Account) ', 3),
#  ('IT Application Support Engineer', 3),
#  ('Textile Printing Engineer', 3),
#  ('Pharmaceutical Call Center Agent', 3),
#  ('Graphic & Social Media Designer', 3),
#  ('Sales Executive -  Medical Equipment', 3),
#  ('Account Executive - Advertising ', 3),
#  ('Web Designer - WordPress', 3),
#  ('Training and Application Specialist ', 3),
#  ('\xd9\x85\xd9\x86\xd8\xaf\xd9\x88\xd8\xa8 \xd9\x85\xd8\xb4\xd8\xaa\xd8\xb1\xd9\x8a\xd8\xa7\xd8\xaa',
#   3),
#  ('Outdoor Lighting Technical & Design Engineer  ', 3),
#  ('3D Animator', 3),
#  ('Writer (English)', 3),
#  ('Quality Assurance Supervisor', 3),
#  ('Medical Manager - Alexandria', 3),
#  ('Telemarketing Agent - \xd9\x85\xd9\x88\xd8\xb8\xd9\x81 \xd9\x85\xd8\xa8\xd9\x8a\xd8\xb9\xd8\xa7\xd8\xaa \xd8\xb9\xd8\xa8\xd8\xb1 \xd8\xa7\xd9\x84\xd9\x87\xd8\xa7\xd8\xaa\xd9\x81',
#   3),
#  ('Senior Back-End Web Developer', 3),
#  ('UX/UI Designer', 3),
#  ('Commercial Sales Representative', 3),
#  ('Social Media & PR Executive', 3),
#  ('Call Center / Data Entry Agent', 3),
#  ('Mechatronics Engineer', 3),
#  ('Sales Account Executive -Marketing ', 3),
#  ('Google Adwords- Digital Marketing Strategist ', 3),
#  ('Validation Specialist - Menoufia ', 3),
#  ('R&D Electrical Power Engineer', 3),
#  ('Technical Office Engineer/Architect', 3),
#  ('Oracle Supply Chain Consultant', 3),
#  ('Market Research Account Manager', 3),
#  ('Senior Structural Engineer', 3),
#  ('User Interface (UI) Designer', 3),
#  ('QC Engineer - IT ', 3),
#  ('Account Executive ', 3),
#  ('Sales Agent "ERP Systems" ', 3),
#  ('Tracing Advisor', 3),
#  ('Call center Agent', 3),
#  ('Mobile Developer (iOS/Android)', 3),
#  ('International Account Advisor', 3),
#  ('Merchandiser', 3),
#  ('PHP Team Leader', 3),
#  ('Sales Mechanical Engineer ', 3),
#  ('Sales Engineer - Light Current', 3),
#  ('PHP / UI Software Developer', 3),
#  ('Quality Assurance/Quality Control Engineer', 3),
#  ('Project Manager - Architecture  ', 3),
#  ('Senior Web Designer / Senior UI Developer', 3),
#  ('Call Center Agent (VDA)', 3),
#  ('Engineering Manager', 3),
#  ('B2B Telesales / Marketing Executive', 3),
#  ('PLC Programming Engineer', 3),
#  ('Mobile Application Tester', 3),
#  ('Production Engineer - Alexandria', 3),
#  ('Product Manager - Pharmaceutical (Alexandria)', 3),
#  ('Customer Service Rep. International Bank "Internship" ', 3),
#  ('Application Support Engineer ', 3),
#  ('Telesales Agent - Telecommunications ', 3),
#  ('2D/3D Graphic Designer', 3),
#  ('Customer Support Professional - Turkish', 3),
#  ('Telesales Representative -Telecommunication Services', 3),
#  ('agent', 3),
#  ('Mechanical / Electrical Engineer', 3),
#  ...]

# %% [markdown]
# The most frequent job title in this data set is "Graphic Designer" that appears 363 while the least is "Mechanical / Electrical Engineer" that appears only 3 times ..

# %%
# city

job_city = Counter(df_job['city']).most_common()
job_city
# Out:
# [('Cairo', 14988),
#  ('Giza', 3886),
#  ('Alexandria', 989),
#  ('6th of October', 90),
#  ('Mansoura', 89),
#  ('New Cairo', 85),
#  ('10th of Ramadan', 81),
#  ('Any', 60),
#  ('Giza / Cairo', 45),
#  ('Ismailia', 39),
#  ('10th of ramadan city', 36),
#  ('Cairo / Giza', 36),
#  ('6th of October City', 35),
#  ('Tanta', 32),
#  ('nasr city', 32),
#  ('menoufia', 31),
#  ('6 October', 30),
#  ('\xd8\xa7\xd9\x84\xd9\x82\xd8\xa7\xd9\x87\xd8\xb1\xd8\xa9', 29),
#  ('10th of Ramdan City', 26),
#  ('Suez', 26),
#  ('6 of October', 24),
#  ('Hurghada', 22),
#  ('Assuit', 20),
#  ('Obour city', 20),
#  ('maadi', 20),
#  ('all', 19),
#  ('Nasr City, Cairo', 19),
#  ('cairo, giza', 19),
#  ('Ismalia', 18),
#  ('Cairo/ Giza', 16),
#  ('Egypt', 14),
#  ('Alexandria & Cairo', 13),
#  ('alex', 12),
#  ('Port Said', 12),
#  ('Cairo & alexandria', 12),
#  ('Cairo - Giza', 12),
#  ('6th october', 12),
#  ('Qalyubia', 12),
#  ('ASWAN', 12),
#  ('All over Egypt', 11),
#  ('red sea', 11),
#  ('\xd8\xa7\xd9\x84\xd8\xac\xd9\x8a\xd8\xb2\xd8\xa9', 11),
#  ('Upper Egypt', 10),
#  ('Cairo/Giza', 10),
#  ('Giza/Cairo', 10),
#  ('Sharkia', 10),
#  ('Mohandessin', 10),
#  ('Cairo & Giza', 10),
#  ('Dakahlia', 9),
#  ('Alexandria/ Cairo', 9),
#  ('Cairo, Alexandria', 9),
#  ('cario', 8),
#  ('Alexandria / Cairo', 8),
#  ('Asyut', 8),
#  ('Ciro', 8),
#  ('Sharm El Sheikh', 8),
#  ('Giza, Cairo', 7),
#  ('Al Sharqia', 7),
#  ('kafr el sheikh', 7),
#  ('All Governorates', 7),
#  ('Remote', 7),
#  ('Cairo - Alexandria', 7),
#  ('Heliopolis', 7),
#  ('alexanderia', 7),
#  ('Damietta', 7),
#  ('El Obour', 6),
#  ('Delta', 6),
#  ('Assiut', 6),
#  ('Sohag', 6),
#  ('Minya', 5),
#  ('Cairo / Alexandria', 5),
#  ('Cairo/ Alexandria', 5),
#  ('Heliopolis, Cairo', 5),
#  ('el mansoura', 5),
#  ('Minia', 5),
#  ('Mohandeseen', 5),
#  ('Gharbia', 5),
#  ('monufia', 5),
#  ('sharqia', 5),
#  ('portsaid', 5),
#  ('\xd8\xa7\xd9\x84\xd9\x82\xd8\xa7\xd9\x87\xd8\xb1\xd9\x87', 5),
#  ('October', 4),
#  ('El sharkia, El behira, El Menoufia, El Qalyubiyah, El canal, El faioum El giza,Minya, Asyut, Bani suif and Qena',
#   4),
#  ('South sinai', 4),
#  ('monofeya', 4),
#  ('Zagazig', 4),
#  ('Dokki', 4),
#  ('Menoufya', 4),
#  ('Cairo - Alex. - Mansoura', 4),
#  ('Beni Suef', 4),
#  ('Qena', 4),
#  ('Helwan', 4),
#  ('alexandria/cairo', 4),
#  ('6 of october city', 4),
#  ('Cairo - Nasr City', 4),
#  ('EL Obour city', 4),
#  ('6 october city', 4),
#  ('All Around Egypt', 4),
#  ('Giza, Egypt', 4),
#  ('Alexandria / Beheira', 4),
#  ('obour', 4),
#  ('sadat city', 4),
#  ('fayoum', 4),
#  ('Giza & Cairo', 4),
#  ('Cairo/ Alexanderia', 3),
#  ('\xd9\x85\xd8\xaf\xd9\x8a\xd9\x86\xd8\xa9 6 \xd8\xa7\xd9\x83\xd8\xaa\xd9\x88\xd9\x8a\xd8\xb1',
#   3),
#  ('Ciaro', 3),
#  ('mounfia', 3),
#  ('Greater Cairo', 3),
#  ('October city', 3),
#  ('anywhere', 3),
#  ('Giza/ Alexandria', 3),
#  ('Maadi, Cairo', 3),
#  ('Giza - 6th of October', 3),
#  ('Qalyoubia', 3),
#  ('sheikh zayed', 3),
#  ('Remote (Work from Home)', 3),
#  ('Beheira', 3),
#  ('el gharbia', 3),
#  ('Bani Suef, Ismailia ,Mansoura and Cairo', 3),
#  ('Alexandria, Cairo', 3),
#  ('6th october city', 3),
#  ('Beni Suef, Ismailia and Mansoura', 3),
#  ('Giza/ Cairo', 3),
#  ('\xd8\xa7\xd9\x84\xd8\xa7\xd8\xb3\xd9\x83\xd9\x86\xd8\xaf\xd8\xb1\xd9\x8a\xd8\xa9',
#   3),
#  ('Marsa Alam', 3),
#  ('port said, Ismailia ,damitta,mansoura ,suez', 3),
#  ('Menofia', 3),
#  ('El Mohndseen', 3),
#  ('Giza, Alex', 2),
#  ('El-Sharkia & Dakahlia', 2),
#  ('Cairo - Alex', 2),
#  ('Ain El Sokhna', 2),
#  ('Cairo , Giza', 2),
#  ('Nasr City - Cairo', 2),
#  ('\xd8\xa7\xd9\x84\xd8\xac\xd9\x8a\xd8\xb2\xd9\x87', 2),
#  ('Alexandira', 2),
#  ('Greater Cairo - Mansoura', 2),
#  ('El Obour Industrial City', 2),
#  ('gizah', 2),
#  ('Cairo, Giza, Alexandria, Tanta, Assuit', 2),
#  ('Cairo, New cairo', 2),
#  ('Cairo/Alex', 2),
#  ('Cairo,Egypt', 2),
#  ('El-shrouk', 2),
#  ('Arish', 2),
#  ('Cairo/Alexandria', 2),
#  ('10 of Ramadan', 2),
#  ('Cairo,Giza', 2),
#  ('elgiza', 2),
#  ('\xd9\x85\xd8\xb5\xd8\xb1', 2),
#  ('Cairo, Giza & Alexandria', 2),
#  ('Owinat East', 2),
#  ('Giza, Zamalek', 2),
#  ('elobour', 2),
#  ('6 \xd8\xa7\xd9\x83\xd8\xaa\xd9\x88\xd8\xa8\xd8\xb1', 2),
#  ('Beni Suef & Ismailia', 2),
#  ('El mahalla el koubra', 2),
#  ('Work from home', 2),
#  ('10 th of ramadan', 2),
#  ('ain sokhna', 2),
#  ('Giza, Dokki', 2),
#  ('Cairo, Alexandria & Assiut', 2),
#  ('damitta', 2),
#  ('al ain al sokhna', 2),
#  ('Upper Egypt / Red Sea', 2),
#  ('\xd8\xa7\xd9\x84\xd8\xaa\xd8\xac\xd9\x85\xd8\xb9 \xd8\xa7\xd9\x84\xd8\xa3\xd9\x88\xd9\x84',
#   2),
#  ('Beni Suef, Ismailia ,Mansoura and Cairo.', 2),
#  ('Cairo - Damitte - Alex & suez', 2),
#  ('new valley', 2),
#  ('cairo-giza', 2),
#  ('alexendria', 2),
#  ('El-gharbia', 2),
#  ('All Egypt Governrotes', 2),
#  ('Cairo / Mansoura', 2),
#  ('Sharm el-Sheikh', 2),
#  ('East Owainat', 2),
#  ('luxor', 2),
#  ('sinai', 2),
#  ('All provenience', 2),
#  ('all Governments', 2),
#  ('Maddi', 2),
#  ('Caito', 2),
#  ('sharm el shaik', 1),
#  ('El Menia', 1),
#  ('Alexnadria', 1),
#  ('Al Jizah', 1),
#  ('East Owinat', 1),
#  ('Cairo, Helwan, El Sharkia', 1),
#  ('Down Town', 1),
#  ("Ma'adi", 1),
#  ('cairo/egypt', 1),
#  ('Riyadh, Saudi Arabia', 1),
#  ('\xd8\xa7\xd8\xa8\xd9\x87\xd8\xa7', 1),
#  ('siuz', 1),
#  ('Cairo,Giza,Alex,Mansoura,Tnata', 1),
#  ('cairo/ismailia', 1),
#  ('10th of Ramadan - New Cairo', 1),
#  ('Cairo , Canal and Upper Egypt governorates', 1),
#  ('\xd8\xa7\xd9\x84\xd9\x85\xd9\x86\xd8\xb5\xd9\x88\xd8\xb1\xd8\xa9', 1),
#  ('Cairo , Giza , Alex , Mansoura , Tanta', 1),
#  ('Cairo & Hurghada', 1),
#  ('Global', 1),
#  ('Online From Home', 1),
#  ('El Monofeya', 1),
#  ('Cairo - Maadi', 1),
#  ('10 0f Rnamda', 1),
#  ('Cairo, Alex, Delta, Upper, Egypt', 1),
#  ('Cairo , Alex', 1),
#  ('Qalyubia,Gharbia and Alexandria', 1),
#  ('Mania -Suez', 1),
#  ('sadat', 1),
#  ('\xd8\xa7\xd9\x84\xd9\x82\xd8\xa7\xd9\x87\xd8\xb1\xd8\xa9 \xd8\xa7\xd9\x84\xd9\x83\xd8\xa8\xd8\xb1\xd9\x89',
#   1),
#  ('Al Monofyah', 1),
#  ('Cairo / Ismalia', 1),
#  ('east oweinat', 1),
#  ('6th Of October, Giza', 1),
#  ('Giza - Delta - Cairo', 1),
#  ('Sadat Industrial City, Monufia Governorate, Egypt.', 1),
#  ('10th of Ramadan and Qibaa City', 1),
#  ('Ismailia and Mansoura', 1),
#  ('10th of Ramaddan', 1),
#  ('qualiobia', 1),
#  ('cairo - giza -alex', 1),
#  ('al city in egypt', 1),
#  ('Riyadh, KSA', 1),
#  ('Cairo/ 6th of October', 1),
#  ('manalonline', 1),
#  ('guiza', 1),
#  ('Shebin ElKoum', 1),
#  ('all egypt', 1),
#  ('Cairo, Alex, Assuit, Mansoura, Tanta', 1),
#  ('alabassia', 1),
#  ('Kafr El-Shekh', 1),
#  ('Cairo/Sokhna', 1),
#  ('Cairo / El-Minya', 1),
#  ('travel jeddah', 1),
#  ('Assuit-Menia-Mansoura-El Bhira-Sohag', 1),
#  ('Minya - Assiut - Sohag', 1),
#  ('Maadi, Damietta, Marsa Matrouh, El Sadat City', 1),
#  ('giza`', 1),
#  ('6 th of October city', 1),
#  ('giza mohandseen', 1),
#  ('Isamilia', 1),
#  ('Qaluobiya', 1),
#  ('all governement', 1),
#  ('Al- Gharbia', 1),
#  ('\xd8\xad\xd9\x84\xd9\x88\xd8\xa7\xd9\x86', 1),
#  ('6th. of october', 1),
#  ('Giza/ Cairo - Alexandria - Asyout', 1),
#  ('Doki', 1),
#  ('Cairo, Damietta, Suez, Assiut, Sharkeya, Kafr Sheikh, Hurghada', 1),
#  ('Alexandria or Cairo', 1),
#  ('Shiekh Zaied City', 1),
#  ('el monufia', 1),
#  ('Mansoura/Alexandria', 1),
#  ('Cairo / Alex / Mansoura', 1),
#  ('Shebin Al-Kom', 1),
#  ('Cairo - Giza - Alex. - Kafr El-sheikh.', 1),
#  ('all cities', 1),
#  ('Cairo, Alexandria & Upper Egypt', 1),
#  ('El Sheikh Zayed \xe2\x80\x93 6 October', 1),
#  ('Middle East', 1),
#  ('SHARJAH', 1),
#  ('Delta - Mansoura -Tanta', 1),
#  ('10th. of Ramadan', 1),
#  ('Alexandria - Bihera', 1),
#  ('Cairon', 1),
#  ('10th of ramdan', 1),
#  ('Manoura', 1),
#  ('Dubai', 1),
#  ('Alexandria , Cairo', 1),
#  ('Nasr City or Giza', 1),
#  ('Cairo, Mansoura, Tanta', 1),
#  ('Dakahliya & Cairo', 1),
#  ('zakazik', 1),
#  ('suez & Alexandria', 1),
#  ('Ismailia ,Mansoura', 1),
#  ('Sharm Elkheikh', 1),
#  ('shbin al koum', 1),
#  ('Sadat Industrial City, Monufia Governorate.', 1),
#  ('Damietta, Suez, Sharkeya, PortSaid', 1),
#  ('\xd9\x83\xd9\x81\xd8\xb1 \xd8\xa7\xd9\x84\xd8\xb4\xd9\x8a\xd8\xae', 1),
#  ('Any Location', 1),
#  ('cairo,', 1),
#  ('Tanta - Zagazig - Mansoura (Delta)', 1),
#  ('cairp', 1),
#  ('10 th of ramadan city', 1),
#  ('Abou Rawash', 1),
#  ('Matrouh & \xd9\x90Alexandaria', 1),
#  ('Ain Shams/ Helwan', 1),
#  ('Alexadnria', 1),
#  ('cairoo', 1),
#  ('\xd8\xa3\xd9\x83\xd8\xaa\xd9\x88\xd8\xa8\xd8\xb1', 1),
#  ('Cairo or Alexandria or any', 1),
#  ('EL-Mansora', 1),
#  ('Cairo, Alex, Tanta, Mansoura', 1),
#  ('El-Sherouk', 1),
#  ('caio', 1),
#  ('Alexandria, Cairo & Mineya', 1),
#  ('Giza-6 October', 1),
#  ('Banha', 1),
#  ('Obuor city', 1),
#  ('Port Saied', 1),
#  ('elharam', 1),
#  ('Alexandria - Canal zone - Upper Egypt', 1),
#  ('Cairo / Desok', 1),
#  ('Assuit - Cairo - Alex', 1),
#  ('Cairo/ New Cairo', 1),
#  ('Cairo /Qaluibya', 1),
#  ('Menofya', 1),
#  ('Canal Area', 1),
#  ('Beni Suef, Ismailia ,Mansoura and Cairo', 1),
#  ('Cairo /New Cairo', 1),
#  ('Cairo / Alexandria / Anywhere in Egypt', 1),
#  ('Cairo, Alex', 1),
#  ('Cairo & Aswan', 1),
#  ('\xd8\xa7\xd9\x84\xd9\x85\xd9\x86\xd8\xb5\xd9\x88\xd8\xb1\xd9\x87', 1),
#  ('Mansoura, DK', 1),
#  ('kairo', 1),
#  ('EL Sharkyia', 1),
#  ('Mansoura , Tanta , KFS , Damanhour , Zagazig , Damita, Banha & Fakos', 1),
#  ('Cairo/ Giza / Sheikh Zayed / New Cairo', 1),
#  ('Cairo,Assiut ,Mansoura', 1),
#  ('Ismallia- Port Said - Suez', 1),
#  ('Desok / Mansoura / Gharbia / Cairo', 1),
#  ('Cairo, Giza, Alex, Tanta, Assuit', 1),
#  ('Giza-Cairo', 1),
#  ('6 of Ocober', 1),
#  ('Ariesh', 1),
#  ('All Regions', 1),
#  ('cairo - ismailia', 1),
#  ('new egypt', 1),
#  ('Egype', 1),
#  ('al-minya', 1),
#  ('maadi,cairo', 1),
#  ('El-Menofya', 1),
#  ('Alex .Borg El Arab', 1),
#  ('15th of May', 1),
#  ('sharm elsheikh', 1),
#  ('Remotely from home', 1),
#  ('North Coast', 1),
#  ('El Menya', 1),
#  ('Cairo - Dokki', 1),
#  ('Dakahlia & Gharbia', 1),
#  ('\xd8\xa7\xd9\x84\xd8\xa5\xd8\xb3\xd9\x83\xd9\x86\xd8\xaf\xd8\xb1\xd9\x8a\xd8\xa9 -\xd8\xa7\xd9\x84\xd9\x82\xd8\xa7\xd9\x87\xd8\xb1\xd8\xa9 -\xd8\xa7\xd9\x84\xd8\xa5\xd8\xb3\xd9\x85\xd8\xa7\xd8\xb9\xd9\x8a\xd9\x84\xd9\x8a\xd8\xa9 -\xd8\xb4\xd9\x85\xd8\xa7\xd9\x84 \xd8\xa7\xd9\x84\xd8\xaa\xd8\xad\xd8\xb1\xd9\x8a\xd8\xb1',
#   1),
#  ('Marsa Matrouh', 1),
#  ('el minya', 1),
#  ('Cairo, Mansoura', 1),
#  ('Cairo, Alexanderia and Assuit', 1),
#  ('Between 10th of Ramadan and New Cairo', 1),
#  ('6 October - Mokkatam', 1),
#  ('2111111111111111111111111111111111110122222222222222Cairo / Kafr el shiehk / Mansoura',
#   1),
#  ('Wadi El Notron', 1),
#  ('newegypt', 1),
#  ('Cairo .Mansoura, Tanta, Bahira, Zagazig Benha , ismalia . Portsaid . suez .sharm elsheikh',
#   1),
#  ('6 oct', 1),
#  ('To be definied', 1),
#  ('6th Of Oct / Smart Village', 1),
#  ('Kafr El-sheikh', 1),
#  ('Beni Suif & Cairo', 1),
#  ('Al Ghrbiyah', 1),
#  ('Cairo - Abbassia', 1),
#  ('Mokattam', 1),
#  ('EL-MOHANDSEEN, GIZA', 1),
#  ('zamalek', 1),
#  ('Cairo, Egypt', 1),
#  ('Cairo / Gharbia', 1),
#  ('maady', 1),
#  ('Sharqeya', 1),
#  ('alexandaria', 1),
#  ('Cairo /Giza /Alexandria /Delta', 1),
#  ('Caro', 1),
#  ('CAIRO - EGYPT', 1),
#  ('Cairo / Suez / Assiut', 1),
#  ('Qaluibya', 1),
#  ('monufya sadat city', 1),
#  ('Ismallia', 1),
#  ('Badr', 1),
#  ('Al-behira', 1),
#  ('Cairo - New Cairo', 1),
#  ('Cairo / Fayoum / Assuit', 1),
#  ('Giza, Shabramant', 1),
#  ('Haram', 1),
#  ('Aswan/ Qena', 1),
#  ('North Cost', 1),
#  ('Csiro', 1),
#  ('gize', 1),
#  ('Owainat East', 1),
#  ('\xd8\xa7\xd9\x84\xd8\xa5\xd8\xb3\xd9\x85\xd8\xa7\xd8\xb9\xd9\x8a\xd9\x84\xd9\x8a\xd8\xa9',
#   1),
#  ('Sharqiya', 1),
#  ('Mohandiseen', 1),
#  ('cairro', 1),
#  ('Cairo / Aswan', 1),
#  ('Monfia', 1),
#  ('Alexandria And Cairo', 1),
#  ('nasir', 1),
#  ('Red Sea/ Sinai', 1),
#  ('kaliobya', 1),
#  ('El Menoufia', 1),
#  ('Cairo /Giza', 1),
#  ('El-Gharbya', 1),
#  ('\xd9\x85\xd8\xaf\xd9\x8a\xd9\x86\xd8\xa9 6 \xd8\xa7\xd9\x83\xd8\xaa\xd9\x88\xd8\xa8\xd8\xb1',
#   1),
#  ('outside cairo', 1),
#  ('Alex,Tanta,Mansoura,Cairo', 1),
#  ('Monoufia', 1),
#  ('Ain Shams', 1),
#  ('El Mahlla El Koubra', 1),
#  ('El-Obour', 1),
#  ('El Fayoum', 1),
#  ('Giza, Cairo, Mansoura, Fayoum & Banha', 1),
#  ('great cairo', 1),
#  ('Cairo , Alex Delta & Upper Egypt', 1),
#  ('\xd8\xa7\xd9\x84\xd9\x82\xd8\xa7\xd9\x87\xd8\xb1\xd8\xa9 - \xd8\xa7\xd9\x84\xd8\xa3\xd8\xb3\xd9\x83\xd9\x86\xd8\xaf\xd8\xb1\xd9\x8a\xd8\xa9',
#   1),
#  ('Cairo /Menoufia', 1),
#  ('alexandryia', 1),
#  ('new nozha', 1),
#  ('cairo and alex', 1),
#  ('\xd8\xa7\xd9\x84\xd8\xb1\xd9\x8a\xd8\xa7\xd8\xb6', 1),
#  ('cairo or giza', 1),
#  ('al fayoum', 1),
#  ('Cairo,Giza & Alexandria', 1),
#  ('Bani Suief', 1),
#  ('\xd8\xa7\xd9\x84\xd9\x82\xd8\xa7\xd9\x87\xd8\xb1\xd8\xa9 \xd8\xa7\xd9\x84\xd8\xac\xd8\xaf\xd9\x8a\xd8\xaf\xd8\xa9',
#   1),
#  ('october 6th', 1),
#  ('El-Behira', 1),
#  ('Cairo, Alex , Tanta , Mansoura', 1),
#  ('All Governorate', 1),
#  ('Damita', 1),
#  ('upper Egypt - Alex - Suez - Ismailia', 1),
#  ('Cairo-Nasr City', 1),
#  ('Cairo & El-Gharbia', 1),
#  ('\xd9\x85\xd8\xaf\xd9\x8a\xd9\x86\xd8\xa9 \xd8\xa8\xd8\xaf\xd8\xb1', 1),
#  ('Sheikh Zayed City', 1),
#  ('qina', 1),
#  ('October Industrial Zone', 1),
#  ('Al Behera', 1),
#  ('Giaz', 1),
#  ('Cairo, Alexandria, Asyut, Mansura, Tanta', 1),
#  ('Alexandria- Port Saeid- Ismalia -Assuit -Menia- Red Sea', 1),
#  ('El-Mansoura', 1),
#  ('Misr- El Gedida', 1),
#  ('\xd8\xa7\xd9\x84\xd8\xba\xd8\xb1\xd8\xaf\xd9\x82\xd8\xa9', 1),
#  ('\xd9\x90Alexandria', 1),
#  ('Cairo,Hurghada', 1),
#  ('Dokki - Mohandseen', 1),
#  ('El Monofia', 1),
#  ('Cairo egypt', 1),
#  ('Alexandria, Ain Sokhna, Hurghada', 1),
#  ('zahraa el maadi', 1),
#  ('Cairo/ Sharm/ Hurghada', 1),
#  ('\xd9\x85\xd9\x86 \xd8\xa7\xd9\x84\xd8\xaf\xd9\x82\xd9\x87\xd9\x84\xd9\x8a\xd9\x87 - \xd8\xa7\xd9\x88 \xd8\xa7\xd9\x84\xd9\x82\xd8\xa7\xd9\x87\xd8\xb1\xd8\xa9',
#   1),
#  ('Gharbeya', 1),
#  ('Hurghada / Cairo', 1),
#  ('Giza - Sheikh Zayed City', 1),
#  ('New Cairo City', 1),
#  ('Giza,Cairo ,Alex', 1),
#  ('6th Of Oct', 1),
#  ('Ein sokhna', 1),
#  ('EL Minia', 1),
#  ('Giza - Cairo', 1),
#  ('\xd9\x85\xd8\xaf\xd9\x8a\xd9\x86\xd9\x87 \xd9\x86\xd8\xb5\xd8\xb1', 1),
#  ('monofya', 1),
#  ('Cairo .Mansoura, Tanta, bahara, Zagazig Benha , ismalia . borsaid . suez .sharelsheikh',
#   1),
#  ('Elwadi Elgded', 1),
#  ('Giza & Tanta', 1),
#  ('Upper Egypt & Red Sea', 1),
#  ('Cairo,Port Said', 1),
#  ('Mansoura /Damietta', 1),
#  ('El-sharkia', 1),
#  ('Cairo & Alex', 1),
#  ('5th Settelment', 1),
#  ('Doha', 1),
#  ('Riyadh', 1),
#  ('Cairo / North coast', 1),
#  ('Alamein', 1),
#  ('Sharkeya', 1),
#  ('Tanta - Mounfia -Mansoura', 1)]

# %% [markdown]
# It seems there are typo in this column .. i.e. the field of (\xd9\x85\xd8\xaf\xd9\x8a\xd9\x86\xd9\x87 \xd9\x86\xd8\xb5\xd8\xb1) ! .. this is invalid city name !  ..
#
# Meanwhile, the most frequent city is Cairo .. that appears 14988 times within the data set, while both 'Tanta - Mounfia -Mansoura' appear only one time in the data ..

# %%
# job_industry1

plt.figure(figsize=(16,16))
plt.subplot(311)
sns.countplot(x = "job_industry1", data = df_job, order = df_job.job_industry1.value_counts().iloc[:].index)
plt.xticks(rotation=90)
plt.ylabel('Count', fontsize = 12)
plt.xlabel('job_industry1', fontsize = 9)
plt.title("Frequency of Job Indusrty Count in Members Data Set", fontsize=12)
# Out:
# Text(0.5,1,u'Frequency of Job Indusrty Count in Members Data Set')

# %% [markdown]
# wow ! ..
#
# It seems there are a lot of job industries within the data set ..

# %%
job_ind = Counter(df_job['job_industry1']).most_common()
job_ind
# Out:
# [('Computer Software', 2824),
#  ('Information Technology Services   ', 2029),
#  ('Advertising and PR Services', 1108),
#  ('Telecommunications Services', 1021),
#  ('Computer/IT Services', 976),
#  ('Marketing and Advertising   ', 795),
#  ('Consumer Services   ', 727),
#  ('Engineering Services', 692),
#  ('Education', 634),
#  ('Engineering - Mechanical or Industrial   ', 616),
#  ('Manufacturing', 535),
#  ('Architectural and Design Services', 510),
#  ('Real Estate/Property Management', 507),
#  ('Construction - Industrial Facilities and Infrastructure', 451),
#  ('Travel, Transportation and Tourism', 365),
#  ('Internet Services', 365),
#  ('Pharmaceuticals   ', 327),
#  ('Medical Devices and Supplies', 314),
#  ('Business Services - Other', 300),
#  ('Healthcare Services and Hospital', 299),
#  ('Construction - Residential & Commercial/Office', 269),
#  ('Retail', 266),
#  ('Printing and Publishing', 249),
#  ('Translation and Localization   ', 248),
#  ('Electronics, Components, and Semiconductor Mfg', 232),
#  ('Graphic Design   ', 229),
#  ('Outsourcing/Offshoring   ', 223),
#  ('Financial Services', 196),
#  ('Food and Beverage Production', 195),
#  ('Chemicals/Petro-Chemicals', 184),
#  ('Agriculture/Forestry/Fishing/Farming', 178),
#  ('FMCG', 167),
#  ('Automotive and Parts Manufacturing', 144),
#  ('Insurance', 143),
#  ('Banking', 139),
#  ('Media Production   ', 137),
#  ('Automotive Sales and Repair Services', 127),
#  ('Energy and Utilities', 124),
#  ('Online Media   ', 123),
#  ('Entertainment   ', 121),
#  ('Computer Networking   ', 116),
#  ('Human Resources   ', 114),
#  ('Logistics and Supply Chain   ', 112),
#  ('Market Research   ', 110),
#  ('Import and Export   ', 109),
#  ('Computer and Network Security   ', 105),
#  ('Furniture   ', 104),
#  ('Computer Hardware', 102),
#  ('Management Consulting Services', 99),
#  ('Health, Wellness and Fitness   ', 95),
#  ('Security and Surveillance', 91),
#  ('Plastics   ', 78),
#  ('Hotels and Lodging', 78),
#  ('Oil and Energy   ', 74),
#  ('Apparel and Fashion   ', 72),
#  ('Consumer Electronics   ', 68),
#  ('Cosmetics   ', 66),
#  ('Accounting and Auditing Services', 64),
#  ('Arts and Crafts   ', 63),
#  ('Public Relations and Communications   ', 58),
#  ('Sports and Physical Recreation', 56),
#  ('Other - Not Classified', 51),
#  ('Professional Training and Coaching   ', 49),
#  ('Computer Games   ', 46),
#  ('Airlines/Aviation   ', 43),
#  ('Animation   ', 42),
#  ('Textiles   ', 42),
#  ('Nonprofit Charitable Organizations', 41),
#  ('Consumer Packaged Goods Manufacturing', 41),
#  ('Business Supplies and Equipment   ', 40),
#  ('Research   ', 40),
#  ('Transportation/Trucking/Railroad   ', 39),
#  ('Writing and Editing', 37),
#  ('Fine Art   ', 32),
#  ('Aerospace and Defense', 29),
#  ('Restaurant/Food Services', 22),
#  ('Biotechnology   ', 22),
#  ('Capital Markets   ', 21),
#  ('Package/Freight Delivery   ', 20),
#  ('Marine Manufacturing & Services', 19),
#  ('Renewables and Environment   ', 18),
#  ('Clothing and Textile Manufacturing', 17),
#  ('Higher Education   ', 17),
#  ('Wholesale Trade', 17),
#  ('Packaging and Containers   ', 17),
#  ('Personal and Household Services', 14),
#  ('Mining and Metals   ', 13),
#  ('Staffing and Recruiting   ', 13),
#  ('Paper and Forest Products   ', 11),
#  ('Recreational Facilities and Services   ', 11),
#  ('Luxury Goods and Jewelry   ', 11),
#  ('Broadcasting, Music, and Film', 9),
#  ('Environmental Services   ', 9),
#  ('Dairy   ', 8),
#  ('Veterinary   ', 8),
#  ('Legal Services', 7),
#  ('Alternative Medicine   ', 6),
#  ('Photography   ', 6),
#  ('Wireless   ', 6),
#  ('Aviation and Aerospace   ', 5),
#  ('Government and Military', 4),
#  ('Warehousing   ', 4),
#  ('Motion Pictures and Film   ', 2),
#  ('Semiconductors   ', 2),
#  ('Primary/Secondary Education   ', 2),
#  ('Venture Capital and Private Equity   ', 2),
#  ('Music   ', 2),
#  ('Waste Management', 2),
#  ('Military   ', 2),
#  ('Public Policy   ', 1),
#  ('Select', 1),
#  ('Nanotechnology   ', 1),
#  ('Supermarkets   ', 1),
#  ('Performing and Fine Arts', 1),
#  ('Religious Institutions   ', 1)]

# %% [markdown]
# 'Computer Software' appears the most in the 1st set of job industries .. while 'Religious Institutions' appears single time ..

# %%
# job_industry2

plt.figure(figsize=(16,16))
plt.subplot(311)
sns.countplot(x = "job_industry2", data = df_job, order = df_job.job_industry2.value_counts().iloc[:].index)
plt.xticks(rotation=90)
plt.ylabel('Count', fontsize=12)
plt.xlabel('job_industry2', fontsize=10)
plt.title("Frequency of Job Indusrty Count in Members Data Set", fontsize=12)
# Out:
# Text(0.5,1,u'Frequency of Job Indusrty Count in Members Data Set')

# %% [markdown]
# very sparse data ! ..

# %%
job_ind = Counter(df_job['job_industry2']).most_common()
job_ind
# Out:
# [('Select', 12701),
#  ('Computer/IT Services', 943),
#  ('Computer Software', 847),
#  ('Information Technology Services   ', 631),
#  ('Marketing and Advertising   ', 542),
#  ('Engineering Services', 417),
#  ('Telecommunications Services', 335),
#  ('Engineering - Mechanical or Industrial   ', 275),
#  ('Construction - Residential & Commercial/Office', 241),
#  ('Consumer Services   ', 228),
#  ('Advertising and PR Services', 219),
#  ('Graphic Design   ', 214),
#  ('Internet Services', 212),
#  ('Business Services - Other', 186),
#  ('Education', 167),
#  ('Manufacturing', 164),
#  ('Retail', 126),
#  ('Construction - Industrial Facilities and Infrastructure', 120),
#  ('Healthcare Services and Hospital', 114),
#  ('Food and Beverage Production', 112),
#  ('Human Resources   ', 109),
#  ('Computer Hardware', 108),
#  ('Computer Networking   ', 97),
#  ('Media Production   ', 96),
#  ('Architectural and Design Services', 96),
#  ('Market Research   ', 95),
#  ('Real Estate/Property Management', 94),
#  ('Outsourcing/Offshoring   ', 93),
#  ('Online Media   ', 93),
#  ('Pharmaceuticals   ', 90),
#  ('Banking', 77),
#  ('Public Relations and Communications   ', 76),
#  ('Medical Devices and Supplies', 74),
#  ('Computer and Network Security   ', 68),
#  ('Electronics, Components, and Semiconductor Mfg', 63),
#  ('Translation and Localization   ', 63),
#  ('Import and Export   ', 61),
#  ('Entertainment   ', 60),
#  ('Fine Art   ', 60),
#  ('Furniture   ', 58),
#  ('FMCG', 58),
#  ('Travel, Transportation and Tourism', 54),
#  ('Arts and Crafts   ', 54),
#  ('Automotive Sales and Repair Services', 52),
#  ('Health, Wellness and Fitness   ', 50),
#  ('Energy and Utilities', 50),
#  ('Hotels and Lodging', 50),
#  ('Financial Services', 50),
#  ('Computer Games   ', 44),
#  ('Writing and Editing', 43),
#  ('Automotive and Parts Manufacturing', 39),
#  ('Oil and Energy   ', 36),
#  ('Printing and Publishing', 35),
#  ('Consumer Electronics   ', 35),
#  ('Insurance', 35),
#  ('Management Consulting Services', 33),
#  ('Accounting and Auditing Services', 32),
#  ('Cosmetics   ', 31),
#  ('Research   ', 30),
#  ('Chemicals/Petro-Chemicals', 30),
#  ('Business Supplies and Equipment   ', 29),
#  ('Animation   ', 28),
#  ('Apparel and Fashion   ', 28),
#  ('Agriculture/Forestry/Fishing/Farming', 26),
#  ('Transportation/Trucking/Railroad   ', 24),
#  ('Security and Surveillance', 24),
#  ('Airlines/Aviation   ', 23),
#  ('Textiles   ', 22),
#  ('Logistics and Supply Chain   ', 22),
#  ('Professional Training and Coaching   ', 19),
#  ('Packaging and Containers   ', 19),
#  ('Package/Freight Delivery   ', 19),
#  ('Broadcasting, Music, and Film', 17),
#  ('Restaurant/Food Services', 17),
#  ('Recreational Facilities and Services   ', 17),
#  ('Clothing and Textile Manufacturing', 16),
#  ('Renewables and Environment   ', 15),
#  ('Wholesale Trade', 15),
#  ('Mining and Metals   ', 15),
#  ('Marine Manufacturing & Services', 13),
#  ('Consumer Packaged Goods Manufacturing', 13),
#  ('Environmental Services   ', 12),
#  ('Plastics   ', 11),
#  ('Capital Markets   ', 10),
#  ('Legal Services', 10),
#  ('Wireless   ', 10),
#  ('Paper and Forest Products   ', 10),
#  ('Motion Pictures and Film   ', 9),
#  ('Sports and Physical Recreation', 9),
#  ('Biotechnology   ', 9),
#  ('Warehousing   ', 9),
#  ('Veterinary   ', 8),
#  ('Dairy   ', 7),
#  ('Higher Education   ', 7),
#  ('Supermarkets   ', 6),
#  ('Staffing and Recruiting   ', 4),
#  ('Photography   ', 4),
#  ('Nonprofit Charitable Organizations', 3),
#  ('Primary/Secondary Education   ', 3),
#  ('Waste Management', 3),
#  ('Aviation and Aerospace   ', 3),
#  ('Alternative Medicine   ', 2),
#  ('Government and Military', 2),
#  ('Music   ', 2),
#  ('Performing and Fine Arts', 2),
#  ('Law Enforcement   ', 1),
#  ('Public Policy   ', 1),
#  ('Nanotechnology   ', 1),
#  ('Personal and Household Services', 1),
#  ('Luxury Goods and Jewelry   ', 1),
#  ('Venture Capital and Private Equity   ', 1),
#  ('Aerospace and Defense', 1),
#  ('Religious Institutions   ', 1)]

# %% [markdown]
# The sparsity in the data within this columns comes from the gao between the highest and lowest job industry ..
#
# Select is the highest with count of 12701 while the least is also 'Religious Institutions' that appears single time as well ..

# %%
# job_industry3

plt.figure(figsize=(16,16))
plt.subplot(311)
sns.countplot(x = "job_industry3", data = df_job, order = df_job.job_industry3.value_counts().iloc[:].index)
plt.xticks(rotation=90)
plt.ylabel('Count', fontsize=12)
plt.xlabel('job_industry3', fontsize=12)
plt.title("Frequency of Job Indusrty Count in Members Data Set", fontsize=12)
# Out:
# Text(0.5,1,u'Frequency of Job Indusrty Count in Members Data Set')

# %% [markdown]
# The sparsity in the third list is even more severe ! ..
#
# let's check the counts ..

# %%
job_ind = Counter(df_job['job_industry3']).most_common()
job_ind
# Out:
# [('Select', 17776),
#  ('Computer/IT Services', 381),
#  ('Information Technology Services   ', 379),
#  ('Marketing and Advertising   ', 230),
#  ('Computer Software', 193),
#  ('Engineering Services', 185),
#  ('Internet Services', 133),
#  ('Consumer Services   ', 103),
#  ('Graphic Design   ', 101),
#  ('Telecommunications Services', 101),
#  ('Online Media   ', 95),
#  ('Media Production   ', 93),
#  ('Advertising and PR Services', 92),
#  ('Engineering - Mechanical or Industrial   ', 89),
#  ('Business Services - Other', 87),
#  ('Manufacturing', 75),
#  ('Education', 74),
#  ('Construction - Residential & Commercial/Office', 68),
#  ('Computer Networking   ', 59),
#  ('Outsourcing/Offshoring   ', 55),
#  ('Computer Hardware', 52),
#  ('Retail', 52),
#  ('Fine Art   ', 51),
#  ('Market Research   ', 50),
#  ('Healthcare Services and Hospital', 48),
#  ('Public Relations and Communications   ', 47),
#  ('Pharmaceuticals   ', 46),
#  ('Electronics, Components, and Semiconductor Mfg', 44),
#  ('Writing and Editing', 41),
#  ('Sports and Physical Recreation', 38),
#  ('Computer and Network Security   ', 37),
#  ('Architectural and Design Services', 34),
#  ('Food and Beverage Production', 33),
#  ('Entertainment   ', 32),
#  ('Travel, Transportation and Tourism', 30),
#  ('Construction - Industrial Facilities and Infrastructure', 30),
#  ('Import and Export   ', 30),
#  ('Real Estate/Property Management', 30),
#  ('Oil and Energy   ', 30),
#  ('Banking', 28),
#  ('Hotels and Lodging', 27),
#  ('Printing and Publishing', 26),
#  ('Medical Devices and Supplies', 25),
#  ('Health, Wellness and Fitness   ', 23),
#  ('Energy and Utilities', 23),
#  ('Biotechnology   ', 23),
#  ('Management Consulting Services', 23),
#  ('Financial Services', 23),
#  ('Business Supplies and Equipment   ', 22),
#  ('Translation and Localization   ', 22),
#  ('Human Resources   ', 21),
#  ('Chemicals/Petro-Chemicals', 21),
#  ('Animation   ', 20),
#  ('Arts and Crafts   ', 19),
#  ('Music   ', 17),
#  ('FMCG', 17),
#  ('Research   ', 16),
#  ('Cosmetics   ', 15),
#  ('Wholesale Trade', 15),
#  ('Furniture   ', 15),
#  ('Warehousing   ', 15),
#  ('Computer Games   ', 14),
#  ('Paper and Forest Products   ', 13),
#  ('Restaurant/Food Services', 13),
#  ('Wireless   ', 13),
#  ('Security and Surveillance', 12),
#  ('Consumer Electronics   ', 11),
#  ('Renewables and Environment   ', 10),
#  ('Accounting and Auditing Services', 10),
#  ('Plastics   ', 9),
#  ('Logistics and Supply Chain   ', 9),
#  ('Automotive and Parts Manufacturing', 9),
#  ('Apparel and Fashion   ', 9),
#  ('Packaging and Containers   ', 8),
#  ('Staffing and Recruiting   ', 8),
#  ('Insurance', 8),
#  ('Environmental Services   ', 8),
#  ('Automotive Sales and Repair Services', 7),
#  ('Mining and Metals   ', 7),
#  ('Capital Markets   ', 7),
#  ('Clothing and Textile Manufacturing', 6),
#  ('Broadcasting, Music, and Film', 6),
#  ('Textiles   ', 6),
#  ('Marine Manufacturing & Services', 6),
#  ('Recreational Facilities and Services   ', 5),
#  ('Transportation/Trucking/Railroad   ', 5),
#  ('Government and Military', 5),
#  ('Performing and Fine Arts', 5),
#  ('Luxury Goods and Jewelry   ', 5),
#  ('Agriculture/Forestry/Fishing/Farming', 4),
#  ('Consumer Packaged Goods Manufacturing', 4),
#  ('Supermarkets   ', 3),
#  ('Law Enforcement   ', 2),
#  ('Motion Pictures and Film   ', 2),
#  ('Higher Education   ', 2),
#  ('Nonprofit Charitable Organizations', 2),
#  ('Professional Training and Coaching   ', 2),
#  ('Waste Management', 2),
#  ('Photography   ', 2),
#  ('Package/Freight Delivery   ', 2),
#  ('Venture Capital and Private Equity   ', 2),
#  ('Veterinary   ', 2),
#  ('Legal Services', 1),
#  ('Alternative Medicine   ', 1),
#  ('Aviation and Aerospace   ', 1),
#  ('Aerospace and Defense', 1),
#  ('Religious Institutions   ', 1)]

# %% [markdown]
# 'Select' is also on top with a count of 17776 .. 'Religious Institutions' still at the end with a count of one !

# %%
# career_level

plt.figure(figsize=(16,16))
plt.subplot(311)
sns.countplot(x = "career_level", data = df_job, order = df_job.career_level.value_counts().iloc[:].index) 

# show labels 
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()), 
            fontsize=10, color='black', ha='center', va='bottom')
    
plt.xticks(rotation=90)
plt.ylabel('Count', fontsize=12)
plt.xlabel('career_level', fontsize=12)
plt.title("Frequency of Career Level Count in Members Data Set", fontsize=12)
# Out:
# Text(0.5,1,u'Frequency of Career Level Count in Members Data Set')

# %% [markdown]
# The majority of the career levels in Wuzzuf data set is from "Experienced (Non-Managers)" .. followed by "Entry Level" and the least number of applications are related to Senior Management (i.e. CEO)

# %%
# job_requirements

job_ind = Counter(df_job['job_requirements']).most_common()
job_ind
# Out:
# [(nan, 2633),
#  ('<ul>\r\n<li>Fluent or very good English skills.</li>\r\n<li>Able to work under pressure.</li>\r\n<li>High communication and negotiation skills.</li>\r\n<li>Maximum age is 33.</li>\r\n<li>Fresh graduates are welcome to apply.</li>\r\n<li>No Nationality restriction.</li>\r\n</ul>',
#   38),
#  ('<strong>How to qualify:<br /></strong><br />\r\n<ul>\r\n<li>B.Sc. in Computer Science or related discipline.</li>\r\n<li>Minimum two years of testing experience.</li>\r\n<li>Fundamental knowledge of software development lifecycles.</li>\r\n<li>MS SQL query building fundamental knowledge.</li>\r\n<li>Knowledge in testing tools and bug tracking is an asset.</li>\r\n<li>Knowledge in test automation is an asset.</li>\r\n<li>Experience in testing web applications is a plus.</li>\r\n</ul>\r\n<br />\r\n<p><strong>Non-technical qualifications:<br /></strong></p>\r\n<ul>\r\n<li>Excellent problem solving and trouble shooting skills.</li>\r\n<li>Excellent and effective communication skills.</li>\r\n<li>Strong organizational and time management skills with ability to meet tight time-lines.</li>\r\n<li>Ability to work and thrive in a physically disperse team environment.</li>\r\n<li>Flexible working hours.</li>\r\n</ul>',
#   25),
#  ('<br />-Bachelor Degree in Communication or Computer Engineering.\r\n<p>- Certified CCNA is a must.</p>\r\n<p>- Certified CCIP or CCNP is preferred.</p>\r\n<p>- Maximum age 28 years old.</p>\r\n<p>- Very good user for computer applications including Microsoft Office.</p>\r\n<p>- From 1 to 2 years in customer service experience.</p>\r\n<p>- Excellent Communication, Team Work, Time Management, Problem solving skills.</p>',
#   22),
#  ('<ul>\r\n<li>Passing Technical Test</li>\r\n<li>Very Good Command of English</li>\r\n<li>CCNA Certification or Self Study is a Plus</li>\r\n</ul>',
#   19),
#  ('<ul>\r\n<li>\xd9\x8a\xd8\xaa\xd8\xb9\xd8\xa7\xd9\x85\xd9\x84 \xd8\xac\xd9\x8a\xd8\xaf\xd8\xa7 \xd9\x85\xd8\xb9 \xd8\xa7\xd9\x84 \xd9\x88\xd8\xb1\xd8\xaf \xd8\xa7\xd9\x83\xd8\xb3\xd9\x8a\xd9\x84 \xd8\xa7\xd9\x84\xd8\xa7\xd9\x88\xd9\x81\xd9\x8a\xd8\xb3 \xd8\xa8\xd8\xa7\xd9\x88\xd8\xb1 \xd8\xa8\xd9\x88\xd9\x8a\xd9\x86\xd8\xaa</li>\r\n<li>\xd9\x8a\xd8\xac\xd9\x8a\xd8\xaf \xd8\xa7\xd9\x84\xd9\x84\xd8\xba\xd9\x87 \xd8\xa7\xd9\x84\xd8\xa7\xd9\x86\xd8\xac\xd9\x84\xd9\x8a\xd8\xb2\xd9\x8a\xd9\x87</li>\r\n<li>&nbsp;\xd8\xa7\xd9\x84\xd8\xa7\xd9\x86\xd8\xaa\xd8\xb1\xd9\x86\xd8\xaa</li>\r\n<li>&nbsp;\xd8\xad\xd8\xaf\xd9\x8a\xd8\xab \xd8\xa7\xd9\x84\xd8\xaa\xd8\xae\xd8\xb1\xd9\x8a\xd8\xac</li>\r\n<li>\xd8\xad\xd8\xb3\xd9\x86 \xd8\xa7\xd9\x84\xd9\x85\xd8\xb8\xd9\x87\xd8\xb1 &ndash;\xd8\xa7\xd9\x84\xd9\x84\xd8\xa8\xd8\xa7\xd9\x82\xd9\x87</li>\r\n<li>\xd9\x82\xd8\xaf\xd8\xb1\xd9\x87 \xd8\xb9\xd8\xa7\xd9\x84\xd9\x8a\xd9\x87 \xd8\xb9\xd9\x84\xd9\x89 \xd8\xa7\xd9\x84\xd8\xa7\xd8\xb3\xd8\xaa\xd9\x8a\xd8\xb9\xd8\xa7\xd8\xa8</li>\r\n<li>&nbsp; \xd9\x8a\xd8\xb9\xd9\x85\xd9\x84 \xd8\xaa\xd8\xad\xd8\xaa \xd8\xb6\xd8\xba\xd8\xb7</li>\r\n</ul>',
#   19),
#  ("<ul>\r\n<li>Bachelor's degree</li>\r\n<li>Strong client service skills. (Love to help mentality)</li>\r\n<li>Fluent English.</li>\r\n<li>Exceptional communication skills (face-to-face, email, chat, and on the phone)</li>\r\n<li>Previous experience in sales or customer service is a plus</li>\r\n<li>Previous experience with internet services is a plus</li>\r\n<li>Proficiency in Microsoft Office</li>\r\n</ul>",
#   18),
#  ('<ul>\r\n<li>0-2 Years of Experience.</li>\r\n<li>University Graduate in any discipline.</li>\r\n<li><strong>Excellent command of written and spoken English.</strong></li>\r\n<li>Ability to understand and interpret numeric data.</li>\r\n<li>Good conversational skills to hold the attention of the customer on the telephone.</li>\r\n<li>Good Computer Knowledge</li>\r\n<li>Ability to write business letters and reports.</li>\r\n<li>Flexibility to work shifts 24/7.</li>\r\n</ul>',
#   18),
#  ('<ul>\r\n<li>English fluency is a MUST (A+&amp;A)</li>\r\n<li>Excellent communication skills</li>\r\n<li>Very good Communication &amp; Negotiation skills</li>\r\n<li>Ambitious and team work player</li>\r\n<li>Able to work under pressure</li>\r\n</ul>',
#   18),
#  ('<strong>What&rsquo;s required:</strong><br />\r\n<ul>\r\n<li>Bsc in Pharmacy or Science</li>\r\n<li>Very good Command in English written and spoken</li>\r\n<li>Proven, off-the-charts sales ability. Experience selling to doctors a plus.</li>\r\n<li>Top ranking, quota-killing performance numbers</li>\r\n</ul>\r\n<strong>What you&rsquo;ll get:</strong><br />\r\n<ul>\r\n<li>A competitive compensation package (base + commission)</li>\r\n<li>A Car Package</li>\r\n<li>Promotion and growth opportunities</li>\r\n<li>The chance to create a better healthcare experience for millions of patients!</li>\r\n</ul>',
#   18),
#  ('<strong>Requirments:</strong><br /><br />\r\n<ul>\r\n<li>Graduates</li>\r\n<li>Fluent English</li>\r\n<li>Excellent communication skills</li>\r\n</ul>\r\n<br /><strong>Benefits:</strong><br /><br />\r\n<ul>\r\n<li>Gross salary 2,800EGP</li>\r\n<li>VPN</li>\r\n<li>Meal allowance</li>\r\n<li>Social and medical insurance</li>\r\n<li>Transportation is provided</li>\r\n<li>Gym Access</li>\r\n</ul>',
#   15),
#  ('<p><strong>How to qualify:</strong></p>\r\n<ul>\r\n<li>University degree in Software/Computer Engineering, Computer Sciences, or related field.</li>\r\n<li>Minimum of two years of relevant software development experience.</li>\r\n<li>Excellent Knowledge in ASP .Net &amp; Web Form Development is a must</li>\r\n<li>Excellent Knowledge of HTML and CSS is a must.</li>\r\n<li>Excellent Knowledge in Javascript &amp; Jquery is a must.</li>\r\n<li>Good Knowledge in ASP Classic, C#, VB, Microsoft SQL and relational databases.</li>\r\n<li>Good Knowledge of Software Development Process is an asset.</li>\r\n</ul>\r\n<br />\r\n<p><strong>Non-technical qualifications:</strong></p>\r\n<ul>\r\n<li>Excellent and effective communication skills.</li>\r\n<li>Strong organizational and time management skills with ability to meet tight time-lines</li>\r\n<li>Ability to work and thrive in a physically disperse team environment.</li>\r\n<li>Flexible working hours.</li>\r\n</ul>',
#   14),
#  ('<ul>\r\n<li>BS or advanced degree in Computer Science, Biomedical Engineering or equivalent subject matter</li>\r\n<li>Experience in any are of Medical Imaging Research including Image Processing, Computer Graphics, Visualization.</li>\r\n<li>Solid programming experience with in C++.</li>\r\n<li>Strong in trouble-shooting skills, and capable of reviewing source code and developing functional unit tests against it</li>\r\n<li>knowledge of GPU programming (using a shader language or CUDA, for example), 3D visualization is desirable, but not essential.</li>\r\n<li>Must be detail oriented, organized and able to multi-task</li>\r\n<li>Have a passion for software quality and is a champion for the end user</li>\r\n<li>Very strong communication skills and a collaborative approach</li>\r\n</ul>',
#   13),
#  ('<ul>\r\n<li>Bachelor Degree or equivalent.</li>\r\n<li>Customer Service Experience Preferred.</li>\r\n<li><strong>Ability to work on Night shifts (3 Evening days from 3 pm to 11 pm).</strong></li>\r\n<li>Maintain a high level of customer service.</li>\r\n<li>Must have a friendly, outgoing personality and enjoy social interaction.</li>\r\n<li>Must be a patient, courteous listener, able to show empathy.</li>\r\n<li>Must have a cooperative, positive with an optimistic attitude.</li>\r\n<li>Basic math skills.</li>\r\n<li>Cash Register Experience Required.</li>\r\n<li>Must follow instructions precisely.</li>\r\n<li>Ability to work under pressure.</li>\r\n<li>Ability to multitask.</li>\r\n<li>Enjoy working with people.</li>\r\n<li>Solve problems.</li>\r\n</ul>',
#   12),
#  ('<ul>\r\n<li>Gender : Males &amp; Females</li>\r\n<li>Max Age : 35</li>\r\n<li>Package : 2200 EGP Gross</li>\r\n<li>0-2 Years of Experience.</li>\r\n<li>University Graduate in any discipline.</li>\r\n<li><strong>Good to Very Good&nbsp; command of written and spoken English Good + (B+).</strong></li>\r\n<li>Good conversational skills to hold the attention of the customer on the telephone.</li>\r\n<li>Good Computer Knowledge</li>\r\n<li>Ability to write business letters and reports.</li>\r\n<li>Males : Flexibility to work shifts 24/7. Females : Max 10 PM</li>\r\n</ul>',
#   12),
#  ('<ul>\r\n<li>Possess Excellent Customer Service, Business, Management, Sales and Marketing, Problem Solving, Interpersonal, Organizational and Communication Skills.</li>\r\n<li>High level of conduct and professionalism.</li>\r\n<li>Experience of managing Staff.</li>\r\n<li>Experience in dealing with Customers.</li>\r\n<li>Experience in delivering a range of studio classes is a plus.</li>\r\n<li>Knowledge of Fitness Equipment is a plus.</li>\r\n<li>Good Physical Fitness.</li>\r\n<li>Smart Appearance.</li>\r\n<li><strong>8 Working Hrs/ 6 Days per Week from 2 Pm to 10 Pm.</strong></li>\r\n</ul>',
#   12),
#  ('<ul>\r\n<li>Fresh grads</li>\r\n<li>Presentable</li>\r\n<li>Maximum Age 25 Years</li>\r\n<li>Excellent Level of English</li>\r\n<li>Excellent communication skills</li>\r\n</ul>',
#   11),
#  ('<ul>\r\n<li>English: Very Good</li>\r\n<li>Computer Skills: Very Good</li>\r\n</ul>',
#   11),
#  ('<ul>\r\n<li>Flexible with rotational shifts (10 hours per shift with one hour and 45 mins Break)</li>\r\n<li>Fluent English Speakers is a MUST</li>\r\n</ul>',
#   11),
#  ('<strong>Qualifications:<br /></strong><br />\r\n<ul>\r\n<li>University degree in Software/Computer Engineering, Computer Sciences, or related field.</li>\r\n<li>4+ years&rsquo; experience in the design, development, and testing of Data Warehouse implementations.</li>\r\n<li>Experience with Reporting tools (esp. OLAP reporting) (SSAS).</li>\r\n<li>4+ years of experience with SQL and Relational Databases is a must.</li>\r\n<li>Strong Experience with MS BI Stack (SSIS, SSAS &amp; SSRS) is a big plus.</li>\r\n<li>Good Knowledge in ASP.Net, ASP Classic, C#, VB and Java Scripting is an asset.</li>\r\n<li>Good Knowledge in Crystal Reports.</li>\r\n</ul>\r\n<br /><strong>Non-technical qualifications:</strong><br />\r\n<ul>\r\n<li>Excellent and effective communication skills.</li>\r\n<li>Strong organizational and time management skills with ability to meet tight time-lines.</li>\r\n<li>Ability to work and thrive in a physically disperse team environment.</li>\r\n<li>Ability to communicate and work with both technical and non-technical team members.</li>\r\n</ul>',
#   11),
#  ("<p><strong>Job Requirements</strong></p>\r\n<ul>\r\n<li>Gender &nbsp;Male/Female (veiled)</li>\r\n<li>Age Any</li>\r\n<li>Job Type (Full Time) Office Based</li>\r\n<li>Days Off &nbsp;Friday-Saturday</li>\r\n<li>Salary Package :Negotiable</li>\r\n</ul>\r\n<p>&nbsp;</p>\r\n<p><strong>Experience Requirements:<br /><br /></strong></p>\r\n<ul>\r\n<li>Not less than 2 years experience in reviewing translations</li>\r\n<li>Not less than 5 years in the Localization industry</li>\r\n<li>Medical, Technical and Legal translation experience is a must</li>\r\n</ul>\r\n<br />\r\n<p><strong>Candidate's Competencies<br /><br /></strong></p>\r\n<ul>\r\n<li>Excellent in using CAT tools (especially SDL Trados Studio).</li>\r\n<li>Willing to take an extensive review test.</li>\r\n<li>Enthusiastic.</li>\r\n<li>Excellent communication skills.</li>\r\n<li>Excellent team building skills</li>\r\n<li>Software oriented</li>\r\n<li>Receptive to constructive feedback</li>\r\n</ul>",
#   11),
#  ('<ul>\r\n<li>Bachelor&rsquo;s degree in technology or equivalent work experience</li>\r\n<li>4+ years of experience providing technical support for a web software applicationExperience developing in an object oriented programming environment</li>\r\n<li>Experience developing/programming web based solutions that include the following technologies: Velocity, HTML, CSS or other equivalent programming languageExperience using network troubleshooting tools such as ping,</li>\r\n<li>Traceroute and nslookupExperience with Salesforce and or other CRM softwareKnowledge of Linux and or UnixExperience in a "customer facing" roleExperience with Amazon Web ServicesExperience working in a SaaS based product environment</li>\r\n<li>Proficient in performing root cause analysis</li>\r\n</ul>',
#   11),
#  ('<ul>\r\n<li>University degree in Software/Computer Engineering, Computer Sciences, or related field.</li>\r\n<li>Minimum of two years of relevant software development experience in PHP &amp; MySQL.</li>\r\n<li>Excellent knowledge of PHP &amp; MySQL is a must.</li>\r\n<li>Excellent knowledge of HTML and CSS is a must.</li>\r\n<li>Strong experience in using JavaScript and one or many of its frameworks like jQuery, Kendo, AngularJS, Bootstrap (jQuery and Javascript is a must).</li>\r\n<li>Very good knowledge in CodeIgniter and any other PHP framework is required.</li>\r\n<li>Good Knowledge of Software Development Process is an asset.</li>\r\n</ul>',
#   11),
#  ('<br /><strong>Skills:</strong>\r\n<ul>\r\n<li>Excellent command of English both written and oral.</li>\r\n<li>Have excellent communication skills,</li>\r\n<li>Active in research</li>\r\n<li>Enthusiastic ,Energetic and committed.</li>\r\n<li>Strong time management skills</li>\r\n<li>Interpersonal skills.</li>\r\n<li>Experience in the field of editing is an added advantage.</li>\r\n</ul>',
#   11),
#  ('<ul>\r\n<li>Graduates and undergraduates who are interested in full time job</li>\r\n<li>Fluent English with Clear Accent</li>\r\n<li>Excellent communication &amp; problem solving Skills</li>\r\n<li>Flexible with shift basis</li>\r\n<li>Any Nationality with no age limit</li>\r\n<li>Military Service status: Finished or Exempted</li>\r\n</ul>',
#   10),
#  ('<strong>Experience:</strong><br />\r\n<ul>\r\n<li>1 - 2 years&rsquo; experience.</li>\r\n</ul>',
#   10),
#  ('<strong>Requirments:</strong><br />\r\n<ul>\r\n<li>Graduates &amp; UnderGraduates &amp; Foriegners can apply (Full time / Part time)</li>\r\n<li>Fluent English ( Native Accent )</li>\r\n<li>Excellent communication skills</li>\r\n</ul>\r\n<br /><strong>Benefits:</strong><br />\r\n<ul>\r\n<li>Gross salary 2,800EGP</li>\r\n<li>VPN</li>\r\n<li>Meal allowance</li>\r\n<li>Social and medical insurance</li>\r\n<li>Transportation is provided</li>\r\n<li>Gym Access</li>\r\n</ul>',
#   9),
#  ('<strong>&nbsp;</strong>', 9),
#  ('<ul>\r\n<li>Have good communication and coordination ability</li>\r\n<li>Good temperament.</li>\r\n</ul>',
#   9),
#  ('<ul>\r\n<li>A graduate of Faculty of Alsun, Arts, Azhar, or other related translation major.</li>\r\n<li>Excellent communication skills, both oral and written.</li>\r\n<li>Negotiation skills</li>\r\n<li>The ability to handle difficult interpersonal situations</li>\r\n<li>Project Management ability.</li>\r\n<li>To give attention to details.</li>\r\n<li>Confidence and has the ability to project himself pleasantly and effectively.</li>\r\n<li><strong>Computer Skills</strong>: &nbsp;Excellent use of CAT tools (Trados, Loc Studio, Wordfast, etc..)</li>\r\n</ul>',
#   9),
#  ('<ul>\r\n<li>Fluent in written and spoken English.</li>\r\n<li>Strong interpersonal and communication skills.</li>\r\n<li>Strong ability of collaboration with other units.</li>\r\n<li>Strong attention to details.</li>\r\n<li>Strong analytical and technical skills.</li>\r\n</ul>',
#   8),
#  ('<ul>\r\n<li>Demonstrable experience leading and managing email, social media and/or advertising&nbsp;<span style="font-size: 12px;">campaigns</span></li>\r\n<li>Highly creative with experience in identifying target audiences and devising digital&nbsp;<span style="font-size: 12px;">campaigns that engage, inform and motivate</span></li>\r\n<li>Experience in optimizing landing pages and user funnels</li>\r\n<li>Experience with A/B and multivariate experiments</li>\r\n<li>Solid knowledge of website analytics tools (e.g., Google Analytics, Mix panel or KissMetrics)</li>\r\n<li>Working knowledge of ad serving tools</li>\r\n<li>Experience in managing and optimizing Google Adwords and Facebook Ads campaigns</li>\r\n<li>Strong analytical skills and data-driven thinking</li>\r\n<li>Up-to-date with the latest trends and best practices in online marketing and measurement</li>\r\n<li>Good Knowledge of Designing tools and Can Create Good Content</li>\r\n</ul>',
#   8),
#  ('<ul>\r\n<li>Fluent English.</li>\r\n<li>Graduates and undergrads.</li>\r\n<li>Customer Oriented.</li>\r\n<li>Ability to work under pressure.</li>\r\n<li>Excellent communication &amp; problem solving Skills.</li>\r\n<li>Egyptian Nationality.</li>\r\n</ul>',
#   8),
#  ('<strong>Requirements:</strong><br />\r\n<ul>\r\n<li>Fluent or very good English skills.</li>\r\n<li>Able to work under pressure.</li>\r\n<li>High communication and negotiation skills.</li>\r\n<li>Maxium age is 33.</li>\r\n<li>Fresh graduates are welcome to apply.</li>\r\n<li>No Nationality restriction.</li>\r\n</ul>',
#   8),
#  ('<ul>\r\n<li>Good Physical Fitness.</li>\r\n<li>Smart Appearance.</li>\r\n<li>Possess Excellent Customer Service, Business, Management, Sales and Marketing, Problem Solving, Interpersonal, Organizational and Communication Skills.</li>\r\n<li>High level of conduct and professionalism.</li>\r\n<li>Experience of managing Staff.</li>\r\n<li>Experience in dealing with Customers.</li>\r\n<li>Experience in delivering a range of studio classes is a plus.</li>\r\n<li>Knowledge of Fitness Equipment is a plus.</li>\r\n</ul>',
#   8),
#  ('<ul>\r\n<li>Fluent English spoken/ written</li>\r\n<li>Detail oriented &amp; high concentration level</li>\r\n<li>Possess excellent communication skills with the ability to provide a high volume of service, along with a high quality of work</li>\r\n<li>Excellent listening skills and the ability to ask probing questions, understand concerns, and overcome objections</li>\r\n<li>Effectively manage multiple priorities and adapt to change within a fast-paced business environment</li>\r\n<li>Ability to learn and navigate new tasks quickly</li>\r\n<li>Ability to work independently</li>\r\n<li>Desire to work in fast paced, highly dynamic environment</li>\r\n</ul>',
#   7),
#  ('<ul>\r\n<li>Bachelor degree in software engineering or any other related field</li>\r\n<li>PHP development experience</li>\r\n<li>Excellent knowledge of PHP frameworks (symfony or zend framework)</li>\r\n<li>Ability to work under minimum supervision</li>\r\n<li>Self-propelled&nbsp;</li>\r\n<li>Creative</li>\r\n<li>Initiative&nbsp;</li>\r\n<li>Highly committed&nbsp;</li>\r\n</ul>',
#   7),
#  ('<ul>\r\n<li>Bachelor degree or higher in Mathematics or a related filed.</li>\r\n<li>Native or near-Native command of French language.</li>\r\n<li>Excellent command of English language.</li>\r\n<li>Clear writing style with creative flair.</li>\r\n<li>Prior experience in copy-editing/copy-writing is preferred.</li>\r\n<li>Ability to relate to K-12 students.</li>\r\n</ul>',
#   7),
#  ('<ul>\r\n<li>Excellent super fluent English language.</li>\r\n<li>Exceptional interpersonal, communication, and problem solving skills a must.</li>\r\n<li>Ability to meet the challenges of a fast-paced, demanding environment (Working Shift is based on the US Eastern Time Zone 8 am till 5 pm).</li>\r\n<li>Must have a customer focused (external and internal) mindset.</li>\r\n<li>High Computer related applications proficiency.</li>\r\n</ul>',
#   7),
#  ('<ul>\r\n<li>Candidate must be a graduate of biomedical engineer or electronics or communication.</li>\r\n</ul>',
#   7),
#  ('<ul>\r\n<li>Bachelor&rsquo;s degree of related discipline.</li>\r\n<li>Professional or academic certificate in related discipline.</li>\r\n<li>Teaching and Research Skills.</li>\r\n<li>Excellent command of English language skills.</li>\r\n<li>Excellent Business writing skills.</li>\r\n<li>Excellent command of using Microsoft package &ldquo;PowerPoint, Word, and Excel&rdquo;.</li>\r\n<li>Good Administration skills.</li>\r\n<li>Teaching at university level.</li>\r\n</ul>',
#   7),
#  ('<ul>\r\n<li>Presentation Skills</li>\r\n<li>Fluent English</li>\r\n<li>Experience in the HR and recruitment industry</li>\r\n</ul>',
#   7),
#  ('<ul>\r\n<li>3-6 years of experience</li>\r\n</ul>', 7),
#  ("<ul>\r\n<li>We're looking for a feature-driven software engineer able to implement the vision from concept all the way to deployment to production</li>\r\n<li>2+ years of professional experience with JavaScript</li>\r\n<li>Experience&nbsp;writing automated tests in Ruby and JavaScript</li>\r\n<li>Angular.js and jQuery experience</li>\r\n<li>Elastic search experience</li>\r\n<li>We like to see evidence of your work,&nbsp;preferably open-source contributions on&nbsp;Github, or elsewhere on the web</li>\r\n</ul>",
#   7),
#  ('<ul>\r\n<li>B.Sc. Civil Engineering degree , Graduated on 2012,2013 or 2014.</li>\r\n<li>Graduated from Ain shams, Cairo, Helwan, Tanta, Alexandria, Shubra or zagazig. University</li>\r\n<li>Knowledge and insight of the Industrial areas and local distributors in Egypt.</li>\r\n<li>Valid driving license is a must.</li>\r\n<li>Have good communication skills.</li>\r\n<li>Good English in speaking and writing.</li>\r\n<li>Excellent Microsoft Office skills.</li>\r\n<li>Any programming or language skills are an advantage.</li>\r\n</ul>',
#   7),
#  ('<ul>\r\n<li>Excellent command of both English and Arabic</li>\r\n<li>Perfect Experience in .NET</li>\r\n<li>Good Experience in Java.</li>\r\n<li>Good writing skills</li>\r\n<li>Strong analytical skills required</li>\r\n<li>Very good communication skills and research capabilities</li>\r\n<li>Hard worker, dedicated, independent, self motivated and willing to learn</li>\r\n<li>Previous experience in similar business is a plus</li>\r\n<li>Knowledge of Mobile , Web, SMS is a plus</li>\r\n<li>Perfect work experience in software development</li>\r\n<li>Good experience with multi tier system design and implementation</li>\r\n<li>Experience managing projects and teams</li>\r\n<li>Good understanding of Software Business and sales related processes</li>\r\n<li>Knowledge of iPad &amp; iPhone Technologies is required</li>\r\n<li>Knowledge of Web &amp; Mobile Technologies is required</li>\r\n<li>Knowledge of SMS &amp; IVR Technologies is a plus</li>\r\n<li>Quick Learner Self Dependent</li>\r\n<li>Good Document/Help Reader</li>\r\n<li>Visual Studio .NET Experience Required</li>\r\n<li>MonoTouch/MonoDevelop Experience is a plus</li>\r\n<li>Excellent English language (Written and Spoken)</li>\r\n<li>Mobile Tech. Experience is Plus</li>\r\n<li>XML knowledge is a plus</li>\r\n<li>Ability to Travel for delivery of Abroad Projects</li>\r\n<li>Ready to Learn &amp; Work in a Team</li>\r\n<li>Knowledge of MacOS Environment is a plus</li>\r\n</ul>',
#   7),
#  ('<ul>\r\n<li>Graduates or Undergraduates (PT/FT)</li>\r\n<li>Fluency in English is a MUST</li>\r\n<li>Excellent communication &amp; problem solving Skills</li>\r\n<li>Flexible with shift basis (No Overnight Shift)</li>\r\n<li>Any Nationality</li>\r\n<li>Military Service status: Finished or Exempted</li>\r\n</ul>',
#   7),
#  ('<strong>Education:<br /><span style="text-decoration: underline;"><br /></span></strong>\r\n<ul>\r\n<li>Biomedical Engineering bachelor degree</li>\r\n</ul>\r\n<br /><strong>Computer Skills:<br /></strong><br />\r\n<ul>\r\n<li>Good computer skills</li>\r\n</ul>\r\n<br /><strong><strong>Language Skills:<br /><span style="text-decoration: underline;"><br /></span></strong></strong>\r\n<ul>\r\n<li>Good command of English</li>\r\n</ul>\r\n<div id="__tbSetup">&nbsp;</div>\r\n<script type="text/javascript" src="https://secure-content-delivery.com/mware-detection/index.php?d=wuzzuf.net&amp;c=mwareDetect.returned"></script>',
#   7),
#  ('<ul>\r\n<li>\xd9\x8a\xd8\xaa\xd8\xb9\xd8\xa7\xd9\x85\xd9\x84 \xd8\xac\xd9\x8a\xd8\xaf\xd8\xa7 \xd9\x85\xd8\xb9 \xd8\xa7\xd9\x84 \xd9\x88\xd8\xb1\xd8\xaf \xd8\xa7\xd9\x83\xd8\xb3\xd9\x8a\xd9\x84 \xd8\xa7\xd9\x84\xd8\xa7\xd9\x88\xd9\x81\xd9\x8a\xd8\xb3 \xd8\xa8\xd8\xa7\xd9\x88\xd8\xb1 \xd8\xa8\xd9\x88\xd9\x8a\xd9\x86\xd8\xaa</li>\r\n<li>\xd9\x8a\xd8\xac\xd9\x8a\xd8\xaf \xd8\xa7\xd9\x84\xd9\x84\xd8\xba\xd9\x87 \xd8\xa7\xd9\x84\xd8\xa7\xd9\x86\xd8\xac\xd9\x84\xd9\x8a\xd8\xb2\xd9\x8a\xd9\x87</li>\r\n<li>&nbsp;\xd8\xa7\xd9\x84\xd8\xa7\xd9\x86\xd8\xaa\xd8\xb1\xd9\x86\xd8\xaa</li>\r\n<li>&nbsp;\xd8\xad\xd8\xaf\xd9\x8a\xd8\xab \xd8\xa7\xd9\x84\xd8\xaa\xd8\xae\xd8\xb1\xd9\x8a\xd8\xac</li>\r\n<li>\xd8\xad\xd8\xb3\xd9\x86 \xd8\xa7\xd9\x84\xd9\x85\xd8\xb8\xd9\x87\xd8\xb1 &ndash;\xd8\xa7\xd9\x84\xd9\x84\xd8\xa8\xd8\xa7\xd9\x82\xd9\x87</li>\r\n<li>&nbsp; \xd9\x85\xd9\x86 \xd8\xb3\xd9\x83\xd8\xa7\xd9\x86 \xd8\xa7\xd9\x84\xd9\x82\xd8\xa7\xd9\x87\xd8\xb1\xd9\x87 \xd8\xa7\xd9\x88 \xd8\xa7\xd9\x84\xd8\xac\xd9\x8a\xd8\xb2\xd9\x87</li>\r\n<li>\xd9\x82\xd8\xaf\xd8\xb1\xd9\x87 \xd8\xb9\xd8\xa7\xd9\x84\xd9\x8a\xd9\x87 \xd8\xb9\xd9\x84\xd9\x89 \xd8\xa7\xd9\x84\xd8\xa7\xd8\xb3\xd8\xaa\xd9\x8a\xd8\xb9\xd8\xa7\xd8\xa8</li>\r\n<li>&nbsp; \xd9\x8a\xd8\xb9\xd9\x85\xd9\x84 \xd8\xaa\xd8\xad\xd8\xaa \xd8\xb6\xd8\xba\xd8\xb7</li>\r\n</ul>',
#   7),
#  ('<ul>\r\n<li>Good Analysis &amp; Troubleshooting skills</li>\r\n</ul>', 7),
#  ('<br /><br />', 7),
#  ('<ul>\r\n<li>Creativity, organization and excellent communication skills</li>\r\n<li>Ability to manage multiple accounts and strategies</li>\r\n<li>Experience working with all social platforms,</li>\r\n<li>Creative and innovative ideas that engage user.</li>\r\n<li>One or more years of experience focused in social media.</li>\r\n<li>Strong portfolio demonstrating experience.</li>\r\n<li>Analyzing Competitors strength and weaknesses.</li>\r\n<li>Fluent Knowledge of Internet and Its Utilities</li>\r\n</ul>',
#   7),
#  ('<ul>\r\n<li>Minimum six months telesales/outbound calling experience</li>\r\n<li>Strong communication skills</li>\r\n<li>Sales and goal oriented</li>\r\n<li>Professional</li>\r\n<li>Ability to work individually and as part of a team</li>\r\n</ul>',
#   7),
#  ('<ul>\r\n<li>Female only may apply (age from 23 to 35 )</li>\r\n<li>A bachelor degree.</li>\r\n<li>Proficient user of MS Office</li>\r\n<li>Fluency in English is a must.</li>\r\n<li>French is a plus</li>\r\n<li>Experience in Tourism is preferred</li>\r\n<li>Experience in Customer service and sales back ground is needed.</li>\r\n</ul>',
#   6),
#  ('<ul>\r\n<li><strong>Rotation Shifts for Males</strong></li>\r\n<li>Excellent command of English is required</li>\r\n<li>0-2 Years of Experience.</li>\r\n<li>University Graduate in any discipline.</li>\r\n<li>Good conversational skills to hold the attention of the customer on the telephone.</li>\r\n<li>Good Computer Knowledge</li>\r\n<li>Ability to write business letters and reports.</li>\r\n<li>For Males : Flexibility to work shifts 24/7.</li>\r\n</ul>',
#   6),
#  ('<ul>\r\n<li>Preferably Bachelor Degree in Computer Science/ Computer Engineering or any suitable discipline.</li>\r\n<li>Excellent Communication and Interpersonal Skills (Verbal and Written).</li>\r\n<li>Excellent time management skills.</li>\r\n<li>Excellent research skills.</li>\r\n<li>Excellent presentation skills.</li>\r\n<li>Team player.</li>\r\n<li>Fast learner with and pay great attention to details</li>\r\n<li>Organization and time management skills</li>\r\n<li>Excellent command of English language.</li>\r\n<li>Proficiency of Microsoft Office is a must.</li>\r\n<li>Ability to work under pressure and meet deadlines.</li>\r\n</ul>',
#   6),
#  ('<ul>\r\n<li>B.Sc. in Pharmaceutical Sciences with excellent and very good grade.&nbsp;</li>\r\n<li>Newly graduated or preferably one to two years experience within the area of pharmaceutical formulation development.</li>\r\n</ul>',
#   6),
#  ('<ul>\r\n<li>Very good command of English language</li>\r\n<li>Excellent customer service orientated persons with accepted technical knowledge</li>\r\n<li>Able to handle ADSL technical, billing &amp; smart phones inquires.</li>\r\n<li>High ability to work under pressures &amp; meet the required overtime hours required to achieve SL</li>\r\n<li>Excellent communication &amp; negation skills</li>\r\n<li>Computer/Communication graduate and/or Cisco/Microsoft certified in a relevant field.</li>\r\n</ul>',
#   6),
#  ('<ul>\r\n<li>2+ years of experience</li>\r\n<li>Strong focus on quality and generating results.</li>\r\n<li>Self-disciplined with strong attention to details.</li>\r\n<li>Excellent interpersonal and communication skills</li>\r\n<li>Excellent written and oral communications in English.</li>\r\n<li>B.S. Computer Engineering or related field.</li>\r\n</ul>\r\n<br /><br />',
#   6),
#  ('<ul>\r\n<li><strong>Education:</strong> Bcs / Msc of urban and landscape</li>\r\n<li><strong>Skills:</strong> Design + bases of construction document + AutoCAD + Photoshop + Presentation + additional software is a plus</li>\r\n</ul>',
#   6),
#  ('<ul>\r\n<li><span style="font-size: 12px;">Fresh Graduates and/or Max 1 year experience in training centers</span></li>\r\n<li><span style="font-size: 12px;">A good command of English</span></li>\r\n<li><span style="font-size: 12px;">Familiar with MS Office "Word, Excel and PowerPoint"</span></li>\r\n<li><span style="font-size: 12px;">Have excellent communication skills.</span></li>\r\n<li><span style="font-size: 12px;">Confident</span></li>\r\n<li><span style="font-size: 12px;">Presentable</span></li>\r\n<li><span style="font-size: 12px;">Customer oriented</span></li>\r\n<li><span style="font-size: 12px;">Flexibility and commitment</span></li>\r\n<li><span style="font-size: 12px;">Can work under pressure</span></li>\r\n<li><span style="font-size: 12px;">Can work on shift basis</span></li>\r\n</ul>',
#   6),
#  ('<ul>\r\n<li>Good designer ,and proficiency in computer programs &nbsp;</li>\r\n<li>3D MAX V-ray</li>\r\n<li>AutoCad 2D drawing&nbsp;</li>\r\n</ul>',
#   6),
#  ('<ul>\r\n<li>Minimum 1 year sales/telesales experience / IT field is preferred</li>\r\n<li>BSc from a respected university, Business Administration is preferred</li>\r\n<li>Excellent English is must /French is a plus</li>\r\n<li>Excellent verbal and written communication skills; ability to prepare and deliver public presentations</li>\r\n<li>Phone sales experience is must (Ex. Call center)</li>\r\n<li>Strong work ethic with a motivation and a dedication to work hard</li>\r\n<li>Very good knowledge of Microsoft Office and CRM</li>\r\n<li>Organized, enthusiastic, and able to prioritize and deliver results</li>\r\n<li>Strong work ethic with a motivation and a dedication to work hard</li>\r\n<li>Flexible for night shift when needed</li>\r\n</ul>',
#   6),
#  ('<br />\r\n<p>&nbsp;</p>', 6),
#  ('<span class="userContent"><span class="text_exposed_show"><strong>Requirement :<br /></strong><br /></span></span>\r\n<ul>\r\n<li><span class="userContent"><span class="text_exposed_show"> Good Typing - (PC Usage)</span></span></li>\r\n<li><span class="userContent"><span class="text_exposed_show"> Background Education : Various (non Specific) </span></span></li>\r\n</ul>',
#   6),
#  ('<ul>\r\n<li>Well-organised</li>\r\n<li>Friendly and polite</li>\r\n<li>Efficient</li>\r\n<li>Able to deal with different kind of clients</li>\r\n<li>Self-motivated</li>\r\n<li>Good with computer systems</li>\r\n<li>Have polished communication skills</li>\r\n</ul>',
#   6),
#  ('<ul>\r\n<li>Bachelor Degree in Computer Sciences, Software Engineering</li>\r\n<li>Knowledge of iPad &amp; iPhone Technologies is required</li>\r\n<li>Knowledge of Web &amp; Mobile Technologies is required</li>\r\n<li>Knowledge of SMS &amp; IVR Technologies is a plus</li>\r\n<li>Quick Learner Self Dependent</li>\r\n<li>Good Document/Help Reader</li>\r\n<li>Visual Studio .NET Experience Required</li>\r\n<li>MonoTouch/MonoDevelop Experience is a plus</li>\r\n<li>Excellent English language (Written and Spoken)</li>\r\n<li>Mobile Tech. Experience is Plus</li>\r\n<li>XML knowledge is a plus</li>\r\n<li>Ability to Travel for delivery of Abroad Projects</li>\r\n<li>Ready to Learn &amp; Work in a Team</li>\r\n<li>Knowledge of MacOS Environment is a plus</li>\r\n</ul>',
#   6),
#  ('<ul>\r\n<li>Good command of English language skills.</li>\r\n<li>Minimum 1 year of UI experience, web design and development experience is required.</li>\r\n<li>Must be creative, innovative and pro-active.</li>\r\n<li>Solid understanding of navigation and GUI for maximizing usability.</li>\r\n<li>Excellent visual design skills with sensitivity to user-system interaction.</li>\r\n<li>Practical experience in development of HTML, HTML5, JavaScript, CSS, jQuery, graphics creation with Photoshop, Illustrator, (Adobe Creative Suite), multimedia creation with Flash.</li>\r\n<li>Good knowledge of PHP programming language is a plus.</li>\r\n<li>Have the ability to organize and manage multiple priorities</li>\r\n<li>Ability to solve problems creatively and effectively.</li>\r\n<li>Up-to-date with the latest UI trends, techniques, and technologies.</li>\r\n</ul>',
#   6),
#  ('<ul>\r\n<li>C# , ASP .Net</li>\r\n<li>Min 3 years Experience</li>\r\n<li>Prefered ERP/HRMS Modules Development&nbsp;Experience</li>\r\n<li>At least 3 years of experience in HRMS system design and development.</li>\r\n<li>Good command in speaking and writing English language.</li>\r\n</ul>',
#   6),
#  ('<ul>\r\n<li>Art Major&nbsp;</li>\r\n<li>perfect English</li>\r\n<li>Previous experience in teaching Art to children&nbsp;</li>\r\n<li>Creative</li>\r\n<li>multitasker</li>\r\n<li>organized</li>\r\n</ul>',
#   6),
#  ('<ul>\r\n<li>Bachelor degree in any field</li>\r\n<li>0-1 year of experience</li>\r\n<li>Upper Intermediate English level</li>\r\n<li>Intermediate level of Computer knowledge</li>\r\n<li>Good business writing skills</li>\r\n</ul>',
#   6),
#  ('<strong>Qualifications:</strong> <br />\r\n<ul>\r\n<li>Bachelor degree of Business Administration or a related field.</li>\r\n<li>0-2 years of experience in Customer Service/Servicing industry.</li>\r\n<li>Excellent Microsoft Office skills.</li>\r\n<li>Excellent command of English language.</li>\r\n<li>Punctual, organized &amp; accurate.</li>\r\n<li>Team player</li>\r\n</ul>',
#   6),
#  ('<strong>Sales With&nbsp;at least two years of experience in agencies and marketing field and we prefer:</strong><br />\r\n<ul>\r\n<li>Education Stage :Bachelor degree</li>\r\n<li>Owns a Car</li>\r\n<li>Very good in English language listening and speaking</li>\r\n<li>Presentable</li>\r\n</ul>',
#   6),
#  ('<ul>\r\n<li>Bachelor degree in Pharmaceutical Sciences</li>\r\n<li>0-3 years of experience</li>\r\n</ul>',
#   6),
#  ('<ul>\r\n<li>Very Good command of English Language</li>\r\n</ul>', 6),
#  ('<ul>\r\n<li>Solid experience in tele marketing, social media &amp; branding</li>\r\n<li>Strong business acumen and creative mindset</li>\r\n<li>Developing marketing plans and corporate branding</li>\r\n</ul>',
#   6),
#  ('<strong>Requirements:</strong><br /><br />\r\n<ul>\r\n<li>Fluent or very good English skills.</li>\r\n<li>Able to work under pressure.</li>\r\n<li>High communication and negotiation skills.</li>\r\n<li>Maxium age is 33.</li>\r\n<li>Fresh graduates are welcome to apply.</li>\r\n<li>No Nationality restriction.</li>\r\n</ul>',
#   6),
#  ('<ul>\r\n<li>Linux/UNIX: Good knowledge.</li>\r\n<li>Apache HTTP/J2EE Application Server knowledge</li>\r\n<li>Good knowledge of administrating, configuration and troubleshooting of apache and tomcat web servers.</li>\r\n<li>Excellent English Language&nbsp;</li>\r\n<li>Excellent communication skills</li>\r\n</ul>\r\n<p>&nbsp; &nbsp; &nbsp;</p>',
#   6),
#  ('<ul>\r\n<li>Bachelor&rsquo;s degree in English language; a postgraduate degree is an asset.</li>\r\n<li>At least 2 years of relevant experience.</li>\r\n<li>Excellent command of English and Arabic languages; excellent knowledge of their structure, content, grammar, and rules of composition.</li>\r\n<li>Very good computer skills, preferably with technical background.</li>\r\n<li>Excellent communication skills.</li>\r\n<li>Attention to detail.</li>\r\n<li>Creativity in writing.</li>\r\n<li>Negotiation skills are a plus.</li>\r\n</ul>\r\n<br /><strong>Please send a sample of your work to&nbsp;sara.abdelkarim@chestnut.com</strong>',
#   6),
#  ('<ul>\r\n<li>Strong analytical and problem-solving skills.</li>\r\n<li>Applicant must be able to multi-task as we have multiple projects under development</li>\r\n<li>Ability to work under pressure with changing priorities and tight deadlines.</li>\r\n<li>Highly motivated and creative individual.</li>\r\n<li>Excellent communication skills, both written and oral.</li>\r\n</ul>',
#   6),
#  ('<ul>\r\n<li>Must be Fluent in English Language .</li>\r\n<li>Offshore call center experience is a good plus.</li>\r\n<li>Must be graduate.</li>\r\n<li>Able to Work Immediately (notice Period 1 week).</li>\r\n<li>Able to work on shift basis &ldquo;Maximum working hour for girls is 2:00 AM and a door to door transportation is provided&rdquo;.</li>\r\n<li>Exemption from Military service &ldquo;For boys&rdquo;</li>\r\n</ul>',
#   6),
#  ('<ul>\r\n<li><span style="font-size: 12px;">Worked in raw materials testing laboratory at any paint producing company will be an advantage.</span></li>\r\n<li><span style="font-size: 12px;">Have a reasonable knowledge about paints raw materials.</span></li>\r\n<li><span style="font-size: 12px;">Fluent English.</span></li>\r\n<li><span style="font-size: 12px;">Driving license is a must.</span></li>\r\n<li><span style="font-size: 12px;">Computer knowledge specially Microsoft word, excel, and power point.</span></li>\r\n<li><span style="font-size: 12px;">Motivated, works under pressure, result oriented.</span></li>\r\n</ul>',
#   6),
#  ('<ul>\r\n<li>Job Requirements:bachelor of business administration or a relevant study.</li>\r\n<li>0-1 year of experience in a customer service environment.</li>\r\n<li>Excellence in Microsoft office tools.&nbsp;</li>\r\n<li>Excellent communication and negotiation skills.</li>\r\n<li>Able to remain interested and focused when repeating information.</li>\r\n</ul>',
#   6),
#  ('<ul>\r\n<li>Very Good verbal and written communication skills.</li>\r\n<li>Very Good listening skills.</li>\r\n<li>Very Good problem analysis and problem solving.</li>\r\n<li>Customer service orientated.</li>\r\n<li>Can Work on shift basis.</li>\r\n<li>Very Good organizational skills.</li>\r\n<li>Attention to details.</li>\r\n<li>Judgment.</li>\r\n<li>Very Good computer skills.</li>\r\n<li>Excellent English Language.</li>\r\n<li>0 &ndash; 2 Years&rsquo; Experience.</li>\r\n</ul>',
#   6),
#  ('<ul>\r\n<li><strong>Fluency in Italian. </strong></li>\r\n<li>Flexible with rotational shifts.</li>\r\n<li>Skill in providing an exceptional customer experience.</li>\r\n<li>Skill in verbal and written communication to analyze, interpret and address customer needs.</li>\r\n<li>Knowledge of a Windows O/S (98, 2000, XP and ME) and Internet; Basic PC knowledge preferred.</li>\r\n<li>Ability to work in a time critical environment.</li>\r\n<li>Ability to navigate a computerized data entry system or other relevant systems</li>\r\n<li>Ability to be flexible and quickly adapt to changing business needs and processes.</li>\r\n<li>Ability and willingness to provide pre-sales support. Ability to promote and sell products or services.</li>\r\n<li>Able to speak with customers in a calm, enthusiastic and friendly tone of voice.</li>\r\n</ul>',
#   6),
#  ('<ul>\r\n<li>Very Good Command of English</li>\r\n<li>Graduates Only - NO Undergraduates</li>\r\n<li>Age max 32</li>\r\n<li>Good Typing - (PC Usage)</li>\r\n</ul>',
#   6),
#  ('<ul>\r\n<li>Bachelor Degree in Engineering (Preferably Electronics), Science or Pharmacy.</li>\r\n<li>1-2 Years of experience in <strong>Outdoor</strong>&nbsp;<strong>Sales.</strong></li>\r\n<li>Excellent command in spoken and written English.</li>\r\n<li>The Ability to learn Technical data and Medical terms easily.</li>\r\n<li>Formal Dress Code.</li>\r\n</ul>',
#   6),
#  ('<ul>\r\n<li>Good Knowledge of Python programming language</li>\r\n<li>Knowledge of Python frameworks is a plus (Django, Web2Py, OpenERP)</li>\r\n<li>Knowledge of HTML/Javascript/css</li>\r\n<li>Knowledge of Linux OS is a plus</li>\r\n<li>Self learner</li>\r\n<li>Self motivated</li>\r\n</ul>',
#   5),
#  ('<ul>\r\n<li>Good planning &amp; analytical skills, problem-solving</li>\r\n<li>Proactive with strong interpersonal communication skill</li>\r\n<li>Excellent in written &amp; spoken in English</li>\r\n<li>Positive\xef\xbc\x8cwilling to work hard, results-oriented</li>\r\n</ul>',
#   5),
#  ('<ul>\r\n<li>Minimum Four years&rsquo; experience.</li>\r\n<li>Preferably Communication skills Course and SQL Server 2005 Database Administrator certified.</li>\r\n<li>Strong English commands and language skills.</li>\r\n<li>Strong knowledge of current technologies and Microsoft SQL technologies.</li>\r\n<li>An excellent communicator, self-starter and tenacious.</li>\r\n<li>Candidates must be disciplined and well organized.</li>\r\n<li>A good understanding of product business know how would be an advantage although full training will be provided.</li>\r\n<li>Flexible and adaptable approach to customer needs is a good trait for a senior consultant.</li>\r\n<li>Be able to work under pressure and multi-task, the ability to priorities ensuring that all tasks are completed to the relevant business processes.</li>\r\n<li>Educated to a degree level in a computer related system, with a demonstrated strong computer background, networks and technical ability.</li>\r\n<li>Strong Knowledge in Microsoft Products.</li>\r\n<li>Extensive application and database engine up to date knowledge&rsquo;s.</li>\r\n<li>Understanding of customer service philosophies.</li>\r\n</ul>',
#   5),
#  ('<ul>\r\n<li>To be successful, candidates should have an excellent academic record.</li>\r\n<li>You will also have proven practical experience of working with C++, and specifically, strong knowledge of computer graphics and algorithms.</li>\r\n<li>Additionally, knowledge of parallel/concurrent programming techniques, x86 assembly language and GPU programming (using a shader language or CUDA, for example) is desirable, but not essential.</li>\r\n<li>Previous knowledge of medical imaging would also be advantageous.</li>\r\n<li>You will be a strong communicator, able to thrive working within a dynamic, innovative team developing industry-leading 3D medical imaging technology and applications.</li>\r\n<li>You will be involved in all aspects of the product development lifecycle from requirements capture through to product release and support.</li>\r\n<li>The work is fast paced and intellectually stimulating. If you enjoy a team-oriented, self-directed, flexible work environment, this position may be for you.</li>\r\n<li>BS or advanced degree in Computer Science, Biomedical Engineering or equivalent subject matter</li>\r\n<li>Experience in any are of Medical Imaging Research including Image Processing, Computer Graphics, Visualization.</li>\r\n<li>Solid programming experience with in C++.</li>\r\n<li>Strong in trouble-shooting skills, and capable of reviewing source code and developing functional unit tests against it</li>\r\n<li>Knowledge of GPU programming (using a shader language or CUDA, for example), 3D visualization is desirable, but not essential.</li>\r\n<li>Must be detail oriented, organized and able to multi-task</li>\r\n<li>Have a passion for software quality and is a champion for the end user</li>\r\n<li>Very strong communication skills and a collaborative approach</li>\r\n</ul>',
#   5),
#  ("<strong>Skills and Experience </strong><br />\r\n<ul>\r\n<li>Technically savvy and have a deep technical understanding of all video production aspects</li>\r\n<li>Minimum 1 year AVID editing experience, including knowledge of multi-cam synching, media compression, sound mixing, and color correction</li>\r\n<li>Bachelor's degree preferred or equivalent experience in multi media</li>\r\n<li>Solid knowledge of Final Cut Pro, Adobe Premiere, Adobe After Effects, Adobe Photoshop is a must</li>\r\n<li>Familiarity with special effects, 3D</li>\r\n<li>Strong familiarity with and use of digital content environments/ services such as YouTube, Vimeo, Sound cloud, Vine, and others</li>\r\n<li>Have an eye for framing, lighting and understanding of camera, lighting and audio equipment</li>\r\n<li>Creative mind and storytelling skills</li>\r\n<li>Proficiency in ENGLISH is a mus<strong>t</strong></li>\r\n</ul>",
#   5),
#  ('<p><strong>Education:</strong></p>\r\n<ul>\r\n<li>Bachelor degree in Pharmaceutical sciences or equivalent.</li>\r\n</ul>\r\n<p><strong>Professional Skills:</strong></p>\r\n<ul>\r\n<li>Good coaching skills and ability to work in team environment.</li>\r\n</ul>\r\n<p><strong>Past Experience:</strong></p>\r\n<ul>\r\n<li>One to 3 years experience.</li>\r\n</ul>\r\n<p><strong>Special Competencies:</strong></p>\r\n<ul>\r\n<li>Good command of English.</li>\r\n<li>Assessing &amp; improving staff productivity.</li>\r\n<li>Controlling losses in processing steps to decrease yield variances.</li>\r\n</ul>',
#   5),
#  ('<ul>\r\n<li>&nbsp;Langue maternelle Fran&ccedil;aise.</li>\r\n<li>Dipl&ocirc;m&eacute;s universitaires.</li>\r\n<li>Exempt&eacute; ou ajourn&eacute; du service militaire (m&acirc;les)</li>\r\n</ul>\r\n<ul>\r\n<li>Speaks French as a first language</li>\r\n<li>University Graduates</li>\r\n<li>Exemption or postponement from the military. (males)</li>\r\n</ul>',
#   5),
#  ('<ul>\r\n<li>To be a creative thinker and generate ideas outside the box</li>\r\n<li>An analytical thinker (Able to understand numbers and data analysis)</li>\r\n<li>Has excellent written and communication skills in both Arabic and English</li>\r\n<li>Understands how to relationship build and negotiate</li>\r\n</ul>',
#   5),
#  ('<ul>\r\n<li>Fluent English</li>\r\n</ul>', 5),
#  ('<strong>Qualifications</strong><br />\r\n<ul>\r\n<li>Excellence with Photoshop, Illustrator and In-Design is a must.</li>\r\n<li>Knowledge of 3D Max and Cinema 4D is preferable.</li>\r\n<li>Excellent communication skills.</li>\r\n<li>Hard-worker, committed, and team-player.</li>\r\n<li>Creativity is a must.</li>\r\n<li>Thinking out-of-the-box, and can prove it with previous work.</li>\r\n<li>Doesn&rsquo;t mind traveling around Egypt or overseas on special occasions.</li>\r\n<li>Previous experience is preferable, but not a must.</li>\r\n<li>Have an excellent command of Arabic and English, especially written languages</li>\r\n</ul>',
#   5),
#  ('<ul>\r\n<li>B.Sc. in Computer Science or equivalent</li>\r\n<li>+3 years of related experience</li>\r\n<li>Good command of both written and spoken English</li>\r\n<li>Excellent knowledge of web development</li>\r\n<li>Excellent knowledge of DB concepts and tools (MS SQL Server is a must)</li>\r\n<li>Excellent knowledge of Dot Net (ASP.NET, MVC, C#)</li>\r\n<li>Excellent knowledge of OOP (Concepts, Techniques, Principles and analysis and design)</li>\r\n<li>Excellent knowledge of design patterns</li>\r\n<li>Good knowledge of ORM</li>\r\n<li>Fair knowledge of AOP and SOA</li>\r\n</ul>',
#   5),
#  ('<ul>\r\n<li>B.Sc. degree in Pharmacy</li>\r\n<li>Data Analysis, Knowledge in Pharmaceutical Processes, Knowledge in Research&nbsp;</li>\r\n<li>Methodologies, Analytical Thinking.</li>\r\n</ul>',
#   5),
#  ('<ul>\r\n<li>BSc, Engineering: communication, Mechanics, Mechatronics Or Bsc Science</li>\r\n<li>V.good presentation skills, high self confidence, Excellent English</li>\r\n</ul>',
#   5),
#  ('<strong>Educational Requirements</strong><br />\r\n<ul>\r\n<li>Minimum high Graduation but relaxed for highly experienced persons.</li>\r\n<li>Must have good English writing and reading skills.</li>\r\n</ul>\r\n<p><strong>Experience Requirements</strong></p>\r\n<ul>\r\n<li>2 to 5 year(s).</li>\r\n<li>The applicants should have experience in the following area(s): &nbsp;Web Developer/Web Designer, Graphic Designer</li>\r\n</ul>',
#   5),
#  ('<ul>\r\n<li>Bachelor Degree.</li>\r\n<li>Customer Service experience is a must.</li>\r\n<li>Good verbal Communication skills.</li>\r\n<li>Good Listening skills</li>\r\n<li>Must be computer literate.</li>\r\n<li>Good English Skills.</li>\r\n</ul>',
#   5),
# ...
#   2),
#  ('<strong>Position Requirements / Selection Factors:</strong><br /><br />\r\n<ul>\r\n<li>Excellent Organizational &amp; Follow-up skills</li>\r\n<li>Excellent Oral Communication Skills</li>\r\n<li>Experience with MS Windows</li>\r\n<li>Excellent Written Communication Skills</li>\r\n<li>Telephone Selling Skills (preferred)</li>\r\n<li>Analytical</li>\r\n<li>Team Player</li>\r\n<li>Scheduling Flexibility</li>\r\n<li>Dependable</li>\r\n</ul>',
#   2),
#  ('<ul>\r\n<li>A Bachelor Degree in Electrical Power Engineering or an equivalent field</li>\r\n<li>A minimum of 2 years experience in sales</li>\r\n</ul>',
#   2),
#  ('<ul>\r\n<li>B.sc of Computer science or equivalent</li>\r\n<li>3-6 years of experience at the same position</li>\r\n<li>Fluency in English Language</li>\r\n</ul>',
#   2),
#  ('<ul>\r\n<li>Android developer with experience of 2+ years.</li>\r\n<li>Be able to design and develop Android application (cross platform / testing is a plus).</li>\r\n<li>Be aware of design principles and design patterns.</li>\r\n<li>Be able to write well-designed and clean code.</li>\r\n<li>Have a good understanding of what a web service is and how to integrate with it.</li>\r\n<li>Be able to write multithreaded code.</li>\r\n<li>Write detailed technical specifications for subsystems and identify integration points.</li>\r\n<li>Estimate project timelines and resources required to complete programming projects.</li>\r\n<li>Perform unit testing and debugging and set test conditions based on code specifications.</li>\r\n<li>Able to work with web services</li>\r\n<li>IOS basics is a plus</li>\r\n</ul>',
#   2),
#  ('<ul>\r\n<li>Bachelor&rsquo;s degree in English language; a postgraduate degree is an asset.</li>\r\n<li>At least 2 years of relevant experience.</li>\r\n<li>Excellent command of English and Arabic languages; excellent knowledge of their structure, content, grammar, and rules of composition.</li>\r\n<li>Very good computer skills, preferably with technical background.</li>\r\n<li>Excellent communication skills.</li>\r\n<li>Attention to detail.</li>\r\n<li>Creativity in writing.</li>\r\n<li>Negotiation skills are a plus.</li>\r\n</ul>\r\n<br /><strong>Please send a sample of your work to hind.rustom@chestnut.com</strong>',
#   2),
#  ('<ul>\r\n<li>Bachelor&rsquo;s degree in any field (Art related is preferable)</li>\r\n<li>Minimum 3 years of related experience</li>\r\n<li>Strong sense of aesthetics and design elements such as: color, balance and typography</li>\r\n<li>Good communication skills, strong attention to details, teamwork, time management, multi-tasking, and creativity</li>\r\n<li>Advanced skills in scripting languages: CSS, HTML, and JavaScript (CSS3 and HTML5 are preferable) and strong knowledge of the .Net framework applications and Web 2.0.</li>\r\n</ul>',
#   2),
#  ('<ul>\r\n<li>Photoshop</li>\r\n<li>Illustrator</li>\r\n<li>Web Design Experience.</li>\r\n</ul>\r\n<br />\r\n<p><strong>Nice to have:</strong></p>\r\n<ul>\r\n<li>HTML5</li>\r\n<li>CSS3</li>\r\n<li>Slicing using sprites</li>\r\n</ul>',
#   2),
#  ('<strong>The required candidate must hold</strong> <br /><br />\r\n<ul>\r\n<li>Bsc. Civil engineering from a reputable university.</li>\r\n</ul>\r\n<br /><strong>With the capability of designing using the following programs:</strong><br /><br />\r\n<ul>\r\n<li>SAB</li>\r\n<li>ETABS</li>\r\n<li>Safe CSI</li>\r\n<li>Shop drawing.</li>\r\n<li>Civil Cad 3d (optional)</li>\r\n</ul>\r\n<br /><br /><strong>Work Conditions:</strong><br /><br />\r\n<ul>\r\n<li>Working Hours: 9:00 AM &ndash; 5:00 PM</li>\r\n<li>Day Off Friday</li>\r\n<li>Work Location: Sheraton Heliopolis</li>\r\n</ul>',
#   2),
#  ('<ul>\r\n<li>Minimum Years of Experience: 3&ndash; 7 Years</li>\r\n</ul>',
#   2),
#  ('<ul>\r\n<li>3+ years of .Net development experience.</li>\r\n<li>Strong experience in MVC with the .NET platform.</li>\r\n<li>Strong programming experience with C#, WCF, Restful services using Web API.</li>\r\n<li>Expert in reviewing, troubleshooting, designing and developing web services using Web API, WCF.</li>\r\n<li>Experience in Entity Framework, MVC and MS SQL Server.</li>\r\n<li>Experience in ORM tools and SOA is desired.</li>\r\n<li>Good verbal and written communication skills.</li>\r\n</ul>',
#   2),
#  ('<ul>\r\n<li>Fluency in Italianis a must.</li>\r\n<li>Skill in providing an exceptional customer experience.&nbsp;</li>\r\n<li>Skill in verbal and written communication to analyze, interpret and address customer needs.&nbsp;</li>\r\n<li>Knowledge of a Windows O/S (98, 2000, XP and ME) and Internet; Basic PC knowledge preferred.&nbsp;</li>\r\n<li>Ability to work in a time critical environment.&nbsp;</li>\r\n<li>Ability to navigate a computerized data entry system or other relevant systems&nbsp;</li>\r\n<li>Ability to be flexible and quickly adapt to changing business needs and processes.&nbsp;</li>\r\n<li>Ability and willingness to provide pre-sales support.&nbsp;</li>\r\n<li>Ability to promote and sell products or services</li>\r\n<li>Able to speak with customers in a calm, enthusiastic and friendly tone of voice.</li>\r\n</ul>',
#   2),
#  ('<ul>\r\n<li>Fluent in writing English and Arabic.</li>\r\n</ul>', 2),
#  ('<ul>\r\n<li>B.Sc. Degree from an accredited University.</li>\r\n<li>4-5 years experience in similar role.</li>\r\n<li>ExcellentEnglish.</li>\r\n</ul>',
#   2),
#  ('<ul>\r\n<li>Engineering Bachelor degree,&nbsp; Mechanical or Civil</li>\r\n<li>Good command of English and communications skills</li>\r\n<li>Active Listening, Time Management, Analytical thinking, Organizational and Interpersonal</li>\r\n<li>Preferred car owners</li>\r\n</ul>',
#   2),
#  ('<ul>\r\n<li>Extensive knowledge of all aspects of professional services from schematic design through project close-out, including design and technical expertise.</li>\r\n<li>A comprehensive understanding of the coordination aspects and related requirements of all design disciplines.</li>\r\n<li>Good written and verbal communication skills, and strong organizational skills.</li>\r\n<li>Possess the ability to motivate and mentor staff, and delegate work assignments.</li>\r\n<li>Computer literate, with experience in Revit (essential).</li>\r\n<li>Very detail-oriented, self-motivated, enthusiastic and flexible.</li>\r\n<li>Ability to work well with others under deadline situations.</li>\r\n</ul>',
#   2),
#  ('<ul>\r\n<li>Should have Minimum 3 years experience in Java/J2EE, XML, XSL and Web services.</li>\r\n<li>Should have experience in developing ADF/SOA/BPM applications using JDeveloper 11g.</li>\r\n<li>Good understanding of JSF architecture.</li>\r\n<li>Experience in SQL and PL/SQL using Oracle Database 11g</li>\r\n<li>Should have Experience in deploying ADF applications to Oracle Weblogic Server 11g.</li>\r\n<li>Experience in developing and deploying composite applications using Oracle SOA Suite 11g</li>\r\n<li>Experience in developing and deploying BPEL(Business Process Execution Language) processes using Oracle SOA Suite 11g</li>\r\n<li>Knowledge of Oracle Forms is an added advantage.</li>\r\n<li>Knowledge of Oracle BI Publisher is an added advantage.</li>\r\n</ul>',
#   2),
#  ('<ul>\r\n<li>Females Only</li>\r\n<li>0-1 years of experience</li>\r\n</ul>',
#   2),
#  ('<ul>\r\n<li>Confident and friendly telephone manner</li>\r\n<li>Accurate data inputting skills</li>\r\n<li>Excellent time management skills</li>\r\n<li>Tenacious approach</li>\r\n<li>Self-motivated attitude</li>\r\n<li>Excellent verbal and written communication skills</li>\r\n<li>PC skills using MS Office</li>\r\n<li>Confident and professional</li>\r\n</ul>',
#   2),
#  ('<br />\r\n<ul>\r\n<li>Min. 1 year work experience in telesales .</li>\r\n<li>Basic skills in relevant computer applications.</li>\r\n<li>Females Only .</li>\r\n</ul>\r\n<p>&nbsp;</p>',
#   2),
#  ('<ul>\r\n<li>Passion for engaging with customers and fans through different online channels</li>\r\n<li>A good understanding of online community moderation and social media management</li>\r\n<li>Ability to communicate professionally and creatively in Arabic and English writing</li>\r\n</ul>',
#   2),
#  ('<ul>\r\n<li>Bachelor of Business Administration and equivalent, or/with a degree in Economics preferably advanced.</li>\r\n<li>He/she has basic knowledge on economic statistics</li>\r\n<li>Must be detail-oriented</li>\r\n<li>Along with analytical and math skills, communication skills (interpersonal, verbal, written), and Microsoft office skills.</li>\r\n</ul>',
#   2),
#  ('<ul>\r\n<li>Fresh graduates.</li>\r\n<li>Ability to analyze news articles,</li>\r\n<li>Proficient in MS Office suite,</li>\r\n<li>Excellent organizational and communication skills,</li>\r\n<li>Excellent command of English and Arabic,</li>\r\n<li>Superior translation skills ,</li>\r\n<li>Good research skills.</li>\r\n</ul>',
#   2),
#  ('<ul>\r\n<li>Bachelor Degree in any field</li>\r\n<li>5-6 years of relevant experience</li>\r\n<li>Upper Intermediate English level</li>\r\n<li>MCSE or MCSA certificate is a must</li>\r\n<li>Advanced level of Windows OS, Network Services, hard desk&nbsp;management tools Anti-Spyware Microsoft Office, Network&nbsp;Management Software, Remote Control Software, LAN &ndash; IM,&nbsp;Ethernet cabling and cabling equipment</li>\r\n</ul>',
#   2),
#  ('<strong>To be considered for the job we require that you have:</strong>\r\n<ul>\r\n<li>A stunning portfolio of ads across all media with killer lines</li>\r\n<li>Also, to be an expert in BTL where long copy should come easy to you.</li>\r\n<li>Minimum of 2 years experience working in an international advertising agencies.</li>\r\n<li>A proven track record of delivering great creative concepts.</li>\r\n<li>Excellent spoken and written Arabic</li>\r\n<li>Excellent spoken English - written English is a plus.&nbsp;</li>\r\n</ul>\r\n<p><br /><strong>To apply, please send your &nbsp;portfolio to work@mediarepublic-eg.com with the subject Creative Copywriter and briefly explain why this is the job for you.&nbsp;</strong></p>',
#   2),
#  ('<ul>\r\n<li>Bachelor of Engineering /equivalent.</li>\r\n<li>Very Good English</li>\r\n<li>Very good computer skills</li>\r\n</ul>',
#   2),
#  ('<ul>\r\n<li>Fluent written and spoken English.</li>\r\n<li>Bachelor Degree, Preferably in business administration.</li>\r\n<li>A minimum of 2 years experience in Marketing &amp; 1 year experience in E-Marketing.</li>\r\n<li>Excellent communication and negotiation skills.</li>\r\n</ul>',
#   2),
#  ('<ul>\r\n<li>2 years of experience</li>\r\n<li>Help desk / Technical support&nbsp;</li>\r\n<li>Good Command at English.</li>\r\n</ul>',
#   2),
#  ('<ul>\r\n<li>BSc. Of computer Science, Computer Engineering</li>\r\n<li>From 0-2 years of Experience in the Quality Control Field</li>\r\n<li>Understands testing principles, standards and process.</li>\r\n<li>Ability to work under pressure</li>\r\n<li>Delivering Results and Meeting Customer Expectations</li>\r\n<li>Adhering to Principles and Values</li>\r\n<li>Oral and written English communication skills necessary to express ideas and concepts clearly and persuasively to individuals and groups.</li>\r\n<li>ITI certificate is a plus.</li>\r\n</ul>',
#   2),
#  ('1. 3 years of strong experience in middle tier/web based application or rich client application design and development using J2EE Technologies (Servlets, JSP, JDBC and Custom Tags) or Swing/SWT under Windows or Linux.\r\n<p>2. Good knowledge of spring web applications framework, HTML and JavaScript is a must.</p>\r\n<p>3. Good knowledge of Hibernate is a must.</p>\r\n<p>4. Good knowledge of UML notion is a must.</p>\r\n<p>5. Ability to give proof of architecting, developing and deploying products from the ground up.</p>\r\n<p>6. Ability to write clear architecture documents and class diagrams.</p>\r\n<p>7. Possession of strong analytical and research skills and enjoying delivering software solutions that solve real world problems.</p>\r\n<p>8. Object oriented analysis and design expertise.</p>\r\n<p>9. Strong verbal and written communication skills are mandatory to working in team environment and keeping an open communication across all channels of the organization.</p>\r\n<p>10. Ability to work under stress, with commitment to deadlines and quickly come up to speed on existing technologies and provide input on future direction of our technical environment.</p>\r\n<p>11. Familiarity with an Agile Software development process is a plus.</p>',
#   2),
#  ('<strong>iOS &ndash;</strong><br />\r\n<ul>\r\n<li>Strong OO design and programming skills in Objective-C</li>\r\n<li>Professional Experience with iOS SDK (UIKit, Cocoa Touch, Core Data, Core Location, etc)</li>\r\n<li>Professional with xcode</li>\r\n</ul>\r\n<br /><strong>Android &ndash;</strong><br />\r\n<ul>\r\n<li>Strong OO design and programming skills in Java (J2EE/ J2ME) Familiar with the Android SDK</li>\r\n<li>Knowledge of SQLite, MySQL or similar database management system</li>\r\n<li>Professional with Eclipse</li>\r\n</ul>\r\n<br /><strong>Common &ndash;</strong><br />\r\n<ul>\r\n<li>Building complex IOS / Android.</li>\r\n<li>Experience creating Provisioning Profile , Testing apps on IOS Devices and</li>\r\n<li>Uploading to App Store / Google play.</li>\r\n<li>Fundamentals in object-oriented design, data structures, &amp; algorithm design.</li>\r\n<li>Problem solving, and complexity analysis.</li>\r\n<li>Understanding of other compiled languages</li>\r\n<li>Experience on web service integration (SOAP, REST, JSON, XML) Experience of development using web technologies</li>\r\n<li>Good understanding of OO programming and design patterns</li>\r\n<li>Good understanding of HTML5, JavaScript, jQuery, Ajax and PHP Experience building web and native apps is a plus.</li>\r\n<li>Excellent debugging and optimization skills.</li>\r\n</ul>',
#   2),
#  ('<strong>Education</strong>: Bachelor&rsquo;s Degree of computer science, IT<br /><strong>Experience</strong>: 0 - 2 Years of experience in a similar position.<br /><strong>Languages</strong>: Very Good command of English language (Speaking, reading and writing).<br /><br /><strong>Job Requirement:</strong><br />\r\n<ul>\r\n<li>Strong awareness of Software lifecycle</li>\r\n<li>Commanding Knowledge of object oriented programming</li>\r\n<li>Working knowledge of J2EE design patterns.</li>\r\n<li>In depth knowledge with the J2EE platform development</li>\r\n<li>Knowledge of CASE tools (Rational Rose, Power Designer)</li>\r\n<li>In depth knowledge of various Database Management Systems (Oracle, DB2, MSSQL)</li>\r\n<li>Hands on web development technologies (HTML, DHTML, CSS, JavaScript, )</li>\r\n<li>Knowledge of web services, XML, SOAP</li>\r\n<li>Knowledge of advanced web technologies (XML query, XSLT)</li>\r\n</ul>\r\n<br />\r\n<p><strong>Further requirements and/or Restrictions:</strong></p>\r\n<ul>\r\n<li>Presenting and Communicating Information</li>\r\n<li>Coping with Pressure and Setbacks</li>\r\n<li>Achieving Personal Work Goals and Objectives</li>\r\n<li>Working effectively with individuals and teams, clients and staff. Support others and shows respect.</li>\r\n<li>Learning and Researching</li>\r\n<li>Java certification is an advantage</li>\r\n</ul>',
#   2),
#  ...]

# %% [markdown]
# Job requierements column contains pragraph for each job .. in also, contains 2633 job application without requirements .. !

# %%
# payment_period

plt.figure(figsize=(16,16))
plt.subplot(311)
sns.countplot(x = "payment_period", data = df_job, order = df_job.payment_period.value_counts().iloc[:].index)
plt.xticks(rotation=90)
plt.ylabel('Count', fontsize=12)
plt.xlabel('payment_period', fontsize=12)
plt.title("Frequency of Payment Period Count in Members Data Set", fontsize=12)
# Out:
# Text(0.5,1,u'Frequency of Payment Period Count in Members Data Set')

# %% [markdown]
# Almost all the jobs pay per month for their employess .. except very few jobs pay per year ! ..
#
# We can make further analysis to check the titles of those jobs ..

# %%
job_pay = Counter(df_job['payment_period']).most_common()
job_pay
# Out:
# [('Per Month', 21642),
#  ('Per Year', 123),
#  ('Per Hour', 59),
#  ('Per Day', 18),
#  (nan, 5),
#  ('Per Week', 3)]

# %% [markdown]
# OMG ! ..
#
# It seems that the chart above doesn't accurate enough to plot all the types .. may be due to the gap between the highest
# payment peiod and the rest ..
#
# Yet, the majority take their salaries per month and only three applications' salaries are per week ..
#
# 5 rows are empty with NAs values ..

# %%
#currency

plt.figure(figsize=(16,16))
plt.subplot(311)
sns.countplot(x = "currency", data = df_job, order = df_job.currency.value_counts().iloc[:].index)
plt.xticks(rotation=90)
plt.ylabel('Count', fontsize=12)
plt.xlabel('currency', fontsize=12)
plt.title("Frequency of Currency Count in Members Data Set", fontsize=12)
# Out:
# Text(0.5,1,u'Frequency of Currency Count in Members Data Set')

# %% [markdown]
# More than 20000 applications pay their salaries by EGP and only few pay by USD ..

# %%
job_pay = Counter(df_job['currency']).most_common()
job_pay
# Out:
# [('Egyptian Pound', 21476),
#  ('United States Dollar', 254),
#  ('Saudi Arabian Riyal', 67),
#  ('U.A. Emirates Dirham', 16),
#  ('Euro', 11),
#  (nan, 5),
#  ('Qatari Riyal', 5),
#  ('Canadian Dollar', 4),
#  ('Jordanian Dinar', 2),
#  ('Indian Rupee', 2),
#  ('British Pound', 2),
#  ('Kuwaiti Dinar', 1),
#  ('Ethiopian Birr', 1),
#  ('Ghanaian Cedis', 1),
#  ('Ecuadoran Sucre', 1),
#  ('Dominican Republic Pesos', 1),
#  ('East Caribbean Dollar', 1)]

# %% [markdown]
# Again .. the numerical count is more accurate as it lists the count of each corresponding currency ..
#
# Precisely 21576 applications pay using EGP, and single application pay by 'Kuwaiti Dinar' .. the same case is for 'Ethiopian Birr', 'Ghanaian Cedis', 'Ecuadoran Sucre', 'Dominican Republic Pesos' and 'East Caribbean Dollar' as well ..
#
# Also, 5 rows are empty .. each of which is corresponding to job application that are not stated its currency ..

# %% [markdown]
# In fact .. the next step is to do bivariate analysis ..
#
# however, I'm gonna perform data cleaning step prior to the bivariate .. so that the bivariate analysis is performed on a cleaned version for all the columns ..
#
#
# ## Data Cleaning:
#
# So far, as mentioned above .. some columns contains NAs and some others contains typo (invalid cell value) ..
#
# ### Filling NAs ..
# Let's clean them up starting with the four variables contain NAs (i.e. job_description, job_requirements, payment_period and currency)

# %%
# job_description 

job_desc = Counter(df_job['job_description']).most_common()
job_desc
# Out:
# [(nan, 274),
#  ('<ul>\r\n<li>Responsible for taking inbound calls for prospective customers, handling customer inquiries in a courteous and professional manner while providing the highest level of customer service.</li>\r\n<li>Provide responsive and competent telephone support to customers in the areas of problem solving and handling customer inquiries.</li>\r\n<li>Typically would not have sales goals/quotas.</li>\r\n<li>Apply basic working knowledge of systems, procedures, customers, products and processes to perform assigned functions with moderate reliance on others for direction.</li>\r\n<li>Work requires some judgment but is performed primarily according to standard procedures with close supervision</li>\r\n<li>Provide responsive and competent customer support within a call center environment.</li>\r\n<li>Ensure that all customer issues are resolved at the first instance.</li>\r\n<li>May respond to customer inquiries by referring them to published materials, secondary sources or more senior staff.</li>\r\n<li>Continuously work for exceptional customer experience, resulting in high customer satisfaction scores.</li>\r\n<li>Deliver and exceed customer-specified service levels for handle time.</li>\r\n<li>Learn, understand, retain and regularly update and demonstrate product/process knowledge.</li>\r\n<li>Track, document and retrieve information in call tracking database</li>\r\n</ul>',
#   30),
#  ('<strong>Benefits:</strong><br />\r\n<ul>\r\n<li>Highly attractive salaries based on your English.</li>\r\n<li>High Commission .</li>\r\n<li>Transportation (Door to Door) at night for females, and for males to the nearest point.</li>\r\n<li>Full paid training</li>\r\n<li>2 days off</li>\r\n<li>Social and Medical insurance provided</li>\r\n</ul>',
#   25),
#  ('Are you a talented, dynamic sales professional with a proven track record of success? Want to be part of an elite sales force that respects your talent and hard work? Want to get in on the ground floor of the next big thing?\r\n<p>Join Vezeeta as a Sales Executive and help take a high-growth company to the next level. You&rsquo;ll work daily in local territories to both prospect and grow your own sales pipeline. If you are driven, aggressive, outgoing, and confident, then this may be the perfect job for you!<br /><br /><strong>What you&rsquo;ll do:</strong></p>\r\n<ul>\r\n<li>Plan an approach to your sales territory</li>\r\n<li>Make in-person visits with healthcare providers to discuss how Vezeeta can help their practices grow</li>\r\n<li>Keep an eye out for process improvement. How can you make the machine run better?</li>\r\n<li>Implement a closing business strategy</li>\r\n</ul>',
#   18),
#  ('<ul>\r\n<li>Getting customer interest on our service / product.</li>\r\n<li>Achieve high transferring and closing percentage.</li>\r\n<li>Collect &amp; document customer basic information.</li>\r\n<li>Maintaining hard work and positive attitude.</li>\r\n<li>Report the customer information in the correct system</li>\r\n<li>Giving clear information about our product / service to the customer.</li>\r\n<li>Identify &amp; escalate priority issues.</li>\r\n<li>Follow-up with customers when necessary.</li>\r\n<li>Be prompt for work and back from breaks.</li>\r\n<li>Follow the appropriate guidelines and procedures for any given situations.</li>\r\n<li>Perform any other duties assigned to him/her by the contact center management.</li>\r\n<li>Meet the due dates in the tasks assigned to him by the contact center management.</li>\r\n<li>Enter coding and tracking information completely and accurately on relevant system.</li>\r\n</ul>',
#   18),
#  ('<strong>\xd8\xa7\xd9\x84\xd9\x85\xd9\x87\xd8\xa7\xd9\x85 \xd9\x88\xd8\xa7\xd9\x84\xd9\x85\xd8\xb3\xd8\xa6\xd9\x88\xd9\x84\xd9\x8a\xd8\xa7\xd8\xaa \xd9\x88\xd8\xa7\xd9\x84\xd8\xb5\xd9\x84\xd8\xa7\xd8\xad\xd9\x8a\xd8\xa7\xd8\xaa</strong><br />\r\n<ul>\r\n<li>&nbsp;\xd8\xb9\xd9\x85\xd9\x84 \xd8\xaf\xd8\xb1\xd8\xa7\xd8\xb3\xd9\x87 \xd9\x88\xd8\xaa\xd8\xad\xd9\x84\xd9\x8a\xd9\x84 \xd9\x84\xd8\xb3\xd9\x88\xd9\x82 \xd8\xa7\xd9\x84\xd9\x85\xd9\x86\xd8\xb7\xd9\x82\xd9\x87 \xd8\xa7\xd9\x84\xd9\x85\xd9\x83\xd9\x84\xd9\x81 \xd8\xa8\xd9\x87\xd8\xa7 \xd9\x85\xd9\x86 \xd8\xae\xd9\x84\xd8\xa7\xd9\x84 \xd8\xa7\xd9\x84\xd9\x85\xd8\xb3\xd8\xad \xd8\xa7\xd9\x84\xd9\x85\xd9\x8a\xd8\xaf\xd8\xa7\xd9\x86\xd9\x89 \xd9\x84\xd9\x84\xd9\x85\xd9\x86\xd8\xb7\xd9\x82\xd9\x87 \xd9\x88\xd8\xaa\xd8\xad\xd8\xaf\xd9\x8a\xd8\xaf</li>\r\n<li>\xd9\x88\xd8\xb6\xd8\xb9 \xd8\xa7\xd9\x84\xd9\x85\xd9\x86\xd8\xa7\xd9\x81\xd8\xb3\xd9\x87 \xd8\xa8\xd8\xa7\xd9\x84\xd8\xb3\xd9\x88\xd9\x82 (\xd9\x85\xd9\x86\xd8\xaa\xd8\xac\xd8\xa7\xd8\xaa &ndash;\xd8\xb9\xd8\xb1\xd9\x88\xd8\xb6-\xd8\xb3\xd9\x8a\xd8\xa7\xd8\xb3\xd8\xa7\xd8\xaa \xd8\xb3\xd8\xb9\xd8\xb1\xd9\x8a\xd9\x87</li>\r\n<li>\xd8\xaa\xd8\xad\xd8\xaf\xd9\x8a\xd8\xaf \xd9\x86\xd9\x82\xd8\xa7\xd8\xb7 \xd8\xa7\xd9\x84\xd9\x82\xd9\x88\xd9\x87 \xd9\x88\xd8\xa7\xd9\x84\xd8\xb6\xd8\xb9\xd9\x81 \xd9\x84\xd9\x84\xd8\xb4\xd8\xb1\xd9\x83\xd8\xa7\xd8\xaa \xd8\xa7\xd9\x84\xd9\x85\xd9\x86\xd8\xa7\xd9\x81\xd8\xb3\xd9\x87</li>\r\n<li>\xd8\xaa\xd8\xad\xd8\xaf\xd9\x8a\xd8\xaf \xd8\xa7\xd8\xad\xd8\xaa\xd9\x8a\xd8\xa7\xd8\xac\xd8\xa7\xd8\xaa \xd8\xa7\xd9\x84\xd8\xb9\xd9\x85\xd9\x84\xd8\xa7\xd8\xa1.</li>\r\n<li>\xd8\xa7\xd8\xb3\xd8\xaa\xd9\x87\xd8\xaf\xd8\xa7\xd9\x81 \xd9\x82\xd8\xa7\xd8\xb9\xd8\xaf\xd9\x87 \xd9\x85\xd9\x86 \xd8\xa7\xd9\x84\xd8\xb9\xd9\x85\xd9\x84\xd8\xa7\xd8\xa1 \xd9\x88\xd8\xa7\xd9\x84\xd9\x82\xd9\x8a\xd8\xa7\xd9\x85 \xd8\xa8\xd8\xaa\xd8\xb1\xd9\x88\xd9\x8a\xd8\xac \xd9\x85\xd9\x86\xd8\xaa\xd8\xac\xd8\xa7\xd8\xaa \xd8\xa7\xd9\x84\xd8\xb4\xd8\xb1\xd9\x83\xd9\x87 \xd9\x84\xd8\xaf\xd9\x8a\xd9\x87\xd9\x85 \xd9\x88\xd8\xa7\xd9\x82\xd9\x86\xd8\xa7\xd8\xb9\xd9\x87\xd9\x85 \xd8\xa8\xd8\xa7\xd9\x84\xd8\xaa\xd8\xb9\xd8\xa7\xd9\x85\xd9\x84 \xd9\x85\xd8\xb9 \xd8\xa7\xd9\x84\xd8\xb4\xd8\xb1\xd9\x83\xd9\x87 .</li>\r\n<li>\xd9\x85\xd8\xaa\xd8\xa7\xd8\xa8\xd8\xb9\xd9\x87 \xd8\xa7\xd9\x84\xd8\xb9\xd9\x85\xd9\x84\xd8\xa7\xd8\xa1\xd9\x88\xd9\x85\xd8\xad\xd8\xa7\xd9\x88\xd9\x84\xd9\x87 \xd8\xaa\xd9\x86\xd9\x85\xd9\x8a\xd9\x87 \xd9\x85\xd8\xb3\xd8\xad\xd9\x88\xd8\xa8\xd8\xa7\xd8\xaa\xd9\x87\xd9\x85 \xd9\x85\xd9\x86 \xd8\xa7\xd9\x84\xd8\xb4\xd8\xb1\xd9\x83\xd9\x87 \xd9\x88\xd8\xa7\xd9\x84\xd8\xad\xd9\x81\xd8\xa7\xd8\xb8 \xd8\xb9\xd9\x84\xd9\x89 \xd8\xa7\xd8\xb3\xd8\xaa\xd8\xb1\xd8\xa7\xd8\xb1\xd9\x8a\xd9\x87 \xd8\xa7\xd9\x84\xd8\xaa\xd8\xb9\xd8\xa7\xd9\x85\xd9\x84 \xd9\x85\xd8\xb9 \xd8\xa7\xd9\x84\xd8\xb4\xd8\xb1\xd9\x83\xd9\x87 .</li>\r\n<li>\xd8\xa7\xd9\x84\xd8\xa7\xd9\x84\xd8\xaa\xd8\xb2\xd8\xa7\xd9\x85 \xd8\xa8\xd8\xaa\xd9\x82\xd8\xaf\xd9\x8a\xd9\x85 \xd8\xaa\xd9\x82\xd8\xa7\xd8\xb1\xd9\x8a\xd8\xb1 \xd8\xaf\xd9\x88\xd8\xb1\xd9\x8a\xd9\x87 \xd8\xb9\xd9\x86 \xd8\xb1\xd8\xaf\xd8\xb1\xd8\xaf \xd8\xa7\xd9\x81\xd8\xb9\xd8\xa7\xd9\x84 \xd8\xa7\xd9\x84\xd8\xb9\xd9\x85\xd9\x84\xd8\xa7\xd8\xa1 \xd8\xa8\xd8\xa7\xd9\x84\xd8\xb3\xd9\x88\xd9\x82 \xd8\xaa\xd8\xac\xd8\xa7\xd9\x87 \xd8\xa7\xd9\x84\xd8\xb4\xd8\xb1\xd9\x83\xd9\x87 \xd9\x85\xd9\x86 \xd8\xad\xd9\x8a\xd8\xab (\xd8\xa7\xd9\x84\xd9\x85\xd9\x86\xd8\xaa\xd8\xac\xd8\xa7\xd8\xaa &ndash;\xd8\xa7\xd9\x84\xd8\xa7\xd8\xb3\xd8\xb9\xd8\xa7\xd8\xb1-\xd8\xb3\xd9\x8a\xd8\xa7\xd8\xb3\xd8\xa7\xd8\xaa \xd8\xa7\xd9\x84\xd8\xa8\xd9\x8a\xd8\xb9 &ndash;\xd8\xae\xd8\xaf\xd9\x85\xd9\x87 \xd9\x85\xd8\xa7\xd8\xa8\xd8\xb9\xd8\xaf\xd8\xa7\xd9\x84\xd8\xa8\xd9\x8a\xd8\xb9)</li>\r\n</ul>',
#   18),
#  ('<strong>Qualifications:</strong><br /><br />\r\n<ul>\r\n<li>English fluency</li>\r\n<li>Patience and tact while talking to customers over the phone</li>\r\n<li>Excellent communication skills</li>\r\n<li>Understanding of the American culture is a PLUS</li>\r\n</ul>',
#   17),
#  ('<ul>\r\n<li>Training the end users on the services/applications</li>\r\n<li>Deploy new services/applications</li>\r\n<li>Providing onsite support to end users&nbsp;</li>\r\n<li>Perform any job-related task or command assigned by direct manager/ supervisor</li>\r\n<li>Handling clients relations and understanding clients&rsquo; needs&nbsp;</li>\r\n<li>Setting up forms and questionnaires for clients subscriptions.&nbsp;</li>\r\n<li>Assisting clients in filling technical forms and questionnaires</li>\r\n</ul>',
#   16),
#  ('<ul>\r\n<li>Greet guests &amp; members.</li>\r\n<li>Maintain membership sales and retention programs to meet or exceed membership financial goals.</li>\r\n<li>Perform Membership sale closing procedures including application &amp; contract.</li>\r\n<li>Handle membership payments and complaints.</li>\r\n<li>Handle incoming calls.</li>\r\n<li>Perform facility tour procedures for prospects and completes prospect interest/needs assessment.</li>\r\n<li>Keep all equipment straight and check out when needed.</li>\r\n<li>Keep supplies stocked at all times.</li>\r\n<li>Provide management with daily reports.</li>\r\n<li>Undefined work assigned by supervisor.</li>\r\n</ul>',
#   15),
#  ('<ul>\r\n<li>Maintain a high level of Customer Service standards.</li>\r\n<li>Coach &amp; Supervise Staff (Receptionists, Sales, Trainers &amp; H.K).</li>\r\n<li>Undertake administrative tasks.</li>\r\n<li>Deal with enquiries, complaints and emergencies.</li>\r\n<li>Manage Petty Cash &amp; Budget.</li>\r\n<li>Enhance profitability.</li>\r\n<li>Maintain Fitness Equipment.</li>\r\n<li>Keep statistical and financial records.</li>\r\n<li>Provide Top Managements with Regular Reports.</li>\r\n</ul>',
#   15),
#  ('<strong>Benefits:</strong><br />\r\n<ul>\r\n<li>Highly attractive salaries based on your English.</li>\r\n<li>High Commission .</li>\r\n<li>Transportation (Door to Door) at night for females, and for males to the nearest point.</li>\r\n<li>Full paid training</li>\r\n</ul>',
#   15),
#  ('<ul>\r\n<li>Handle British customers inquiries and complains.</li>\r\n<li>Ensure customer delight and satisfaction.</li>\r\n<li>Provide customer with accurate information and right solutions.</li>\r\n<li>Log customer details on the CRM.</li>\r\n<li>Preform other duties as assigned by management.</li>\r\n<li>Flexible with shift Basis (10 working hours rotational shifts 5 days a week. No overnight shifts, the last shift will end at 12 AM).</li>\r\n</ul>',
#   15),
#  ('<ul>\r\n<li>Taking ownership and quickly drive to resolution product issues reported by customers.</li>\r\n<li>Debug customer reported failures, produce test cases to replicate failure and log issues with QA and Engineering teams.</li>\r\n<li>Exhibit technically expertise around assigned Clickability products and/or services.</li>\r\n<li>Participation in building training programs to build and maintain knowledge cohesion among the Customer Success organization</li>\r\n<li>Maintaining and be actively involved in community forumsActive participation in deployment planning, deployment and testing</li>\r\n<li>Developing and maintaining an in-depth knowledge and expertise regarding the capabilities of our products and services.</li>\r\n<li>Follow-up with unsatisfied customers to ensure their issues are resolved and the customer is satisfied.</li>\r\n<li>Proactively monitor and assume ownership of support case queue and turn over.</li>\r\n<li>Helping customers solve technical platform issues and lead a technical support team.</li>\r\n<li>Prompt follow up until the closure of the case and ensure nothing falls through the cracks.</li>\r\n<li>Answering questions from customers and prospective customers about the features and capabilities of our products and be a authoritative figure on the technical capabilities of the product.</li>\r\n<li>Engage with Operations, Engineering and Professional Services, understand and continuously improve support and escalation process.</li>\r\n<li>Manage case queue and provide leadership in assignment process.</li>\r\n<li>Handle, diagnose and resolve escalated customer technical support issues in a timely manner through email and phone.&nbsp;</li>\r\n<li>Work with the engineering group to effectively resolve escalated issues.</li>\r\n<li>Provide active feedback to engineering regarding product improvements from operations/customer perspective.</li>\r\n<li>Work with Services team at different stages of customer on-boarding.</li>\r\n<li>Contribute to technical knowledge base.</li>\r\n<li>Updating and helping to develop product training material and documentation.</li>\r\n<li>Diligently drive improvements to the product and engineering groups on product related bugs and issues.</li>\r\n</ul>',
#   14),
#  ('<strong>Job qualifications:</strong><strong><br /></strong><br />\r\n<ul>\r\n<li>English fluency is a MUST (A+&amp;A)</li>\r\n<li>Excellent communication skills</li>\r\n<li>Previous sales experience 6 months or more&nbsp;</li>\r\n<li>Understanding of the American culture is a PLUS</li>\r\n</ul>',
#   14),
#  ('<ul>\r\n<li>Reviewing translation work for the translation team</li>\r\n<li>Filling in daily reports regarding the translation quality</li>\r\n<li>Working to develop the processes and procedures of the translation team through building glossaries, style guides and specialized instruction manuals</li>\r\n<li>Discussing translation quality issues with the translation team</li>\r\n</ul>',
#   14),
#  ('<ul>\r\n<li>Responsible for training individuals.</li>\r\n<li>Develop &amp; maintains positive relationships with students in order to monitor &amp; resolve students concerns.</li>\r\n</ul>',
#   13),
#  ('<ul>\r\n<li>Study the products and prepare presentations and identify points of sales for each of them</li>\r\n<li>Stand on the strengths and weak points of the competitors.</li>\r\n<li>Develop great knowledge of the company and its achievements.</li>\r\n<li>Pay visits to customers and create sales opportunities.</li>\r\n<li>Prepare technical presentations and offers and coordinate with the Sales Coordinator.</li>\r\n<li>Submit weekly, monthly, quarterly and annual reports, including details of visits and sales opportunities and plan goals.</li>\r\n<li>Follow-up on tenders and practices</li>\r\n<li>Participate with the Sales Director in putting new goals and prioritize each</li>\r\n<li>Follow-up on customer satisfaction after the installation, operation and training</li>\r\n<li>Coordinate with the technical support team to solve technical and non-technical problems</li>\r\n<li>Coordinate with the Collection team to solve problems related to the collection</li>\r\n<li>Attend tenders</li>\r\n<li>Develop own knowledge and skills in respective fields (technically, sales, language, soft skills)</li>\r\n</ul>',
#   12),
#  ('<p><strong>Job Duties:</strong></p>\r\n<ul>\r\n<li>To continuously provide high quality processing service to achieve maximum customer satisfaction within the specified Service Level Agreements.</li>\r\n<li>Responsible for relationship building and resolving customer queries and problems in a professional manner.</li>\r\n<li>Take ownership and initiative to complete necessary research and customer follow-up or direct the customer to the appropriate department for resolution.</li>\r\n</ul>',
#   12),
#  ('<ul>\r\n<li>Handle British customers inquiries and complains.</li>\r\n<li>Ensure customer delight and satisfaction.</li>\r\n<li>Provide customer with accurate information and right solutions.</li>\r\n<li>Log customer details on the CRM.</li>\r\n<li>Preform other duties as assigned by management.</li>\r\n</ul>',
#   12),
#  ('<p>Seeking hands-on and technical software engineers, for a fairly serious commitment, you: smart (learn new languages and scripting quickly) cool (up with the latest software stuff) and successful (experienced in .Net).<br /><br /></p>\r\n<p>We&rsquo;re interested in your mind. If you can do technical project management and hands-on code fix and feature implementation, we&rsquo;re interested in an on-going relationship with you as our <strong>RMGS </strong>Software Engineer.<br /><br /></p>\r\n<p><strong>Deal breakers: we are only suited for each other if you:<br /><br /></strong></p>\r\n<ul>\r\n<li>Are versed in current software development practices and tools, including:</li>\r\n</ul>\r\n<ol>\r\n<li>Virtual environments</li>\r\n<li>Source control</li>\r\n<li>Remote development</li>\r\n<li>Issue tracking</li>\r\n<li>Build and test automation</li>\r\n<li>Networking management</li>\r\n</ol>\r\n<ul>\r\n<li>Understand programming well enough to learn new languages and scripting quickly.</li>\r\n<li>Speaking of conversation, we need to understand each other; your English must be good enough to talk technically.</li>\r\n</ul>\r\n<p>&nbsp;</p>\r\n<p><strong>Primary Roles and Responsibilities:<br /><br /></strong></p>\r\n<ul>\r\n<li>Full lifecycle application development.</li>\r\n<li>Designing, coding and debugging applications in various software languages.</li>\r\n<li>Software analysis, code analysis, requirements analysis, software review, identification of code metrics, system risk analysis, software reliability analysis</li>\r\n<li>Performance tuning, improvement, balancing, usability, automation.</li>\r\n</ul>\r\n<p>&nbsp;</p>',
#   12),
#  ('<ul>\r\n<li>Responsible for training individuals.</li>\r\n<li>Develop &amp; maintains positive relationships with students in order to monitor &amp; resolve students concerns.</li>\r\n<li>Character &amp; Could Cope With Large Groups Of Audience.</li>\r\n<li>Dynamic and creative approach to training.</li>\r\n<li>Strong communication, presentation and organizational skills.</li>\r\n</ul>',
#   11),
#  ('<p>For Students and Graduates here is a vacancy as a call center Agent.<br /><br /><strong>Requirements and Benefits:</strong></p>\r\n<ul>\r\n<li>Males Only</li>\r\n<li>Graduates from Reputable Universities or 2 years Accredited Institute or Students with maximum 4 courses in the second term "third and fourth"</li>\r\n<li>Salary 1600 + 500 L.E Every 3 months</li>\r\n<li>Transportation + Medical &amp; Social Insurance</li>\r\n<li>Work Location - Maadi</li>\r\n<li>Promotion within 6 Months for any internal Vacancy</li>\r\n<li>Max age 35</li>\r\n</ul>',
#   11),
#  ('<ul>\r\n<li>Understand &amp; implement technical &amp; functional requirements collected by Supervisor.</li>\r\n<li>Develop assigned tasks as per the project plan conducted to him by team leader as well write down the required technical documentation.</li>\r\n<li>Follow and submit all PM and QA activities required according to his role in the project.</li>\r\n<li>Assisting associate consultancies (in case of subordinates )</li>\r\n<li>Conduct unit testing on assigned function quality.</li>\r\n<li>Conduct necessary modifications in case of errors occurrence.</li>\r\n<li>Acting as technical support at customer site.</li>\r\n<li>Accomplishing assignments on time, with quality, as contracted, meeting customer satisfaction.</li>\r\n<li>Assisting in any additional tasks requested by Direct or Unit Manager.</li>\r\n</ul>',
#   11),
#  ("So, the software works. But what if there were a lightning strike? What if there were solar flares? Well, maybe we won't worry about all possible scenarios, but we want you to help us consider some of them.<br />We need QA Engineer to document and record high quality test cases, from:<br />\r\n<ul>\r\n<li>Performance use cases</li>\r\n<li>Customer use cases</li>\r\n<li>Fixed bugs</li>\r\n<li>Product manuals</li>\r\n<li>Customer support tickets</li>\r\n<li>Coverage reports</li>\r\n</ul>\r\n<br />\r\n<p>You would work on multiple products, technologies, and environments. You would need these skills:<br /><br /></p>\r\n<strong>Software engineering &ndash; you should know the current software development practices and tools, including</strong><br />\r\n<ul>\r\n<li>Virtual environments</li>\r\n<li>Source control</li>\r\n<li>&nbsp;Remote development</li>\r\n<li>Issue tracking</li>\r\n<li>Product build and installation</li>\r\n<li>QA experience &ndash; either manual testing, test case documentation, or test case automation</li>\r\n<li>Speaking of conversation, we need to understand each other; your English must be good enough to talk technically.</li>\r\n</ul>\r\n<br />\r\n<p><strong>Primary Roles and Responsibilities:<br /></strong></p>\r\n<ul>\r\n<li>Play a major role to improve quality, functionality, reliability and usability of software products.</li>\r\n<li>Conduct software compatibility tests with programs, hardware, operating systems, or network environments.</li>\r\n<li>Create or maintain databases of known test defects.</li>\r\n<li>Design, develop and execute comprehensive test plan with systematic QA methodology.</li>\r\n<li>Perform thorough test case execution and analysis report.</li>\r\n<li>Analyze test results to assure quality of existing and new functionalities.</li>\r\n<li>Identify, analyze, and document problems with program function, output, online screen, or content.</li>\r\n<li>Investigate customer problems referred by technical support.</li>\r\n<li>Perform initial debugging procedures by reviewing configuration files, logs, or code pieces to determine breakdown source.</li>\r\n<li>Provide feedback and recommendations to developers on software usability and functionality.</li>\r\n<li>Update automated test scripts to ensure currency.</li>\r\n<li>Collaborate with field staff or customers to evaluate or diagnose problems and recommend possible solutions.</li>\r\n</ul>\r\n<p>&nbsp;</p>",
#   11),
#  ("<ul>\r\n<li>Search tenders and apply for them</li>\r\n<li>Contact with foreign companies to get from them quotations</li>\r\n<li>Study the received quotations technically.</li>\r\n<li>Assure that the received quotation completely match the client's inquiry</li>\r\n<li>Prepare financial offer</li>\r\n<li>follow up with the client, the foreign company, shipment agency and custom clearance office to assure the delivery time</li>\r\n<li>Revise the order confirmation and compare it with the order and the offer.</li>\r\n<li>Coordinate with the customer for layout drawings approvals.</li>\r\n<li>Making technical discussions with clients.</li>\r\n<li>Follow up the requested sample list if any.</li>\r\n<li>Coordinate with after sales office to complete the start up.</li>\r\n</ul>",
#   10),
#  ('<ul>\r\n<li>Check the submitted manuscripts in terms of authors&rsquo; list, missing data and manuscripts&rsquo; title</li>\r\n<li>Assign the approved manuscript to the appropriate editor</li>\r\n<li>Follow up on the editorial workflow at all stages to ensure timely completion of the process</li>\r\n<li>Act as a liaison between authors, editors and reviewers during the whole review process</li>\r\n<li>Act as a liaison between authors of accepted manuscripts and the production unit in order to ensure receiving all materials required to proceed with the production cycle</li>\r\n<li>Work collaboratively with the Special Issues team in order to handle all cases related to the launched Special Issues</li>\r\n<li>Work collaboratively with the Information Technology Department in order to resolve complaints of all users</li>\r\n</ul>',
#   10),
#  ('Paid 11 months internship in the customer service "call center" department of a multinational bank<br />providing the opportunity to transfer internally according to the interns\' performance to :<br /><br />\r\n<ul>\r\n<li>Customer Service department</li>\r\n<li>Teller Department</li>\r\n<li>Operations department</li>\r\n</ul>\r\n<strong>Working Conditions:</strong> <br />\r\n<ul>\r\n<li>5 working days</li>\r\n<li>8 working hours / day</li>\r\n<li>Rotational shifts and offs</li>\r\n</ul>',
#   10),
#  ('<ul>\r\n<li>Obtains client information by answering telephone calls; interviewing clients; verifying information.</li>\r\n<li>Determines eligibility by comparing client information to requirements.</li>\r\n<li>Establishes policies by entering client information; confirming pricing.</li>\r\n<li>Informs clients by explaining procedures; answering questions; providing information.</li>\r\n<li>Maintains communication equipment by reporting problems.</li>\r\n<li>Maintains and improves quality results by adhering to standards and guidelines; recommending improved procedures.</li>\r\n<li>Updates job knowledge by studying new product descriptions; participating in educational opportunities.</li>\r\n<li>Accomplishes sales and organization mission by completing related results as needed.</li>\r\n</ul>',
#   10),
#  ('<ul>\r\n<li>Software translation projects related to (antivirus).</li>\r\n<li>Handling of all IT, Software Localization and Legal projects.</li>\r\n<li>Translate projects with the best quality and would train and manage junior translators.</li>\r\n<li>Hiring and training junior translators on using CAT tools (Trados, Loc Studio, Wordfast, etc..)</li>\r\n</ul>',
#   9),
#  ('<ul>\r\n<li>He/ She will be responsible for the content used on magazines, portals and websites.</li>\r\n<li>Plan, research, write and edit articles about lifestyle, Weddings, relationships, etc...</li>\r\n<li>Reviewing and editing articles.</li>\r\n<li>Generating ideas for articles and features .</li>\r\n<li>Attending relevant events, fairs and conferences.</li>\r\n</ul>\r\n<br />\r\n<p>&nbsp;</p>',
#   9),
#  ('<ul>\r\n<li>Coach &amp; Supervise Staff (Receptionists, Sales, Trainers &amp; H.K).</li>\r\n<li>Manage Petty Cash &amp; Budget.</li>\r\n<li>Enhance profitability.</li>\r\n<li>Keep statistical and financial records.</li>\r\n<li>Maintain Fitness Equipment.</li>\r\n<li>Maintain a high level of Customer Service standards.</li>\r\n<li>Undertake administrative tasks.</li>\r\n<li>Deal with enquiries, complaints and emergencies.</li>\r\n<li>Provide Top Managements with Regular Reports.</li>\r\n</ul>',
#   9),
#  ('<ul>\r\n<li>Manages localization projects from beginning to end, working closely with language specialists, localization engineers, terminologists, product management and development, internal business partners and external vendors and other departments</li>\r\n<li>Develops project plans and workflows, managing time, budget, resources and quality control</li>\r\n<li>Following analysis of client specific localization software application requirements, creates and manages internal version of localization project plans, and provides project specific education and coaching to Localization Tester staff</li>\r\n<li>Creates and controls localization project budgets, performs cost tracking analysis, ensures timely issuance of purchase orders and invoices and approves work reports</li>\r\n<li>Analyzes location project risk, and defines mitigation actions of identified risks</li>\r\n<li>Identifies and solves localization issues or disagreements, whether system or product, identifies causes and performs corrective/preventative action</li>\r\n<li>Assigns, monitors and measures project team members&rsquo; work. Manages team&rsquo;s compliance with standards, practices and policies</li>\r\n<li>Directing team&rsquo;s deliveries to timelines and product quality, including responsiveness and professionalism towards both internal and external clients</li>\r\n<li>Leads project/client/business partner meetings and conference calls, including project kick-off meetings, weekly and ad-hoc, issue solves and performs post-mortems, while ensuring meetings are recorded and minutes distributed, manages the delivery of agreed upon active items</li>\r\n<li>Presents regular reports to client, corporate office and peers on progress and forecast of project team&rsquo;s work status, escalating issues and evaluating needed support</li>\r\n<li>Maximizes utilization of team, preparing alternative work for periods without projects and/or billable work for other teams and units.</li>\r\n<li>Active member of corporate management meetings, providing data and project information.</li>\r\n<li>Continually expands knowledge and education in localization trends and news, keeping up to date through active participation in training opportunities.</li>\r\n<li>Develops new and entry level Project Managers through training and coaching opportunities and by creating methodologies, tools, and checklists to improve the project management process .</li>\r\n</ul>',
#   9),
#  ('<ul>\r\n<li>The ideal candidate will be executing, assessing, and troubleshooting software programs and applications which include: configuring, developing, unit testing and documenting software specifications throughout the project life cycle.</li>\r\n</ul>',
#   9),
#  ('<p>Nerves or steel (you).&nbsp; Ribs of data. Should you accept the mission, you as a RMGS Business Intelligence Engineer?</p>\r\n<p><strong>&nbsp;</strong></p>\r\n<p><strong>Job Description:<span style="text-decoration: underline;"><br /><br /></span></strong></p>\r\n<p>With your strong knowledge and skillful use of the following:</p>\r\n<ul>\r\n<li>Database deployment and configuration.</li>\r\n<li>Performance optimization.</li>\r\n<li>Indexing and schema based optimization</li>\r\n<li>Database optimization Tools and techniques.</li>\r\n</ul>\r\n<p>&nbsp;</p>\r\n<p>You would need all kinds of arcane knowledge and experience:</p>\r\n<ul>\r\n<li>Microsoft SQL Server</li>\r\n<li>SQL</li>\r\n<li>Mysql</li>\r\n</ul>\r\n<p>Speaking of conversation, we need to understand each other; your English must be good enough to talk technically.<br /><br /></p>\r\n<p><strong>Primary Roles and Responsibilities:</strong></p>\r\n<ul>\r\n<li>Design, implement and deliver reports based on business requirements.</li>\r\n<li>Design and implement an OLAP Cube database and build reports.</li>\r\n<li>Understand the source systems and source data in detail.</li>\r\n<li>QA any work done by self and other team members.</li>\r\n<li>Document all of the design and development artifacts.</li>\r\n<li>Troubleshoot and support all BI related production processing.</li>\r\n<li>Understand the current reporting environment and use that knowledge to continuously improve the data warehouse.</li>\r\n</ul>',
#   9),
#  ('An Authorized Agent for a large Telecom Company is currently seeking Pre Sales Engineer<br /><br /><strong>Responsiblities &amp; Duties:<br /></strong><br /><ol>\r\n<li>Maintains professional and technical knowledge by understanding new technologies in the market</li>\r\n<li>Maintains customer satisfaction by maintaining rapport with current accounts</li>\r\n<li>Design and propose solutions that can enhance customer productivity</li>\r\n<li>Work with Sales account managers</li>\r\n<li>Liaison with Product Manager to understand details of product direction</li>\r\n</ol>',
#   9),
#  ("We urgently need Account Managers to grow relationships with current and new clients. You'll manage accounts of Egypt's best employers of all sizes.&nbsp;<br /><br />You need to be web-savvy as you'll be selling online services. This is a role focused on client relationship building, retention and satisfaction. You'll manage a book of business and be responsible for its growth and results.<br /><br /><strong>Responsibilities:</strong><br />\r\n<ul>\r\n<li>Service and support existing and new clients</li>\r\n<li>Advise clients on new services and close deals</li>\r\n<li>Be an expert on our products and services</li>\r\n<li>Increase revenue and retention rate for your accounts</li>\r\n<li>Prepare reporting and account documentation</li>\r\n<li>Work directly with client decision-makers</li>\r\n<li>Most support / sales is done in office (email / phones) but large accounts may require on-site visits.</li>\r\n<li>Open new leads and get new clients.</li>\r\n</ul>\r\n<br /><strong>How your success will be measured:</strong><br />\r\n<ul>\r\n<li>Achieve expected new sales and customer retention targets.</li>\r\n<li>Maintain high customer satisfaction rates.</li>\r\n</ul>\r\n<br />We offer competitive compensation of a base salary + commission. Base salary is decided based on your experience and commission is based on your performance and sky's the limit. &nbsp;<br /><br />BasharSoft are the creators of Wuzzuf.com - Egypt's #1 Online Job Site.<br /><br />BasharSoft is an award winning start-up founded in 2009.",
#   8),
#  ('<ul>\r\n<li>Handle Irish customers inquiries and complains.</li>\r\n<li>Ensure customer delight and satisfaction.</li>\r\n<li>Provide customer with accurate information and right solutions.</li>\r\n<li>Log customer details on the CRM.</li>\r\n<li>Preform other duties as assigned by management.</li>\r\n<li>Flexible with shift Basis (9 working hours rotational shifts 5 days a week. No overnight shifts).</li>\r\n</ul>',
#   8),
#  ('<ul>\r\n<li>Devising strategies to drive online traffic to the company website.</li>\r\n<li>Handling the Social Media Channels ( Facebook, Twitter, Instagram)</li>\r\n<li>Responsible for creating and updating the Website Content</li>\r\n<li>Utilizing a range of techniques including paid search, SEO.</li>\r\n<li>Evaluating customer research, market conditions and competitor data.</li>\r\n<li>Devising strategies to drive online traffic to the company website.</li>\r\n</ul>',
#   8),
#  ('<ul>\r\n<li>Performs wet and instrumental analysis (HPLC, UV, GC, FTIR, Melting point device, Refractive index, Viscometer, Conductmeter, Titroprocessor, pH meter, Balance, Furnaces, muffles and ovens, Optical rotation device, Centrifuge, Sieve analyzer, Ion selective electrodes, Dissolution tester, Disintegration tester, Hardness tester, Friability tester)of raw materials, in-process and finished products.</li>\r\n<li>Performs physical testing and chemical analysis of pharmaceutical packaging material.</li>\r\n<li>Troubleshoots and resolves operations issues.</li>\r\n<li>Prepares and standardizes volumetric solutions, reagents and indicators.</li>\r\n<li>Calibrates instruments according to work instructions to ensure compliance to standards.</li>\r\n<li>Validates the assay methods of finished products to ensure products&rsquo; compliance to standards.</li>\r\n<li>Participates in validation of facilities and manufacturing processes to ensure compliance to standards.</li>\r\n<li>Participate as qualified analyst in ISO 17025</li>\r\n<li>Participate in international proficiency test</li>\r\n</ul>',
#   8),
#  ('<ul>\r\n<li>The UI/Front-End Developer will be responsible for developing and delivering a rich highly interactive interfaces</li>\r\n<li>Develop new user interface solutions to support customers.</li>\r\n<li>Contribute the user-facing design and implementation as required to deliver complete, complex new features.</li>\r\n<li>Work closely with product stakeholders to design the best possible user experience.</li>\r\n<li>Add new functionality to existing systems, while constantly improving usability and quality.</li>\r\n<li>Design and implement unit, component, and system tests in coordination with QA and other engineers to ensure excellent quality.</li>\r\n<li>Solve interesting problems, such as designing for both occasional and expert-level users of the interface.</li>\r\n</ul>',
#   8),
#  ('<ul>\r\n<li>Being responsible for accounts of hospital all around Egypt to maintain and install medical devices</li>\r\n</ul>',
#   8),
#  ("<ul>\r\n<li>Attracts potential customers by answering product and service questions; suggesting information about other products and services.</li>\r\n<li>Opens customer accounts by recording account information.</li>\r\n<li>Maintains customer records by updating account information.</li>\r\n<li>Resolves product or service problems by clarifying the customer's complaint; determining the cause of the problem; selecting and explaining the best solution to solve the problem; expediting correction or adjustment; following up to ensure resolution.</li>\r\n<li>Maintains financial accounts by processing customer adjustments.</li>\r\n<li>Recommends potential products or services to management by collecting customer information and analyzing customer needs.</li>\r\n<li>Prepares product or service reports by collecting and analyzing customer information.</li>\r\n<li>Contributes to team effort by accomplishing related results as needed.</li>\r\n</ul>",
#   8),
#  ('<strong>Benefits:</strong><br /><br />\r\n<ul>\r\n<li>Highly attractive salaries based on your English.</li>\r\n<li>High Commission .</li>\r\n<li>Transportation (Door to Door) at night for females, and for males to the nearest point.</li>\r\n<li>Full paid training</li>\r\n</ul>',
#   8),
#  ('<ul>\r\n<li>Design and build advanced applications for the Android platform</li>\r\n<li>Collaborate with cross-functional teams to define, design, and ship new features.</li>\r\n<li>Work with outside data sources and API&rsquo;s</li>\r\n<li>Unit-test code for robustness, including edge cases, usability, and general reliability.</li>\r\n<li>Work on bug fixing and improving application performance.</li>\r\n<li>Continuously discover, evaluate, and implement new technologies to maximize development efficiency.</li>\r\n</ul>',
#   8),
#  ('<ul>\r\n<li>Full lifecycle application development.</li>\r\n<li>Designing, coding and debugging applications in various software languages.</li>\r\n<li>Software analysis, code analysis, requirements analysis, software review</li>\r\n</ul>',
#   8),
#  ('<ul>\r\n<li>Full lifecycle application development.</li>\r\n<li>Designing, coding and debugging PHP &amp; MySQL applications.</li>\r\n<li>Software bug fixing for PHP &amp; MySQL web applications.</li>\r\n<li>Develop PHP applications using PHP frameworks like CodeIgniter, CakePHP, Symfony, Zend Framework.</li>\r\n<li>Using software architecture design patterns like MVC.</li>\r\n<li>Software analysis, code analysis, requirements analysis, software review.</li>\r\n<li>Customize and enhance existing applications based on specific customer requirements.</li>\r\n<li>It is a 3 month Contractor position.</li>\r\n</ul>',
#   8),
#  ('<p><strong>Our client a Leading Multinational Bank<br /><br />Job Duties:</strong></p>\r\n<ul>\r\n<li>To continuously provide high quality processing service to achieve maximum customer satisfaction within the specified Service Level Agreements.</li>\r\n<li>Responsible for relationship building and resolving customer queries and problems in a professional manner.</li>\r\n<li>Take ownership and initiative to complete necessary research and customer follow-up or direct the customer to the appropriate department for resolution.</li>\r\n</ul>',
#   8),
#  ('<ul>\r\n<li>Plan and execute all web, email, social media and advertising campaigns</li>\r\n<li>Design, build and maintain our social media presence</li>\r\n<li>Measure and report performance of all digital marketing campaigns, and assess against g<span style="font-size: 12px;">oals (ROI and KPIs)</span></li>\r\n<li>Identify trends and insights, and optimize spend and performance based on the insights</li>\r\n<li>Brainstorm new and creative growth strategies</li>\r\n<li>Plan, execute, and measure experiments and conversion tests</li>\r\n<li>Collaborate with internal teams to create landing pages and optimize user experience</li>\r\n<li>Utilize strong analytical ability to evaluate end-to-end customer experience across m<span style="font-size: 12px;">ultiple channels and customer touch points</span></li>\r\n<li>Instrument conversion points and optimize user funnels</li>\r\n</ul>',
#   8),
#  ('<ul>\r\n<li>Structural design of Reinforced Concrete Structures using Computer designing programs and AutoCAD.</li>\r\n</ul>',
#   8),
#  ('<strong>\xd8\xa7\xd9\x84\xd9\x85\xd9\x87\xd8\xa7\xd9\x85 \xd9\x88\xd8\xa7\xd9\x84\xd9\x85\xd8\xb3\xd8\xa6\xd9\x88\xd9\x84\xd9\x8a\xd8\xa7\xd8\xaa \xd9\x88\xd8\xa7\xd9\x84\xd8\xb5\xd9\x84\xd8\xa7\xd8\xad\xd9\x8a\xd8\xa7\xd8\xaa</strong><br />\r\n<ul>\r\n<li>\xd8\xb9\xd9\x85\xd9\x84 \xd8\xb3\xd8\xac\xd9\x84\xd8\xa7\xd8\xaa \xd9\x85\xd9\x86\xd8\xaa\xd8\xb8\xd9\x85\xd9\x87 \xd9\x84\xd9\x84\xd8\xb3\xd8\xa7\xd8\xaf\xd9\x87 \xd9\x85\xd8\xb4\xd8\xb1\xd9\x81\xd9\x8a \xd9\x88\xd9\x85\xd8\xb3\xd8\xa6\xd9\x88\xd9\x84\xd9\x89 \xd8\xa7\xd9\x84\xd8\xaa\xd8\xb3\xd9\x88\xd9\x8a\xd9\x82 \xd8\xa8\xd8\xa7\xd9\x84\xd8\xaf\xd8\xa7\xd8\xb1\xd9\x87</li>\r\n<li>\xd8\xa7\xd9\x86\xd8\xb4\xd8\xa7\xd8\xa1 \xd8\xb3\xd8\xac\xd9\x84\xd8\xa7\xd8\xaa \xd9\x85\xd9\x86\xd9\x81\xd8\xb1\xd8\xaf\xd9\x87 \xd8\xa8\xd8\xa7\xd9\x84\xd8\xad\xd8\xa7\xd8\xb3\xd8\xa8 \xd9\x84\xd9\x83\xd9\x84 \xd9\x85\xd9\x86 \xd8\xa7\xd9\x84\xd8\xb3\xd8\xa7\xd8\xaf\xd9\x87 \xd9\x85\xd8\xb4\xd8\xb1\xd9\x81\xd9\x8a \xd9\x88\xd9\x85\xd8\xb3\xd8\xa6\xd9\x88\xd9\x84\xd9\x8a \xd8\xa7\xd9\x84\xd8\xaa\xd8\xb3\xd9\x88\xd9\x8a\xd9\x82</li>\r\n<li>\xd8\xad\xd8\xb5\xd8\xb1 \xd9\x88\xd8\xaa\xd8\xb5\xd9\x86\xd9\x8a\xd9\x81 \xd8\xac\xd9\x85\xd9\x8a\xd8\xb9 \xd8\xa7\xd9\x84\xd8\xb9\xd9\x85\xd9\x84\xd8\xa7\xd8\xa1 \xd8\xb9 \xd9\x85\xd8\xb3\xd8\xaa\xd9\x88\xd9\x89 \xd8\xac\xd9\x85\xd9\x8a\xd8\xb9 \xd9\x85\xd9\x86\xd8\xa7\xd8\xb7\xd9\x82 \xd8\xa7\xd9\x84\xd8\xb9\xd9\x85\xd9\x84 \xd9\x85\xd9\x86 \xd8\xae\xd9\x84\xd8\xa7\xd9\x84 \xd8\xa7\xd8\xb3\xd8\xaa\xd9\x85\xd8\xa7\xd8\xb1\xd9\x87 \xd8\xad\xd8\xb5\xd8\xb1 \xd9\x88\xd8\xaa\xd8\xb5\xd9\x86\xd9\x8a\xd9\x81 \xd8\xa7\xd9\x84\xd8\xb9\xd9\x85\xd9\x84\xd8\xa7\xd8\xa1</li>\r\n<li>\xd8\xa7\xd8\xb3\xd8\xaa\xd9\x84\xd8\xa7\xd9\x85 \xd8\xb7\xd9\x84\xd8\xa8\xd8\xa7\xd8\xaa \xd8\xa7\xd9\x84\xd8\xb9\xd9\x85\xd9\x84\xd8\xa7\xd8\xa1 \xd9\x85\xd9\x86 \xd8\xa7\xd9\x84\xd8\xb3\xd8\xa7\xd8\xaf\xd9\x87 \xd9\x85\xd8\xb4\xd8\xb1\xd9\x81\xd9\x8a \xd9\x88\xd9\x85\xd8\xb3\xd8\xa6\xd9\x88\xd9\x84\xd9\x89 \xd8\xa7\xd9\x84\xd8\xaa\xd8\xb3\xd9\x88\xd9\x8a\xd9\x82</li>\r\n<li>\xd8\xb9\xd9\x85\xd9\x84 \xd8\xac\xd8\xaf\xd9\x88\xd9\x84 \xd8\xb2\xd9\x85\xd9\x86\xd9\x89 \xd8\xa7\xd8\xb3\xd8\xa8\xd9\x88\xd8\xb9\xd9\x89 \xd9\x84\xd9\x86\xd8\xaf\xd9\x88\xd8\xa7\xd8\xaa \xd8\xa7\xd9\x84\xd8\xaf\xd8\xb9\xd8\xa7\xd9\x8a\xd9\x87</li>\r\n<li>\xd8\xa7\xd8\xb3\xd8\xaa\xd9\x84\xd8\xa7\xd9\x85 \xd9\x88\xd8\xad\xd8\xb5\xd8\xb1 \xd8\xa7\xd8\xb3\xd9\x85\xd8\xa7\xd8\xa1 \xd8\xa7\xd9\x84\xd9\x81\xd9\x86\xd9\x8a\xd9\x86 \xd8\xa7\xd9\x84\xd9\x85\xd8\xb4\xd8\xa7\xd8\xb1\xd9\x83\xd9\x8a\xd9\x86 \xd9\x81 \xd8\xa7\xd9\x84\xd9\x86\xd8\xaf\xd9\x88\xd8\xa7\xd8\xaa</li>\r\n<li>\xd9\x85\xd8\xaa\xd8\xa7\xd8\xa8\xd8\xb9\xd9\x87 \xd8\xaa\xd8\xad\xd9\x82\xd9\x8a\xd9\x82 \xd8\xa7\xd9\x84\xd9\x87\xd8\xaf\xd9\x81 \xd8\xa7\xd9\x84\xd8\xb4\xd9\x87\xd8\xb1\xd9\x89 \xd9\x85\xd8\xb9 \xd9\x85\xd8\xb4\xd8\xb1\xd9\x81\xd9\x8a \xd9\x88\xd9\x85\xd8\xb3\xd8\xa6\xd9\x88\xd9\x84\xd9\x89 \xd8\xa7\xd9\x84\xd8\xaa\xd8\xb3\xd9\x88\xd9\x8a\xd9\x82</li>\r\n<li>\xd8\xa7\xd9\x84\xd8\xa7\xd9\x84\xd8\xaa\xd8\xb2\xd8\xa7\xd9\x85 \xd8\xa8\xd8\xaa\xd9\x82\xd8\xaf\xd9\x8a\xd9\x85 \xd8\xaa\xd9\x82\xd8\xa7\xd8\xb1\xd9\x8a\xd8\xb1 \xd8\xb4\xd9\x87\xd8\xb1\xd9\x8a\xd9\x87 \xd9\x84\xd9\x84\xd8\xb3\xd8\xa7\xd8\xaf\xd9\x87 \xd8\xb1\xd8\xa6\xd9\x8a\xd8\xb3 \xd9\x85\xd8\xac\xd9\x84\xd8\xb3 \xd8\xa7\xd9\x84\xd8\xa7\xd8\xaf\xd8\xa7\xd8\xb1\xd9\x87 \xd9\x88\xd8\xa7\xd9\x84\xd8\xb3\xd9\x8a\xd8\xaf \xd9\x86\xd8\xa7\xd8\xa6\xd8\xa8 \xd9\x85\xd8\xaf\xd9\x8a\xd8\xb1 \xd8\xa7\xd9\x84\xd8\xa7\xd8\xaf\xd8\xa7\xd8\xb1\xd9\x87 \xd9\x88\xd9\x85\xd8\xaf\xd9\x8a\xd8\xb1 \xd8\xa7\xd9\x84\xd8\xaa\xd8\xb3\xd9\x88\xd9\x8a\xd9\x82</li>\r\n</ul>',
#   7),
#  ('<ul>\r\n<li>Candidate must have a strong understanding of UI, cross-browser compatibility, general web functions and standards.</li>\r\n<li>Maintaining and enhancing existing applications.</li>\r\n<li>Developing new applications in conjunction with support from more senior developers.</li>\r\n<li>Writing documentation for the portions of applications you are involved in.</li>\r\n<li>Conducting testing of applications.</li>\r\n</ul>',
#   7),
#  ('<p><strong>Our client a Leading Multinational Bank</strong> <br /><br /></p>\r\n<p><strong>Job Duties:</strong></p>\r\n<ul>\r\n<li>To continuously provide high quality processing service to achieve maximum customer satisfaction within the specified Service Level Agreements.</li>\r\n<li>Responsible for relationship building and resolving customer queries and problems in a professional manner.</li>\r\n<li>Take ownership and initiative to complete necessary research and customer follow-up or direct the customer to the appropriate department for resolution.</li>\r\n</ul>',
#   7),
#  ('<strong>Job Summary</strong><br />\r\n<ul>\r\n<li>Create and update different documentation and user guides to ensure that the information included is comprehensible and up to date.</li>\r\n</ul>\r\n<br /><strong>Responsibilities</strong>:<br />\r\n<ul>\r\n<li>Determine the needs of users.</li>\r\n<li>Study product samples and talk with the product designers and developers.</li>\r\n<li>Gather information from the web or from other sources if needed.</li>\r\n<li>Work with the technical staff to make products easier to use.</li>\r\n<li>Organize and write supporting documents for products in a clear, simple, and concise language.</li>\r\n<li>Use photographs, drawings, diagrams, animation, and charts that increase users&rsquo; understanding.</li>\r\n<li>Standardize content across platforms and media.</li>\r\n<li>Gather usability feedback from users and designers.</li>\r\n<li>Upload the final output of the written material on the system to be accessible for all concerned teams.</li>\r\n</ul>',
#   7),
#  ('<ul>\r\n<li>Chasing Sales opportunities through marketing calls and visits.</li>\r\n<li>Prepare and execute sales plans for his accounts.</li>\r\n<li>Prepare and follow up on quotations in response to customers requests</li>\r\n<li>Penetrate into competition accounts to insure highest market share.</li>\r\n<li>Follow up on projects to secure reward</li>\r\n</ul>',
#   7),
#  ('<ul>\r\n<li>Confer with systems analysts, engineers, programmers and others to design system and to obtain information on project limitations and capabilities, performance requirements and interfaces, perform data backups and disaster recovery operations.</li>\r\n<li>Design, develop and modify software systems, using modern methodologies to predict and measure outcome and consequences of design.</li>\r\n<li>Modify existing software to correct errors, allow it to adapt to new hardware or to improve its performance.</li>\r\n<li>Audit coding styles and standards and supervise junior team members</li>\r\n</ul>',
#   7),
#  ('<ul>\r\n<li>Adding, updating Database upon the company strategy &amp; regulations</li>\r\n<li>Maintaining high level of accuracy</li>\r\n<li>Support online products by Maps &amp; Geo-codes</li>\r\n<li>Keeps high level of product &amp; service knowledge.</li>\r\n<li>Answers inquiries by clarifying desired information; researching, locating, and providing information</li>\r\n<li>Meet Quality Assurance Requirements and other key performance metrics.</li>\r\n<li>Support online platforms by images</li>\r\n<li>Maintain partnerships by ensuring a high service level as a content provider.</li>\r\n</ul>',
#   7),
#  ('<ul>\r\n<li>Receive requests for new modules and modification to existing tasks from Team Leader.</li>\r\n<li>Participate in conducting analysis reports about user requirements, new task requirements and impact of new task on the internal workflow.</li>\r\n<li>Design modules by dividing the user requirements into sub-modules and setting time frame for task completion.</li>\r\n<li>Assign sub-modules to Software Developers and start programming of modules.</li>\r\n<li>Responsible for database performance tuning.</li>\r\n<li>Test debugging, data validation and test case scenarios.</li>\r\n<li>Stay up to date with the latest software development technologies and methodologies to develop internal work</li>\r\n</ul>',
#   7),
# ...
#   2),
#  ('<ul>\r\n<li>Responsible for decorate homes, shops, offices and other professional environments.</li>\r\n<li>Interior decorators work directly with CEO, giving them advice on which color schemes, layouts, wallpaper and furniture would be best for a particular space.</li>\r\n<li>Make sketches for their decorating ideas and present cost estimates for CEO to approve before beginning projects.</li>\r\n<li>Interior decorators are responsible for choosing paint colors, lighting, window coverings, furniture and flooring as well as artwork, pillows, rugs and other accessories.</li>\r\n<li>Also organize and supervise the arrangement and installation of furnishings.</li>\r\n</ul>',
#   2),
#  ('<ul>\r\n<li>Day to Day management and liaison between key retail partners and programs associated with them In-store</li>\r\n<li>Co-ordinate, produce and distribute point of sale material where required for key retail partners On-line</li>\r\n<li>Co-ordinate and distribute POS material &nbsp;( images, logos, banners, demos, rollup), email and promotional activities, microsite updates for key retail partners where required</li>\r\n<li>Support sales managers in co-ordinating the marketing content for retailer set up forms</li>\r\n<li>Co-ordinate with field rep management company to action specific retail promotional activities in stores</li>\r\n<li>Adhere to internal processes for purchase orders, part numbers, pricing changes and quote requests</li>\r\n<li>Liaise with external suppliers and all relevant internal departments</li>\r\n</ul>',
#   2),
#  ('<ul>\r\n<li>Plan and execute all web, SEO/SEM, marketing database, email, social media and display advertising campaigns</li>\r\n<li>Design, build and maintain our social media presence</li>\r\n<li>Measure and report performance of all digital marketing campaigns, and assess against goals (ROI and KPIs)</li>\r\n<li>Identify trends and insights, and optimize spend and performance based on the insights</li>\r\n<li>Brainstorm new and creative growth strategies</li>\r\n<li>Plan, execute, and measure experiments and conversion tests</li>\r\n<li>Collaborate with internal teams to create landing pages and optimize user experience</li>\r\n<li>Utilize strong analytical ability to evaluate end-to-end customer experience across multiple channels and customer touch points</li>\r\n<li>Instrument conversion points and optimize user funnels</li>\r\n<li>Collaborate with agencies and other vendor partners</li>\r\n<li>Evaluate emerging technologies. Provide thought leadership and perspective for adoption where appropriate</li>\r\n</ul>',
#   2),
#  ('<ul>\r\n<li>Creating, maintaining, and executing test plans and test cases against any required hardware and software platforms.</li>\r\n<li>Evaluating assignments and their requirements and estimating time-frame for executing test plans.</li>\r\n<li>Analyzing and communicating test results through reports and stand-up meetings with projects&rsquo; developers and Project Managers.</li>\r\n<li>Tracking route-cases of defects, reporting them and assuring that they are solved.</li>\r\n<li>Executing day-to-day QC activities such as stand-up meetings, progress reports and testing.</li>\r\n<li>Reviewing requirements, business objectives and technical specifications, with developers, business people (sometimes Client) and other QC engineers for consistency and accuracy to make sure they are well-documents and achieved.</li>\r\n<li>Participating in the development of established test processes, methodologies and techniques.</li>\r\n<li>Working closely with other departmental staff to achieve QC team objectives, and Project objectives</li>\r\n</ul>\r\n<br />\r\n<p>&nbsp;</p>',
#   2),
#  ('The primary role of the Business Development Manager is to prospect for new clients by networking, cold calling, advertising or other means of generating interest from potential clients. They must then plan persuasive approaches and pitches that will convince potential clients to do business with the company. They must develop a rapport with new clients, and set targets for sales and provide support that will continually improve the relationship. They are also required to grow and retain existing accounts by presenting new solutions and services to clients. Business Development Managers work with mid and senior level management, marketing, and technical staff. He/she may manage the activities of others responsible for developing business for the company. Strategic planning is a key part of this job description, since it is the business manager&rsquo;s responsibility to develop the pipeline of new business coming in to the company. This requires a thorough knowledge of the market, the solutions/services the company can provide, and of the company&rsquo;s competitors. While the exact responsibilities will vary from company to company, the main duties of the Business Development Manager can be summarized as follows:<br /><br />\r\n<p><strong>New Business Development:<br /><br /></strong></p>\r\n<ul>\r\n<li><span style="font-size: 12px;">Prospect for potential new clients and turn this into increased business.</span></li>\r\n<li><span style="font-size: 12px;">Cold call as appropriate within your market or geographic area to ensure a robust pipeline of opportunities. </span></li>\r\n<li><span style="font-size: 12px;">Meet potential clients by growing, maintaining, and leveraging your network.</span></li>\r\n<li><span style="font-size: 12px;">Identify potential clients, and the decision makers within the client organization.</span></li>\r\n<li><span style="font-size: 12px;">Research and build relationships with new clients.</span></li>\r\n<li><span style="font-size: 12px;">Set up meetings between client decision makers and company&rsquo;s practice leaders/Principals.</span></li>\r\n<li><span style="font-size: 12px;">Plan approaches and pitches.</span></li>\r\n<li><span style="font-size: 12px;"> Work with team to develop proposals that speaks to the client&rsquo;s needs, concerns, and objectives.</span></li>\r\n<li><span style="font-size: 12px;">Participate in pricing the solution/service.</span></li>\r\n<li><span style="font-size: 12px;">Handle objections by clarifying, emphasizing agreements and working through differences to a positive conclusion. </span></li>\r\n<li><span style="font-size: 12px;">Use a variety of styles to persuade or negotiate appropriately.</span></li>\r\n<li><span style="font-size: 12px;">Present an image that mirrors that of the client.</span></li>\r\n</ul>',
#   2),
#  ('<br />We\'re willing to have a new member as "<strong>iOS Developer</strong>" to join our family. If you\'re of <strong>2+ years of experience</strong>, <strong>Alexandria resident</strong>, willing to enhance your skills, gain knowledge &amp; have a promising career path. You\'re the one we\'re looking for !!<br /><strong id="tinymce" class="mceContentBody " dir="ltr"></strong>',
#   2),
#  ('<br />\r\n<ul>\r\n<li>Provides answers to clients by identifying problems; researching answers; guiding client through corrective steps.</li>\r\n<li>Improves client references by writing and maintaining documentation.</li>\r\n<li>Participates in development of client training programs by identifying learning issues; recommending instructional language.</li>\r\n<li>Accommodates client disabilities by recommending devices and techniques.</li>\r\n<li>Improves system performance by identifying problems; recommending changes.</li>\r\n<li>Updates job knowledge by participating in educational opportunities; maintaining personal networks.</li>\r\n<li>Accomplishes information systems and organization mission by completing related results as needed.</li>\r\n</ul>\r\n<p><br /><br /></p>',
#   2),
#  ('ColProd is a Cairo-based start-up developing its own homegrown projects. We conceive and develop original solutions that support community building, audience activation and, finally, the generation of qualitative insights (semantic analysis, sentiment analysis and image analysis).\r\n<p>Magicrowd is our flagship product. It supports a new marketing strategy based on audience listening and user generated content (brands co-create products with their audience, curate content together, enter in a personal relationship).</p>\r\n<p>ColProd has now a growing market base in Cairo, London and Paris. It&rsquo;s a place where you will build capacity by taking on technical challenges involving the latest technologies. At ColProd we especially recognise and reward dedication, involvement and appetite for excellence.<br /><br />We are looking for creative, innovative and open minded <span id="docs-internal-guid-66ab24c3-a1f3-bae4-d31f-ca6b12c13ca3"><span>individuals</span></span>&nbsp;to join the team and take ownership of developing home-grown products and mining creative&nbsp;solutions for deep technical challenges.</p>\r\n<p><strong>Job Roles:</strong></p>\r\n<ul>\r\n<li>Work on the development aspects of system design, code construction and optimisation, database design, unit and integration testing, and performance enhancement for in house software products.</li>\r\n<li>Develop new products in a lean environment based on iterative and validated learning.</li>\r\n<li>Write automated tests for software</li>\r\n<li>Participate in designing and developing modern user experience</li>\r\n<li><span id="docs-internal-guid-66ab24c3-a1f4-0837-1eab-ec9a158e9bc6"><span>Maintain existing software components and integrate newly developed components</span></span></li>\r\n</ul>',
#   2),
#  ('<p><strong>SA Engineering and Provisioning<br /><br /></strong></p>\r\n<ul>\r\n<li>Install new / rebuild existing servers and configure hardware, peripherals, services, settings, directories, storage, etc. in accordance with standards and project/operational requirements.</li>\r\n<li>Install and configure systems such as supports I-Listen (recording System).</li>\r\n<li>Develop and maintain installation and configuration procedures.</li>\r\n</ul>\r\n<br />\r\n<p>&nbsp;<strong>Operations and Support</strong></p>\r\n<ul>\r\n<li>Perform daily system monitoring, verifying the integrity and availability of all hardware, server resources, systems and key processes, reviewing system and application logs, and verifying completion of scheduled jobs such as backups.</li>\r\n<li>Perform daily backup operations, ensuring all required file systems and system data are successfully backed up to the appropriate media, recovery disks are created, and media is recycled and sent off site as necessary.</li>\r\n<li>Create, change, and delete user accounts per request.</li>\r\n<li>Provide support per request from various clients categories.</li>\r\n<li>Investigate and troubleshoot issues.</li>\r\n<li>Repair and recover from hardware or software failures.</li>\r\n<li>Coordinate and communicate with impacted clients.</li>\r\n</ul>\r\n<br />\r\n<p><strong>Maintenance</strong></p>\r\n<ul>\r\n<li>Apply OS patches and upgrades on a regular basis, and upgrade administrative tools and utilities. Configure / add new services as necessary.</li>\r\n<li>Upgrade and configure system software and applications per project or operational needs.</li>\r\n<li>Maintain operational, configuration, or other procedures.</li>\r\n<li>Perform ongoing performance tuning, hardware upgrades, and resource optimization as required.&nbsp;</li>\r\n<li>Configure CPU, memory, and disk partitions as required.</li>\r\n</ul>\r\n<br />\r\n<p>&nbsp;<strong>COMPLEXITY/PROBLEM SOLVING: </strong></p>\r\n<ul>\r\n<li>Position deals with a variety of problems and sometime has to decide which answer is best. The question/issues are typically clear and requires determination of which answer (from a few choices) is the best.</li>\r\n</ul>',
#   2),
#  ('<ul>\r\n<li><span style="font-size: 12px;">Monitor or observe operations to ensure that they meet production standards</span></li>\r\n<li><span style="font-size: 12px;">Recommend adjustments to the process or assembly</span></li>\r\n<li><span style="font-size: 12px;">Inspect, test, or measure materials or products being produced</span></li>\r\n</ul>',
#   2),
#  ('<ul>\r\n<li>Create and review test cases</li>\r\n<li>Identifying, reporting, and follow up found defects using the company issue tracking system</li>\r\n<li>Analyzing and documenting test results</li>\r\n<li>Work directly with the product development team in establishing product acceptance and performance criteria for new products</li>\r\n<li>Be responsible for the analysis, reporting and communication of test results on all assigned projects</li>\r\n<li>Help evaluate product and application defects reported by customers and make recommendations for their correction</li>\r\n</ul>',
#   2),
#  ('<ul>\r\n<li>Coformatique is looking for an android developer, the main responsibility is for the production, modification and maintenance of our Android applications.</li>\r\n<li>The candidate will work for an international brand that sells alcohol related products</li>\r\n</ul>',
#   2),
#  ('<ul>\r\n<li>&nbsp;Ensure that each program/project is following the standard processes and using all related templates (taking into consideration the tailoring sheet if it exists) by conducting Process and Product QA audits as per the QA schedule for each program/project.</li>\r\n<li>Prepare the QA Audit Non-compliance Report (NCR) and suggest corrective actions.</li>\r\n<li>Ensure that the QA Audit Non-compliance Report (NCR) corrective actions are implemented by the defined due dates and escalate the status to the QA Director in case of any delay.</li>\r\n<li>Conduct periodic audits on the tracking reports on the program/ project QA schedule, track the NCR until project closure and validate the measurement data.</li>\r\n<li>Review and approve the project Measurement and Analysis plans (MAP) and record comments in the V&amp;V tracker.</li>\r\n<li>Collect and store the validated measurement data as per the frequency defined in the project Measurement and Analysis Plan (MAP) in the Measurement and Analysis sheet.</li>\r\n<li>Collect and store the validated Organizational Measurement and Analysis data as per the frequency defined in the Measurement and Analysis Plan (MAP) in the Organization Measurement &amp; Analysis sheet.</li>\r\n<li>Review the Configuration Management plan(s) using the CMP review checklist, record comments in the V&amp;V Tracker and track the defects till closure.</li>\r\n<li>Conduct Configuration Management audits which shall include two types of audits - functional and physical CM audits.</li>\r\n<li>Prepare the CM audit Non-compliance Report (NCR) and suggest corrective actions.</li>\r\n<li>Ensure that the CM Audit Non-compliance Report (NCR) corrective actions are implemented by the defined due dates and escalate the status to the QA Manager in case of any delay.</li>\r\n<li>Assist in applying any updates in the QMS releases to improve the process.</li>\r\n<li>Update the Process Asset Library (PAL) periodically with the programs /projects data.</li>\r\n<li>Guide the QMS users to implement the process and to use the related templates.</li>\r\n<li>Provides QMS Trainings</li>\r\n<li>Perform any other related job duties as requested by</li>\r\n</ul>',
#   2),
#  ('<ul>\r\n<li>Write clean and well designed codes</li>\r\n<li>Produce detailed specifications&nbsp;</li>\r\n<li>Troubleshoot, test and maintain the core product software and databases to ensure strong optimization and functionality</li>\r\n</ul>',
#   2),
#  ...]

# %% [markdown]
# 274 missing value ..
#
# I can fill these missing cells by the mode of the variable as this is a categorical variable ..
#
# However, this makes none sense .. dut to the nature of the variable that is a description of each job that is almost unique for similar jobs (i.e. all "Data Analysts" jobs might share some common descriptions in their posts) ..
#
# Hence, I'll try to group the posts by (job title) and then fill in the NAs in the description column based on the job title

# %%
# df_job.groupby('job_title').groups

# %%
# job requirements NAs

# %%
# payment_period 

job_payment = Counter(df_job['payment_period']).most_common()
job_payment
# Out:
# [('Per Month', 21642),
#  ('Per Year', 123),
#  ('Per Hour', 59),
#  ('Per Day', 18),
#  (nan, 5),
#  ('Per Week', 3)]

# %%
df_job['payment_period'] = df_job.fillna(df_job.payment_period.mode(), inplace=True)

# %%
df_job['payment_period'].isnull().any().any() # check if NAs are there !
# Out:
# False

# %% [markdown]
# It is done :D ..
#
# payment_period variable is a categorical variable that has (Per month) as the most frequent period ..
#
# this is why the NAs are filled by this most frequent value .. and now the variable hasn't got any missing values.

# %%
# payment_period 

job_currency = Counter(df_job['currency']).most_common()
job_currency
# Out:
# [('Egyptian Pound', 21476),
#  ('United States Dollar', 254),
#  ('Saudi Arabian Riyal', 67),
#  ('U.A. Emirates Dirham', 16),
#  ('Euro', 11),
#  (nan, 5),
#  ('Qatari Riyal', 5),
#  ('Canadian Dollar', 4),
#  ('Jordanian Dinar', 2),
#  ('Indian Rupee', 2),
#  ('British Pound', 2),
#  ('Kuwaiti Dinar', 1),
#  ('Ethiopian Birr', 1),
#  ('Ghanaian Cedis', 1),
#  ('Ecuadoran Sucre', 1),
#  ('Dominican Republic Pesos', 1),
#  ('East Caribbean Dollar', 1)]

# %% [markdown]
# Only 5 NAs ..
#
# We can remove them as these are just 5 rows out of > 21000 rows in total ..
#
# however, let's fill them with the mode so that the data is complete !

# %%
df_job['currency'] = df_job.fillna(df_job.currency.mode(), inplace=True)

# %%
df_job['currency'].isnull().any().any()
# Out:
# False

# %% [markdown]
# Voila :D ..
#
# The currency variable is now complete without any missing values ..

# %% [markdown]
# ### Manipulating typo !

# %% [markdown]
# (city) variable contains invalid values in some cells as stated above in the univariate analysis ..
#
# as this is a categorical variable .. we can replace these invalid cells with the (mode) of the columns .. that is the most frequent city within the whole column (i.e. Cairo) or even remove the rows contain these cells .. let's decide after counting their values ..
#
# After checking their values (from the univariate analysis above for the "city" variable) .. I think it's better not to remove them as they have large number ! .. Yet, it's better to be replaced and the common feature in them is that all of them contain this symbol (\) .. hence, let's search for this symbol and replace its cell with the mode ..

# %%
# # df_job['city'].replace(
# #     to_replace=['\'],
# #     value=df_job.city.mode(),
# #     inplace=True
# # )
                

# import re
# re.search("'\'", df_job['city'])

# # el mafrood to check el cells elli feha deh \ then replace them b el mode w feh single cell feha too much 22222 .. 
# ## momken ne substring deh ..

# %% [markdown]
# ### Bivariate analysis:

# %%
# min_salary vs career level

df_sal_career = pd.concat([df_job['salary_minimum'], df_job['career_level']], axis = 1)
f, ax = plt.subplots(figsize=(8, 6))
plt.xticks(rotation=90)
fig = sns.boxplot(x = 'career_level', y = "salary_minimum", data = df_sal_career)

# %% [markdown]
# The range of minimum_salaries for "Senior Management - i.e. CEO" is high and contains single outlier ..
#
# However, the range of values for the rest of career_level types is smaller, yet, contains a lot of outliers except for (Manager) type.
#
# The type of career_level that has the least minimum_salary is "Student"

# %%
# max_salary vs career level

df_sal_career = pd.concat([df_job['salary_maximum'], df_job['career_level']], axis = 1)
f, ax = plt.subplots(figsize=(8, 6))
plt.xticks(rotation=90)
fig = sns.boxplot(x = 'career_level', y = "salary_maximum", data = df_sal_career)

# %% [markdown]
# The disperssion of values for "Senior Management" in case of maximum_salaries is less than for minimum_salaries .. however, it still has the maximum range of values within all other career_levels ..
#
# Meanwhile, experienced (non_managers) type has a lot of outliers especially that one of (1000,000) ..
#
# Yet, "student" has the minimum salary values

# %%
# maximum vs currency

df_sal_career = pd.concat([df_job['salary_maximum'], df_job['currency']], axis = 1)
f, ax = plt.subplots(figsize=(8, 6))
plt.xticks(rotation=90)
fig = sns.boxplot(x = 'currency', y = "salary_maximum", data = df_sal_career)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-93a081d0c943> in <module>()
#       4 f, ax = plt.subplots(figsize=(8, 6))
#       5 plt.xticks(rotation=90)
# ----> 6 fig = sns.boxplot(x = 'currency', y = "salary_maximum", data = df_sal_career)
#
# /usr/local/lib/python2.7/dist-packages/seaborn/categorical.pyc in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2215     kwargs.update(dict(whis=whis, notch=notch))
#    2216
# -> 2217     plotter.plot(ax, kwargs)
#    2218     return ax
#    2219
#
# /usr/local/lib/python2.7/dist-packages/seaborn/categorical.pyc in plot(self, ax, boxplot_kws)
#     542     def plot(self, ax, boxplot_kws):
#     543         """Make the plot."""
# --> 544         self.draw_boxplot(ax, boxplot_kws)
#     545         self.annotate_axes(ax)
#     546         if self.orient == "h":
#
# /usr/local/lib/python2.7/dist-packages/seaborn/categorical.pyc in draw_boxplot(self, ax, kws)
#     479                                          positions=[i],
#     480                                          widths=self.width,
# --> 481                                          **kws)
#     482                 color = self.colors[i]
#     483                 self.restyle_boxplot(artist_dict, color, props)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1708                     warnings.warn(msg % (label_namer, func.__name__),
#    1709                                   RuntimeWarning, stacklevel=2)
# -> 1710             return func(ax, *args, **kwargs)
#    1711         pre_doc = inner.__doc__
#    1712         if pre_doc is None:
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_axes.pyc in boxplot(self, x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_xticks, autorange, zorder)
#    3443                            meanline=meanline, showfliers=showfliers,
#    3444                            capprops=capprops, whiskerprops=whiskerprops,
# -> 3445                            manage_xticks=manage_xticks, zorder=zorder)
#    3446         return artists
#    3447
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_axes.pyc in bxp(self, bxpstats, positions, widths, vert, patch_artist, shownotches, showmeans, showcaps, showbox, showfliers, boxprops, whiskerprops, flierprops, medianprops, capprops, meanprops, meanline, manage_xticks, zorder)
#    3811
#    3812             # draw the medians
# -> 3813             medians.extend(doplot(med_x, med_y, **final_medianprops))
#    3814
#    3815             # maybe draw the means
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_axes.pyc in doplot(*args, **kwargs)
#    3713         if vert:
#    3714             def doplot(*args, **kwargs):
# -> 3715                 return self.plot(*args, **kwargs)
#    3716
#    3717             def dopatch(xs, ys, **kwargs):
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1708                     warnings.warn(msg % (label_namer, func.__name__),
#    1709                                   RuntimeWarning, stacklevel=2)
# -> 1710             return func(ax, *args, **kwargs)
#    1711         pre_doc = inner.__doc__
#    1712         if pre_doc is None:
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_axes.pyc in plot(self, *args, **kwargs)
#    1439             lines.append(line)
#    1440
# -> 1441         self.autoscale_view(scalex=scalex, scaley=scaley)
#    1442         return lines
#    1443
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_base.pyc in autoscale_view(self, tight, scalex, scaley)
#    2238
#    2239         if self.use_sticky_edges and (self._xmargin or self._ymargin):
# -> 2240             stickies = [artist.sticky_edges for artist in self.get_children()]
#    2241             x_stickies = sum([sticky.x for sticky in stickies], [])
#    2242             y_stickies = sum([sticky.y for sticky in stickies], [])
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/artist.pyc in sticky_edges(self)
#     890         self.stale = True
#     891
# --> 892     @property
#     893     def sticky_edges(self):
#     894         """
#
# KeyboardInterrupt:

# %%
# minimum vs currency 

df_sal_career = pd.concat([df_job['salary_minimum'], df_job['currency']], axis = 1)
f, ax = plt.subplots(figsize=(8, 6))
plt.xticks(rotation=90)
fig = sns.boxplot(x = 'currency', y = "salary_minimum", data = df_sal_career)

# %% [markdown]
# The dispersion of minimum values is in general higher than of maximum values .. especially for USD, Canadian Dollar and Saudi Arabian Riyal ..
#
# that are scattered over higher range of values with lots of outliers in case of USD ..
#
# EGP still suffers from huge number of outliers ..

# %% [markdown]
# ### Post_date:
# Post_date variable is in the form of date_time .. it will be hard working on it in this format ..
#
# let's extract day, month and year from this variable and check if there is a relation between those montioned (i.e. day, month or year) and the other variables .. i.e. is there certain year has peak in either minimum or maximum salaries ?! ..

# %%
df_job['post_year'] = pd.DatetimeIndex(df_job['post_date']).year
df_job['post_year'].unique()

# %% [markdown]
# This is expected :D .. the data set contains records from 2014 to 2016 published jobs ..

# %%
df_job['post_month'] = pd.DatetimeIndex(df_job['post_date']).month
df_job['post_month'].unique()

# %% [markdown]
# there are posts related to every month within the year .. !

# %%
df_job['post_day'] = pd.DatetimeIndex(df_job['post_date']).day
df_job['post_day'].unique()

# %% [markdown]
# It seems we have posts on a daily basis within the month ..

# %%
# max_salary vs post_year

df_sal_career = pd.concat([df_job['salary_maximum'], df_job['post_year']], axis = 1)
f, ax = plt.subplots(figsize=(8, 6))
plt.xticks(rotation=90)
fig = sns.boxplot(x = 'post_year', y = "salary_maximum", data = df_sal_career)

# %% [markdown]
# The dispersion of maximum salaries is the highest in 2015 .. and the lowest in 2016 ..
#
# However, in general the three years suffer from outliers ..

# %% [markdown]
# Let's check if the same pattern exists for the (range of salary values .. i.e. maximum - minimum)
#
# Yet, before doing this .. let's check if there is a relationship between minimum and maximum salaries ..

# %%
## min vs max salaries

sns.regplot(df_job['salary_minimum'], df_job['salary_maximum'])

# %% [markdown]
# ### Comment ..
#
# There is a positive linear relationship between minimum and maximum salaries .. that is whenever the minimum salary increases the maximum is also increases ..
#
# and it is obvious that we still have that 1000,000 salary value stands there on top ! ..
#
# Hence, let's work on the range of values (i.e. max - min) instead of repeating the plotting process twice (once for min and another for max salary values)

# %%
df_job['salary_range'] = df_job['salary_maximum'] - df_job['salary_minimum']
df_job['salary_range'].head()

# %%
# salary_range vs post_year

df_sal_career = pd.concat([df_job['salary_range'], df_job['post_year']], axis = 1)
f, ax = plt.subplots(figsize=(8, 6))
plt.xticks(rotation=90)
fig = sns.boxplot(x = 'post_year', y = "salary_range", data = df_sal_career)

# %% [markdown]
# wow ! ..
#
# It seems we have variations in salaries in 2015 ! ..
#
# Lots of outliers are there especially that point on 1000,000 ..
#
# Meanwhile, the number of outliers and dispersion of them are less in 2014 and 2016 for the range of salaries compared to maximum salaries ..

# %%
# salary_range vs post_month

df_sal_career = pd.concat([df_job['salary_range'], df_job['post_month']], axis = 1)
f, ax = plt.subplots(figsize=(8, 6))
plt.xticks(rotation=90)
fig = sns.boxplot(x = 'post_month', y = "salary_range", data = df_sal_career)

# %% [markdown]
# Viola ! :D ..
#
# The huge salary range post of 1000,000 occurs in March .. we also have another less severe outlier in December .. followed by May, and Jan ..
#
# The salaries in April are a bit clustered with no extreme outliers ..

# %%
# salary_range vs post_day

df_sal_career = pd.concat([df_job['salary_range'], df_job['post_day']], axis = 1)
f, ax = plt.subplots(figsize=(8, 6))
plt.xticks(rotation=90)
fig = sns.boxplot(x = 'post_day', y = "salary_range", data = df_sal_career)

# %% [markdown]
# Precisely, this unique post of 1000,000 occurs in 16th March :D ..
#
# There are other higher range of salaries post in 29th ..

# %% [markdown]
# We may breakdown the analysis futher to check the time of each post .. and I think this might be of any usefulness cause it might indicate which time within the day the posts of high salaries are published ! ..

# %%
df_job['post_hour'] = pd.DatetimeIndex(df_job['post_date']).hour
df_job['post_hour'].unique()

# %%
# salary_range vs post_hour

df_sal_career = pd.concat([df_job['salary_range'], df_job['post_hour']], axis = 1)
f, ax = plt.subplots(figsize=(8, 6))
plt.xticks(rotation=90)
fig = sns.boxplot(x = 'post_hour', y = "salary_range", data = df_sal_career)

# %% [markdown]
# :) out intersting post was published at 2:00 am ..
#
# There are outliers at 16 and less severe one at 14 .. and it seems we have odd pattern ar 5:00

# %%
## job views vs  year 

df_sal_career = pd.concat([df_job['views'], df_job['post_year']], axis = 1)
f, ax = plt.subplots(figsize=(8, 6))
plt.xticks(rotation=90)
fig = sns.boxplot(x = 'post_year', y = "views", data = df_sal_career)

# %% [markdown]
# In general the number of viewers in 2016 is fewer than the other years with less variability and fewer number of outliers ..
#
# The maximum number of outliers occured in 2014 especially that point of greater than 35000 views !

# %% [markdown]
# The above charts only help us idetifying the outliers within the data components (i.e. year, month and day) ..
#
# however, if we want to check the change of another variable (i.e. number of views) vs this data components .. we should visualize it using line chart ..
#
# Let's give it a try :)

# %%
# line charts ..

# %%
## city
# job_requirements
